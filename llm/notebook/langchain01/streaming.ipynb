# %% [markdown]
# # Streaming
#
# This notebook covers functionality related to streaming.
#
# For more information, see:
#
# - [Streaming with LCEL](https://python.langchain.com/docs/expression_language/interface#stream)
#
# - [Streaming for RAG](https://python.langchain.com/docs/use_cases/question_answering/streaming)
#
# - [Streaming for Agents](https://python.langchain.com/docs/modules/agents/how_to/streaming)

# %% [markdown]
# ## Basic Streaming

# %%
import logging
from dotenv import load_dotenv

from langchain_openai import ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser

# %%
logging.basicConfig(level=logging.INFO)
log = logging.getLogger(__name__)

load_dotenv()
# Out:
# True

# %%
prompt = ChatPromptTemplate.from_template("Tell me a joke about {topic}")
model = ChatOpenAI()
output_parser = StrOutputParser()
chain = prompt | model | output_parser

# %%
for s in chain.stream({"topic": "bears"}):
    print(s)
# Out:
# Why
#  don
# 't
#  bears
#  use
#  cell
#  phones
# ?
#
#
# Because
#  they
#  can
# 't
#  bear
#  to
#  have
#  their
#  calls
#  dropped
# !

# %% [markdown]
# ## Streaming with RunnableParallel

# %%
from langchain_core.runnables import RunnableParallel

prompt = ChatPromptTemplate.from_template("Tell me a joke about {topic}")
model = ChatOpenAI()
output_parser = StrOutputParser()
chain1 = prompt | model | output_parser

prompt = ChatPromptTemplate.from_template("Write me a poem about {topic}")
model = ChatOpenAI()
output_parser = StrOutputParser()
chain2 = prompt | model | output_parser

parallel_chain = RunnableParallel({
    "joke": chain1,
    "poem": chain2
})

for s in parallel_chain.stream({"topic": "bears"}):
    print(s)
# Out:
# {'poem': ''}
# {'poem': 'In'}
# {'poem': ' the'}
# {'poem': ' wild'}
# {'poem': ' where'}
# {'poem': ' nature'}
# {'poem': "'s"}
# {'poem': ' beauty'}
# {'poem': ' thr'}
# {'poem': 'ives'}
# {'poem': ',\n'}
# {'poem': 'Am'}
# {'poem': 'id'}
# {'poem': 'st'}
# {'poem': ' the'}
# {'poem': ' towering'}
# {'joke': ''}
# {'poem': ' trees'}
# {'poem': ' and'}
# {'poem': ' buzzing'}
# {'joke': 'Why'}
# {'joke': ' don'}
# {'joke': "'t"}
# {'poem': ' h'}
# {'poem': 'ives'}
# {'poem': ',\n'}
# {'poem': 'A'}
# {'poem': ' creature'}
# {'poem': ' ro'}
# {'poem': 'ams'}
# {'poem': ' with'}
# {'poem': ' majestic'}
# {'joke': ' bears'}
# {'joke': ' wear'}
# {'joke': ' shoes'}
# {'joke': '?\n\n'}
# {'joke': 'Because'}
# {'joke': ' they'}
# {'joke': ' have'}
# {'joke': ' bear'}
# {'joke': ' feet'}
# {'joke': '!'}
# {'joke': ''}
# {'poem': ' flair'}
# {'poem': ',\n'}
# {'poem': 'The'}
# {'poem': ' mighty'}
# {'poem': ' bear'}
# {'poem': ','}
# {'poem': ' beyond'}
# {'poem': ' compare'}
# {'poem': '.\n\n'}
# {'poem': 'With'}
# {'poem': ' fur'}
# {'poem': ' as'}
# {'poem': ' dark'}
# {'poem': ' as'}
# {'poem': ' the'}
# {'poem': ' moon'}
# {'poem': 'less'}
# {'poem': ' night'}
# {'poem': ',\n'}
# {'poem': 'A'}
# {'poem': ' symbol'}
# {'poem': ' of'}
# {'poem': ' strength'}
# {'poem': ','}
# {'poem': ' a'}
# {'poem': ' creature'}
# {'poem': ' of'}
# {'poem': ' might'}
# {'poem': ',\n'}
# {'poem': 'Through'}
# {'poem': ' mountains'}
# {'poem': ' and'}
# {'poem': ' rivers'}
# {'poem': ','}
# {'poem': ' it'}
# {'poem': ' ro'}
# {'poem': 'ams'}
# {'poem': ' with'}
# {'poem': ' grace'}
# {'poem': ',\n'}
# {'poem': 'Navig'}
# {'poem': 'ating'}
# {'poem': ' the'}
# {'poem': ' land'}
# {'poem': ' at'}
# {'poem': ' its'}
# {'poem': ' own'}
# {'poem': ' pace'}
# {'poem': '.\n\n'}
# {'poem': 'In'}
# {'poem': ' the'}
# {'poem': ' heart'}
# {'poem': ' of'}
# {'poem': ' the'}
# {'poem': ' forest'}
# {'poem': ','}
# {'poem': ' where'}
# {'poem': ' secrets'}
# {'poem': ' hide'}
# {'poem': ',\n'}
# {'poem': 'The'}
# {'poem': ' bear'}
# {'poem': ' t'}
# {'poem': 'reads'}
# {'poem': ' softly'}
# {'poem': ','}
# {'poem': ' with'}
# {'poem': ' a'}
# {'poem': ' silent'}
# {'poem': ' stride'}
# {'poem': ',\n'}
# {'poem': 'Its'}
# {'poem': ' p'}
# {'poem': 'aws'}
# {'poem': ' leave'}
# {'poem': ' im'}
# {'poem': 'prints'}
# {'poem': ' on'}
# {'poem': ' the'}
# {'poem': ' forest'}
# {'poem': ' floor'}
# {'poem': ',\n'}
# {'poem': 'A'}
# {'poem': ' testament'}
# {'poem': ' to'}
# {'poem': ' a'}
# {'poem': ' life'}
# {'poem': ' it'}
# {'poem': ' must'}
# {'poem': ' explore'}
# {'poem': '.\n\n'}
# {'poem': 'With'}
# {'poem': ' eyes'}
# {'poem': ' like'}
# {'poem': ' amber'}
# {'poem': ','}
# {'poem': ' a'}
# {'poem': ' gaze'}
# {'poem': ' so'}
# {'poem': ' wise'}
# {'poem': ',\n'}
# {'poem': 'It'}
# {'poem': ' sees'}
# {'poem': ' beyond'}
# {'poem': ' what'}
# {'poem': ' meets'}
# {'poem': ' the'}
# {'poem': ' eyes'}
# {'poem': ',\n'}
# {'poem': 'A'}
# {'poem': ' wisdom'}
# {'poem': ' gained'}
# {'poem': ' through'}
# {'poem': ' ages'}
# {'poem': ' past'}
# {'poem': ',\n'}
# {'poem': 'A'}
# {'poem': ' knowledge'}
# {'poem': ' that'}
# {'poem': ' forever'}
# {'poem': ' will'}
# {'poem': ' last'}
# {'poem': '.\n\n'}
# {'poem': 'In'}
# {'poem': ' winter'}
# {'poem': "'s"}
# {'poem': ' embrace'}
# {'poem': ','}
# {'poem': ' it'}
# {'poem': ' seeks'}
# {'poem': ' its'}
# {'poem': ' den'}
# {'poem': ',\n'}
# {'poem': 'A'}
# {'poem': ' sanctuary'}
# {'poem': ' where'}
# {'poem': ' dreams'}
# {'poem': ' begin'}
# {'poem': ',\n'}
# {'poem': 'H'}
# {'poem': 'ibern'}
# {'poem': 'ating'}
# {'poem': ' through'}
# {'poem': ' the'}
# {'poem': ' icy'}
# {'poem': ' cold'}
# {'poem': ',\n'}
# {'poem': 'Em'}
# {'poem': 'br'}
# {'poem': 'acing'}
# {'poem': ' sl'}
# {'poem': 'umber'}
# {'poem': ','}
# {'poem': ' a'}
# {'poem': ' tale'}
# {'poem': ' unt'}
# {'poem': 'old'}
# {'poem': '.\n\n'}
# {'poem': 'Yet'}
# {'poem': ','}
# {'poem': ' in'}
# {'poem': ' the'}
# {'poem': ' warmth'}
# {'poem': ' of'}
# {'poem': ' summer'}
# {'poem': "'s"}
# {'poem': ' embrace'}
# {'poem': ',\n'}
# {'poem': 'The'}
# {'poem': ' bear'}
# {'poem': ' emerges'}
# {'poem': ','}
# {'poem': ' with'}
# {'poem': ' newfound'}
# {'poem': ' grace'}
# {'poem': ',\n'}
# {'poem': 'Fe'}
# {'poem': 'asting'}
# {'poem': ' on'}
# {'poem': ' berries'}
# {'poem': ','}
# {'poem': ' rivers'}
# {'poem': ' te'}
# {'poem': 'eming'}
# {'poem': ' with'}
# {'poem': ' fish'}
# {'poem': ',\n'}
# {'poem': 'A'}
# {'poem': ' symbol'}
# {'poem': ' of'}
# {'poem': ' nature'}
# {'poem': "'s"}
# {'poem': ' eternal'}
# {'poem': ' wish'}
# {'poem': '.\n\n'}
# {'poem': 'Oh'}
# {'poem': ','}
# {'poem': ' bear'}
# {'poem': ','}
# {'poem': ' you'}
# {'poem': ' teach'}
# {'poem': ' us'}
# {'poem': ' lessons'}
# {'poem': ' profound'}
# {'poem': ',\n'}
# {'poem': 'Of'}
# {'poem': ' strength'}
# {'poem': ' and'}
# {'poem': ' resilience'}
# {'poem': ','}
# {'poem': ' we'}
# {'poem': ' have'}
# {'poem': ' found'}
# {'poem': ',\n'}
# {'poem': 'In'}
# {'poem': ' your'}
# {'poem': ' existence'}
# {'poem': ','}
# {'poem': ' a'}
# {'poem': ' balance'}
# {'poem': ' we'}
# {'poem': ' see'}
# {'poem': ',\n'}
# {'poem': 'A'}
# {'poem': ' reminder'}
# {'poem': ' to'}
# {'poem': ' cherish'}
# {'poem': ' this'}
# {'poem': ' world'}
# {'poem': "'s"}
# {'poem': ' harmony'}
# {'poem': '.\n\n'}
# {'poem': 'So'}
# {'poem': ','}
# {'poem': ' let'}
# {'poem': ' us'}
# {'poem': ' honor'}
# {'poem': ' this'}
# {'poem': ' creature'}
# {'poem': ' so'}
# {'poem': ' grand'}
# {'poem': ',\n'}
# {'poem': 'With'}
# {'poem': ' reverence'}
# {'poem': ' and'}
# {'poem': ' awe'}
# {'poem': ','}
# {'poem': ' let'}
# {'poem': ' us'}
# {'poem': ' understand'}
# {'poem': ',\n'}
# {'poem': 'That'}
# {'poem': ' in'}
# {'poem': ' the'}
# {'poem': ' realm'}
# {'poem': ' of'}
# {'poem': ' nature'}
# {'poem': ','}
# {'poem': ' bears'}
# {'poem': ' are'}
# {'poem': ' rare'}
# {'poem': ',\n'}
# {'poem': 'A'}
# {'poem': ' symbol'}
# {'poem': ' of'}
# {'poem': ' wilderness'}
# {'poem': ','}
# {'poem': ' beyond'}
# {'poem': ' compare'}
# {'poem': '.'}
# {'poem': ''}

# %%
result = {}
for s in parallel_chain.stream({"topic": "bears"}):
    for k,v in s.items():
        if k not in result:
            result[k] = ""
        result[k] += v
    print(result)
# Out:
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# {'poem': ''}
# {'poem': 'In'}
# {'poem': 'In the'}
# {'poem': 'In the wild'}
# {'poem': 'In the wild,'}
# {'poem': 'In the wild, where'}
# {'poem': 'In the wild, where nature'}
# {'poem': "In the wild, where nature's"}
# {'poem': "In the wild, where nature's beauty"}
# {'poem': "In the wild, where nature's beauty thr"}
# {'poem': "In the wild, where nature's beauty thrives"}
# {'poem': "In the wild, where nature's beauty thrives,\n"}
# {'poem': "In the wild, where nature's beauty thrives,\nRes"}
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# {'poem': "In the wild, where nature's beauty thrives,\nResides"}
# {'poem': "In the wild, where nature's beauty thrives,\nResides a"}
# {'poem': "In the wild, where nature's beauty thrives,\nResides a creature"}
# {'poem': "In the wild, where nature's beauty thrives,\nResides a creature with"}
# {'poem': "In the wild, where nature's beauty thrives,\nResides a creature with gentle"}
# {'poem': "In the wild, where nature's beauty thrives,\nResides a creature with gentle lives"}
# {'poem': "In the wild, where nature's beauty thrives,\nResides a creature with gentle lives", 'joke': ''}
# {'poem': "In the wild, where nature's beauty thrives,\nResides a creature with gentle lives,\n", 'joke': ''}
# {'poem': "In the wild, where nature's beauty thrives,\nResides a creature with gentle lives,\nA", 'joke': ''}
# {'poem': "In the wild, where nature's beauty thrives,\nResides a creature with gentle lives,\nA majestic", 'joke': ''}
# {'poem': "In the wild, where nature's beauty thrives,\nResides a creature with gentle lives,\nA majestic", 'joke': 'Why'}
# {'poem': "In the wild, where nature's beauty thrives,\nResides a creature with gentle lives,\nA majestic beast", 'joke': 'Why'}
# {'poem': "In the wild, where nature's beauty thrives,\nResides a creature with gentle lives,\nA majestic beast,", 'joke': 'Why'}
# {'poem': "In the wild, where nature's beauty thrives,\nResides a creature with gentle lives,\nA majestic beast,", 'joke': 'Why don'}
# {'poem': "In the wild, where nature's beauty thrives,\nResides a creature with gentle lives,\nA majestic beast,", 'joke': "Why don't"}
# {'poem': "In the wild, where nature's beauty thrives,\nResides a creature with gentle lives,\nA majestic beast, both", 'joke': "Why don't"}
# {'poem': "In the wild, where nature's beauty thrives,\nResides a creature with gentle lives,\nA majestic beast, both strong", 'joke': "Why don't"}
# {'poem': "In the wild, where nature's beauty thrives,\nResides a creature with gentle lives,\nA majestic beast, both strong and", 'joke': "Why don't"}
# {'poem': "In the wild, where nature's beauty thrives,\nResides a creature with gentle lives,\nA majestic beast, both strong and wise", 'joke': "Why don't"}
# {'poem': "In the wild, where nature's beauty thrives,\nResides a creature with gentle lives,\nA majestic beast, both strong and wise", 'joke': "Why don't bears"}
# {'poem': "In the wild, where nature's beauty thrives,\nResides a creature with gentle lives,\nA majestic beast, both strong and wise", 'joke': "Why don't bears wear"}
# {'poem': "In the wild, where nature's beauty thrives,\nResides a creature with gentle lives,\nA majestic beast, both strong and wise", 'joke': "Why don't bears wear shoes"}
# {'poem': "In the wild, where nature's beauty thrives,\nResides a creature with gentle lives,\nA majestic beast, both strong and wise,\n", 'joke': "Why don't bears wear shoes"}
# {'poem': "In the wild, where nature's beauty thrives,\nResides a creature with gentle lives,\nA majestic beast, both strong and wise,\nLet", 'joke': "Why don't bears wear shoes"}
# {'poem': "In the wild, where nature's beauty thrives,\nResides a creature with gentle lives,\nA majestic beast, both strong and wise,\nLet me", 'joke': "Why don't bears wear shoes"}
# {'poem': "In the wild, where nature's beauty thrives,\nResides a creature with gentle lives,\nA majestic beast, both strong and wise,\nLet me", 'joke': "Why don't bears wear shoes?\n\n"}
# {'poem': "In the wild, where nature's beauty thrives,\nResides a creature with gentle lives,\nA majestic beast, both strong and wise,\nLet me", 'joke': "Why don't bears wear shoes?\n\nBecause"}
# {'poem': "In the wild, where nature's beauty thrives,\nResides a creature with gentle lives,\nA majestic beast, both strong and wise,\nLet me", 'joke': "Why don't bears wear shoes?\n\nBecause they"}
# {'poem': "In the wild, where nature's beauty thrives,\nResides a creature with gentle lives,\nA majestic beast, both strong and wise,\nLet me", 'joke': "Why don't bears wear shoes?\n\nBecause they have"}
# {'poem': "In the wild, where nature's beauty thrives,\nResides a creature with gentle lives,\nA majestic beast, both strong and wise,\nLet me", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear"}
# {'poem': "In the wild, where nature's beauty thrives,\nResides a creature with gentle lives,\nA majestic beast, both strong and wise,\nLet me", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet"}
# {'poem': "In the wild, where nature's beauty thrives,\nResides a creature with gentle lives,\nA majestic beast, both strong and wise,\nLet me", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In the wild, where nature's beauty thrives,\nResides a creature with gentle lives,\nA majestic beast, both strong and wise,\nLet me", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In the wild, where nature's beauty thrives,\nResides a creature with gentle lives,\nA majestic beast, both strong and wise,\nLet me weave", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In the wild, where nature's beauty thrives,\nResides a creature with gentle lives,\nA majestic beast, both strong and wise,\nLet me weave a", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In the wild, where nature's beauty thrives,\nResides a creature with gentle lives,\nA majestic beast, both strong and wise,\nLet me weave a tale", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In the wild, where nature's beauty thrives,\nResides a creature with gentle lives,\nA majestic beast, both strong and wise,\nLet me weave a tale of", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In the wild, where nature's beauty thrives,\nResides a creature with gentle lives,\nA majestic beast, both strong and wise,\nLet me weave a tale of bears", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In the wild, where nature's beauty thrives,\nResides a creature with gentle lives,\nA majestic beast, both strong and wise,\nLet me weave a tale of bears,", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In the wild, where nature's beauty thrives,\nResides a creature with gentle lives,\nA majestic beast, both strong and wise,\nLet me weave a tale of bears, arise", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In the wild, where nature's beauty thrives,\nResides a creature with gentle lives,\nA majestic beast, both strong and wise,\nLet me weave a tale of bears, arise!\n\n", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In the wild, where nature's beauty thrives,\nResides a creature with gentle lives,\nA majestic beast, both strong and wise,\nLet me weave a tale of bears, arise!\n\nThrough", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In the wild, where nature's beauty thrives,\nResides a creature with gentle lives,\nA majestic beast, both strong and wise,\nLet me weave a tale of bears, arise!\n\nThrough towering", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In the wild, where nature's beauty thrives,\nResides a creature with gentle lives,\nA majestic beast, both strong and wise,\nLet me weave a tale of bears, arise!\n\nThrough towering forests", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In the wild, where nature's beauty thrives,\nResides a creature with gentle lives,\nA majestic beast, both strong and wise,\nLet me weave a tale of bears, arise!\n\nThrough towering forests,", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In the wild, where nature's beauty thrives,\nResides a creature with gentle lives,\nA majestic beast, both strong and wise,\nLet me weave a tale of bears, arise!\n\nThrough towering forests, they", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In the wild, where nature's beauty thrives,\nResides a creature with gentle lives,\nA majestic beast, both strong and wise,\nLet me weave a tale of bears, arise!\n\nThrough towering forests, they roam", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In the wild, where nature's beauty thrives,\nResides a creature with gentle lives,\nA majestic beast, both strong and wise,\nLet me weave a tale of bears, arise!\n\nThrough towering forests, they roam with", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In the wild, where nature's beauty thrives,\nResides a creature with gentle lives,\nA majestic beast, both strong and wise,\nLet me weave a tale of bears, arise!\n\nThrough towering forests, they roam with grace", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In the wild, where nature's beauty thrives,\nResides a creature with gentle lives,\nA majestic beast, both strong and wise,\nLet me weave a tale of bears, arise!\n\nThrough towering forests, they roam with grace,\n", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In the wild, where nature's beauty thrives,\nResides a creature with gentle lives,\nA majestic beast, both strong and wise,\nLet me weave a tale of bears, arise!\n\nThrough towering forests, they roam with grace,\nP", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In the wild, where nature's beauty thrives,\nResides a creature with gentle lives,\nA majestic beast, both strong and wise,\nLet me weave a tale of bears, arise!\n\nThrough towering forests, they roam with grace,\nPaws", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In the wild, where nature's beauty thrives,\nResides a creature with gentle lives,\nA majestic beast, both strong and wise,\nLet me weave a tale of bears, arise!\n\nThrough towering forests, they roam with grace,\nPaws t", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In the wild, where nature's beauty thrives,\nResides a creature with gentle lives,\nA majestic beast, both strong and wise,\nLet me weave a tale of bears, arise!\n\nThrough towering forests, they roam with grace,\nPaws treading", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In the wild, where nature's beauty thrives,\nResides a creature with gentle lives,\nA majestic beast, both strong and wise,\nLet me weave a tale of bears, arise!\n\nThrough towering forests, they roam with grace,\nPaws treading softly", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In the wild, where nature's beauty thrives,\nResides a creature with gentle lives,\nA majestic beast, both strong and wise,\nLet me weave a tale of bears, arise!\n\nThrough towering forests, they roam with grace,\nPaws treading softly,", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In the wild, where nature's beauty thrives,\nResides a creature with gentle lives,\nA majestic beast, both strong and wise,\nLet me weave a tale of bears, arise!\n\nThrough towering forests, they roam with grace,\nPaws treading softly, leaving", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In the wild, where nature's beauty thrives,\nResides a creature with gentle lives,\nA majestic beast, both strong and wise,\nLet me weave a tale of bears, arise!\n\nThrough towering forests, they roam with grace,\nPaws treading softly, leaving no", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In the wild, where nature's beauty thrives,\nResides a creature with gentle lives,\nA majestic beast, both strong and wise,\nLet me weave a tale of bears, arise!\n\nThrough towering forests, they roam with grace,\nPaws treading softly, leaving no trace", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In the wild, where nature's beauty thrives,\nResides a creature with gentle lives,\nA majestic beast, both strong and wise,\nLet me weave a tale of bears, arise!\n\nThrough towering forests, they roam with grace,\nPaws treading softly, leaving no trace,\n", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In the wild, where nature's beauty thrives,\nResides a creature with gentle lives,\nA majestic beast, both strong and wise,\nLet me weave a tale of bears, arise!\n\nThrough towering forests, they roam with grace,\nPaws treading softly, leaving no trace,\nTheir", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In the wild, where nature's beauty thrives,\nResides a creature with gentle lives,\nA majestic beast, both strong and wise,\nLet me weave a tale of bears, arise!\n\nThrough towering forests, they roam with grace,\nPaws treading softly, leaving no trace,\nTheir fur", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In the wild, where nature's beauty thrives,\nResides a creature with gentle lives,\nA majestic beast, both strong and wise,\nLet me weave a tale of bears, arise!\n\nThrough towering forests, they roam with grace,\nPaws treading softly, leaving no trace,\nTheir fur,", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In the wild, where nature's beauty thrives,\nResides a creature with gentle lives,\nA majestic beast, both strong and wise,\nLet me weave a tale of bears, arise!\n\nThrough towering forests, they roam with grace,\nPaws treading softly, leaving no trace,\nTheir fur, a", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In the wild, where nature's beauty thrives,\nResides a creature with gentle lives,\nA majestic beast, both strong and wise,\nLet me weave a tale of bears, arise!\n\nThrough towering forests, they roam with grace,\nPaws treading softly, leaving no trace,\nTheir fur, a tape", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In the wild, where nature's beauty thrives,\nResides a creature with gentle lives,\nA majestic beast, both strong and wise,\nLet me weave a tale of bears, arise!\n\nThrough towering forests, they roam with grace,\nPaws treading softly, leaving no trace,\nTheir fur, a tapestry", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In the wild, where nature's beauty thrives,\nResides a creature with gentle lives,\nA majestic beast, both strong and wise,\nLet me weave a tale of bears, arise!\n\nThrough towering forests, they roam with grace,\nPaws treading softly, leaving no trace,\nTheir fur, a tapestry of", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In the wild, where nature's beauty thrives,\nResides a creature with gentle lives,\nA majestic beast, both strong and wise,\nLet me weave a tale of bears, arise!\n\nThrough towering forests, they roam with grace,\nPaws treading softly, leaving no trace,\nTheir fur, a tapestry of earthly", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In the wild, where nature's beauty thrives,\nResides a creature with gentle lives,\nA majestic beast, both strong and wise,\nLet me weave a tale of bears, arise!\n\nThrough towering forests, they roam with grace,\nPaws treading softly, leaving no trace,\nTheir fur, a tapestry of earthly hues", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In the wild, where nature's beauty thrives,\nResides a creature with gentle lives,\nA majestic beast, both strong and wise,\nLet me weave a tale of bears, arise!\n\nThrough towering forests, they roam with grace,\nPaws treading softly, leaving no trace,\nTheir fur, a tapestry of earthly hues,\n", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In the wild, where nature's beauty thrives,\nResides a creature with gentle lives,\nA majestic beast, both strong and wise,\nLet me weave a tale of bears, arise!\n\nThrough towering forests, they roam with grace,\nPaws treading softly, leaving no trace,\nTheir fur, a tapestry of earthly hues,\nA", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In the wild, where nature's beauty thrives,\nResides a creature with gentle lives,\nA majestic beast, both strong and wise,\nLet me weave a tale of bears, arise!\n\nThrough towering forests, they roam with grace,\nPaws treading softly, leaving no trace,\nTheir fur, a tapestry of earthly hues,\nA testament", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In the wild, where nature's beauty thrives,\nResides a creature with gentle lives,\nA majestic beast, both strong and wise,\nLet me weave a tale of bears, arise!\n\nThrough towering forests, they roam with grace,\nPaws treading softly, leaving no trace,\nTheir fur, a tapestry of earthly hues,\nA testament to", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In the wild, where nature's beauty thrives,\nResides a creature with gentle lives,\nA majestic beast, both strong and wise,\nLet me weave a tale of bears, arise!\n\nThrough towering forests, they roam with grace,\nPaws treading softly, leaving no trace,\nTheir fur, a tapestry of earthly hues,\nA testament to nature", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In the wild, where nature's beauty thrives,\nResides a creature with gentle lives,\nA majestic beast, both strong and wise,\nLet me weave a tale of bears, arise!\n\nThrough towering forests, they roam with grace,\nPaws treading softly, leaving no trace,\nTheir fur, a tapestry of earthly hues,\nA testament to nature's", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In the wild, where nature's beauty thrives,\nResides a creature with gentle lives,\nA majestic beast, both strong and wise,\nLet me weave a tale of bears, arise!\n\nThrough towering forests, they roam with grace,\nPaws treading softly, leaving no trace,\nTheir fur, a tapestry of earthly hues,\nA testament to nature's w", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In the wild, where nature's beauty thrives,\nResides a creature with gentle lives,\nA majestic beast, both strong and wise,\nLet me weave a tale of bears, arise!\n\nThrough towering forests, they roam with grace,\nPaws treading softly, leaving no trace,\nTheir fur, a tapestry of earthly hues,\nA testament to nature's wondrous", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In the wild, where nature's beauty thrives,\nResides a creature with gentle lives,\nA majestic beast, both strong and wise,\nLet me weave a tale of bears, arise!\n\nThrough towering forests, they roam with grace,\nPaws treading softly, leaving no trace,\nTheir fur, a tapestry of earthly hues,\nA testament to nature's wondrous muse", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In the wild, where nature's beauty thrives,\nResides a creature with gentle lives,\nA majestic beast, both strong and wise,\nLet me weave a tale of bears, arise!\n\nThrough towering forests, they roam with grace,\nPaws treading softly, leaving no trace,\nTheir fur, a tapestry of earthly hues,\nA testament to nature's wondrous muse.\n\n", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In the wild, where nature's beauty thrives,\nResides a creature with gentle lives,\nA majestic beast, both strong and wise,\nLet me weave a tale of bears, arise!\n\nThrough towering forests, they roam with grace,\nPaws treading softly, leaving no trace,\nTheir fur, a tapestry of earthly hues,\nA testament to nature's wondrous muse.\n\nThe", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In the wild, where nature's beauty thrives,\nResides a creature with gentle lives,\nA majestic beast, both strong and wise,\nLet me weave a tale of bears, arise!\n\nThrough towering forests, they roam with grace,\nPaws treading softly, leaving no trace,\nTheir fur, a tapestry of earthly hues,\nA testament to nature's wondrous muse.\n\nThe mighty", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In the wild, where nature's beauty thrives,\nResides a creature with gentle lives,\nA majestic beast, both strong and wise,\nLet me weave a tale of bears, arise!\n\nThrough towering forests, they roam with grace,\nPaws treading softly, leaving no trace,\nTheir fur, a tapestry of earthly hues,\nA testament to nature's wondrous muse.\n\nThe mighty gr", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In the wild, where nature's beauty thrives,\nResides a creature with gentle lives,\nA majestic beast, both strong and wise,\nLet me weave a tale of bears, arise!\n\nThrough towering forests, they roam with grace,\nPaws treading softly, leaving no trace,\nTheir fur, a tapestry of earthly hues,\nA testament to nature's wondrous muse.\n\nThe mighty grizzly", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In the wild, where nature's beauty thrives,\nResides a creature with gentle lives,\nA majestic beast, both strong and wise,\nLet me weave a tale of bears, arise!\n\nThrough towering forests, they roam with grace,\nPaws treading softly, leaving no trace,\nTheir fur, a tapestry of earthly hues,\nA testament to nature's wondrous muse.\n\nThe mighty grizzly,", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In the wild, where nature's beauty thrives,\nResides a creature with gentle lives,\nA majestic beast, both strong and wise,\nLet me weave a tale of bears, arise!\n\nThrough towering forests, they roam with grace,\nPaws treading softly, leaving no trace,\nTheir fur, a tapestry of earthly hues,\nA testament to nature's wondrous muse.\n\nThe mighty grizzly, a", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In the wild, where nature's beauty thrives,\nResides a creature with gentle lives,\nA majestic beast, both strong and wise,\nLet me weave a tale of bears, arise!\n\nThrough towering forests, they roam with grace,\nPaws treading softly, leaving no trace,\nTheir fur, a tapestry of earthly hues,\nA testament to nature's wondrous muse.\n\nThe mighty grizzly, a towering", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In the wild, where nature's beauty thrives,\nResides a creature with gentle lives,\nA majestic beast, both strong and wise,\nLet me weave a tale of bears, arise!\n\nThrough towering forests, they roam with grace,\nPaws treading softly, leaving no trace,\nTheir fur, a tapestry of earthly hues,\nA testament to nature's wondrous muse.\n\nThe mighty grizzly, a towering sight", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In the wild, where nature's beauty thrives,\nResides a creature with gentle lives,\nA majestic beast, both strong and wise,\nLet me weave a tale of bears, arise!\n\nThrough towering forests, they roam with grace,\nPaws treading softly, leaving no trace,\nTheir fur, a tapestry of earthly hues,\nA testament to nature's wondrous muse.\n\nThe mighty grizzly, a towering sight,\n", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In the wild, where nature's beauty thrives,\nResides a creature with gentle lives,\nA majestic beast, both strong and wise,\nLet me weave a tale of bears, arise!\n\nThrough towering forests, they roam with grace,\nPaws treading softly, leaving no trace,\nTheir fur, a tapestry of earthly hues,\nA testament to nature's wondrous muse.\n\nThe mighty grizzly, a towering sight,\nWith", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In the wild, where nature's beauty thrives,\nResides a creature with gentle lives,\nA majestic beast, both strong and wise,\nLet me weave a tale of bears, arise!\n\nThrough towering forests, they roam with grace,\nPaws treading softly, leaving no trace,\nTheir fur, a tapestry of earthly hues,\nA testament to nature's wondrous muse.\n\nThe mighty grizzly, a towering sight,\nWith strength", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In the wild, where nature's beauty thrives,\nResides a creature with gentle lives,\nA majestic beast, both strong and wise,\nLet me weave a tale of bears, arise!\n\nThrough towering forests, they roam with grace,\nPaws treading softly, leaving no trace,\nTheir fur, a tapestry of earthly hues,\nA testament to nature's wondrous muse.\n\nThe mighty grizzly, a towering sight,\nWith strength unmatched", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In the wild, where nature's beauty thrives,\nResides a creature with gentle lives,\nA majestic beast, both strong and wise,\nLet me weave a tale of bears, arise!\n\nThrough towering forests, they roam with grace,\nPaws treading softly, leaving no trace,\nTheir fur, a tapestry of earthly hues,\nA testament to nature's wondrous muse.\n\nThe mighty grizzly, a towering sight,\nWith strength unmatched,", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In the wild, where nature's beauty thrives,\nResides a creature with gentle lives,\nA majestic beast, both strong and wise,\nLet me weave a tale of bears, arise!\n\nThrough towering forests, they roam with grace,\nPaws treading softly, leaving no trace,\nTheir fur, a tapestry of earthly hues,\nA testament to nature's wondrous muse.\n\nThe mighty grizzly, a towering sight,\nWith strength unmatched, they", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In the wild, where nature's beauty thrives,\nResides a creature with gentle lives,\nA majestic beast, both strong and wise,\nLet me weave a tale of bears, arise!\n\nThrough towering forests, they roam with grace,\nPaws treading softly, leaving no trace,\nTheir fur, a tapestry of earthly hues,\nA testament to nature's wondrous muse.\n\nThe mighty grizzly, a towering sight,\nWith strength unmatched, they rule", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In the wild, where nature's beauty thrives,\nResides a creature with gentle lives,\nA majestic beast, both strong and wise,\nLet me weave a tale of bears, arise!\n\nThrough towering forests, they roam with grace,\nPaws treading softly, leaving no trace,\nTheir fur, a tapestry of earthly hues,\nA testament to nature's wondrous muse.\n\nThe mighty grizzly, a towering sight,\nWith strength unmatched, they rule the", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In the wild, where nature's beauty thrives,\nResides a creature with gentle lives,\nA majestic beast, both strong and wise,\nLet me weave a tale of bears, arise!\n\nThrough towering forests, they roam with grace,\nPaws treading softly, leaving no trace,\nTheir fur, a tapestry of earthly hues,\nA testament to nature's wondrous muse.\n\nThe mighty grizzly, a towering sight,\nWith strength unmatched, they rule the night", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In the wild, where nature's beauty thrives,\nResides a creature with gentle lives,\nA majestic beast, both strong and wise,\nLet me weave a tale of bears, arise!\n\nThrough towering forests, they roam with grace,\nPaws treading softly, leaving no trace,\nTheir fur, a tapestry of earthly hues,\nA testament to nature's wondrous muse.\n\nThe mighty grizzly, a towering sight,\nWith strength unmatched, they rule the night,\n", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In the wild, where nature's beauty thrives,\nResides a creature with gentle lives,\nA majestic beast, both strong and wise,\nLet me weave a tale of bears, arise!\n\nThrough towering forests, they roam with grace,\nPaws treading softly, leaving no trace,\nTheir fur, a tapestry of earthly hues,\nA testament to nature's wondrous muse.\n\nThe mighty grizzly, a towering sight,\nWith strength unmatched, they rule the night,\nTheir", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In the wild, where nature's beauty thrives,\nResides a creature with gentle lives,\nA majestic beast, both strong and wise,\nLet me weave a tale of bears, arise!\n\nThrough towering forests, they roam with grace,\nPaws treading softly, leaving no trace,\nTheir fur, a tapestry of earthly hues,\nA testament to nature's wondrous muse.\n\nThe mighty grizzly, a towering sight,\nWith strength unmatched, they rule the night,\nTheir presence", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In the wild, where nature's beauty thrives,\nResides a creature with gentle lives,\nA majestic beast, both strong and wise,\nLet me weave a tale of bears, arise!\n\nThrough towering forests, they roam with grace,\nPaws treading softly, leaving no trace,\nTheir fur, a tapestry of earthly hues,\nA testament to nature's wondrous muse.\n\nThe mighty grizzly, a towering sight,\nWith strength unmatched, they rule the night,\nTheir presence commands", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In the wild, where nature's beauty thrives,\nResides a creature with gentle lives,\nA majestic beast, both strong and wise,\nLet me weave a tale of bears, arise!\n\nThrough towering forests, they roam with grace,\nPaws treading softly, leaving no trace,\nTheir fur, a tapestry of earthly hues,\nA testament to nature's wondrous muse.\n\nThe mighty grizzly, a towering sight,\nWith strength unmatched, they rule the night,\nTheir presence commands respect", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In the wild, where nature's beauty thrives,\nResides a creature with gentle lives,\nA majestic beast, both strong and wise,\nLet me weave a tale of bears, arise!\n\nThrough towering forests, they roam with grace,\nPaws treading softly, leaving no trace,\nTheir fur, a tapestry of earthly hues,\nA testament to nature's wondrous muse.\n\nThe mighty grizzly, a towering sight,\nWith strength unmatched, they rule the night,\nTheir presence commands respect,", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In the wild, where nature's beauty thrives,\nResides a creature with gentle lives,\nA majestic beast, both strong and wise,\nLet me weave a tale of bears, arise!\n\nThrough towering forests, they roam with grace,\nPaws treading softly, leaving no trace,\nTheir fur, a tapestry of earthly hues,\nA testament to nature's wondrous muse.\n\nThe mighty grizzly, a towering sight,\nWith strength unmatched, they rule the night,\nTheir presence commands respect, with", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In the wild, where nature's beauty thrives,\nResides a creature with gentle lives,\nA majestic beast, both strong and wise,\nLet me weave a tale of bears, arise!\n\nThrough towering forests, they roam with grace,\nPaws treading softly, leaving no trace,\nTheir fur, a tapestry of earthly hues,\nA testament to nature's wondrous muse.\n\nThe mighty grizzly, a towering sight,\nWith strength unmatched, they rule the night,\nTheir presence commands respect, with no", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In the wild, where nature's beauty thrives,\nResides a creature with gentle lives,\nA majestic beast, both strong and wise,\nLet me weave a tale of bears, arise!\n\nThrough towering forests, they roam with grace,\nPaws treading softly, leaving no trace,\nTheir fur, a tapestry of earthly hues,\nA testament to nature's wondrous muse.\n\nThe mighty grizzly, a towering sight,\nWith strength unmatched, they rule the night,\nTheir presence commands respect, with no compare", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In the wild, where nature's beauty thrives,\nResides a creature with gentle lives,\nA majestic beast, both strong and wise,\nLet me weave a tale of bears, arise!\n\nThrough towering forests, they roam with grace,\nPaws treading softly, leaving no trace,\nTheir fur, a tapestry of earthly hues,\nA testament to nature's wondrous muse.\n\nThe mighty grizzly, a towering sight,\nWith strength unmatched, they rule the night,\nTheir presence commands respect, with no compare,\n", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In the wild, where nature's beauty thrives,\nResides a creature with gentle lives,\nA majestic beast, both strong and wise,\nLet me weave a tale of bears, arise!\n\nThrough towering forests, they roam with grace,\nPaws treading softly, leaving no trace,\nTheir fur, a tapestry of earthly hues,\nA testament to nature's wondrous muse.\n\nThe mighty grizzly, a towering sight,\nWith strength unmatched, they rule the night,\nTheir presence commands respect, with no compare,\nA", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In the wild, where nature's beauty thrives,\nResides a creature with gentle lives,\nA majestic beast, both strong and wise,\nLet me weave a tale of bears, arise!\n\nThrough towering forests, they roam with grace,\nPaws treading softly, leaving no trace,\nTheir fur, a tapestry of earthly hues,\nA testament to nature's wondrous muse.\n\nThe mighty grizzly, a towering sight,\nWith strength unmatched, they rule the night,\nTheir presence commands respect, with no compare,\nA symbol", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In the wild, where nature's beauty thrives,\nResides a creature with gentle lives,\nA majestic beast, both strong and wise,\nLet me weave a tale of bears, arise!\n\nThrough towering forests, they roam with grace,\nPaws treading softly, leaving no trace,\nTheir fur, a tapestry of earthly hues,\nA testament to nature's wondrous muse.\n\nThe mighty grizzly, a towering sight,\nWith strength unmatched, they rule the night,\nTheir presence commands respect, with no compare,\nA symbol of", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In the wild, where nature's beauty thrives,\nResides a creature with gentle lives,\nA majestic beast, both strong and wise,\nLet me weave a tale of bears, arise!\n\nThrough towering forests, they roam with grace,\nPaws treading softly, leaving no trace,\nTheir fur, a tapestry of earthly hues,\nA testament to nature's wondrous muse.\n\nThe mighty grizzly, a towering sight,\nWith strength unmatched, they rule the night,\nTheir presence commands respect, with no compare,\nA symbol of nature", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In the wild, where nature's beauty thrives,\nResides a creature with gentle lives,\nA majestic beast, both strong and wise,\nLet me weave a tale of bears, arise!\n\nThrough towering forests, they roam with grace,\nPaws treading softly, leaving no trace,\nTheir fur, a tapestry of earthly hues,\nA testament to nature's wondrous muse.\n\nThe mighty grizzly, a towering sight,\nWith strength unmatched, they rule the night,\nTheir presence commands respect, with no compare,\nA symbol of nature's", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In the wild, where nature's beauty thrives,\nResides a creature with gentle lives,\nA majestic beast, both strong and wise,\nLet me weave a tale of bears, arise!\n\nThrough towering forests, they roam with grace,\nPaws treading softly, leaving no trace,\nTheir fur, a tapestry of earthly hues,\nA testament to nature's wondrous muse.\n\nThe mighty grizzly, a towering sight,\nWith strength unmatched, they rule the night,\nTheir presence commands respect, with no compare,\nA symbol of nature's unt", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In the wild, where nature's beauty thrives,\nResides a creature with gentle lives,\nA majestic beast, both strong and wise,\nLet me weave a tale of bears, arise!\n\nThrough towering forests, they roam with grace,\nPaws treading softly, leaving no trace,\nTheir fur, a tapestry of earthly hues,\nA testament to nature's wondrous muse.\n\nThe mighty grizzly, a towering sight,\nWith strength unmatched, they rule the night,\nTheir presence commands respect, with no compare,\nA symbol of nature's untamed", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In the wild, where nature's beauty thrives,\nResides a creature with gentle lives,\nA majestic beast, both strong and wise,\nLet me weave a tale of bears, arise!\n\nThrough towering forests, they roam with grace,\nPaws treading softly, leaving no trace,\nTheir fur, a tapestry of earthly hues,\nA testament to nature's wondrous muse.\n\nThe mighty grizzly, a towering sight,\nWith strength unmatched, they rule the night,\nTheir presence commands respect, with no compare,\nA symbol of nature's untamed flair", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In the wild, where nature's beauty thrives,\nResides a creature with gentle lives,\nA majestic beast, both strong and wise,\nLet me weave a tale of bears, arise!\n\nThrough towering forests, they roam with grace,\nPaws treading softly, leaving no trace,\nTheir fur, a tapestry of earthly hues,\nA testament to nature's wondrous muse.\n\nThe mighty grizzly, a towering sight,\nWith strength unmatched, they rule the night,\nTheir presence commands respect, with no compare,\nA symbol of nature's untamed flair.\n\n", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In the wild, where nature's beauty thrives,\nResides a creature with gentle lives,\nA majestic beast, both strong and wise,\nLet me weave a tale of bears, arise!\n\nThrough towering forests, they roam with grace,\nPaws treading softly, leaving no trace,\nTheir fur, a tapestry of earthly hues,\nA testament to nature's wondrous muse.\n\nThe mighty grizzly, a towering sight,\nWith strength unmatched, they rule the night,\nTheir presence commands respect, with no compare,\nA symbol of nature's untamed flair.\n\nIn", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In the wild, where nature's beauty thrives,\nResides a creature with gentle lives,\nA majestic beast, both strong and wise,\nLet me weave a tale of bears, arise!\n\nThrough towering forests, they roam with grace,\nPaws treading softly, leaving no trace,\nTheir fur, a tapestry of earthly hues,\nA testament to nature's wondrous muse.\n\nThe mighty grizzly, a towering sight,\nWith strength unmatched, they rule the night,\nTheir presence commands respect, with no compare,\nA symbol of nature's untamed flair.\n\nIn caves", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In the wild, where nature's beauty thrives,\nResides a creature with gentle lives,\nA majestic beast, both strong and wise,\nLet me weave a tale of bears, arise!\n\nThrough towering forests, they roam with grace,\nPaws treading softly, leaving no trace,\nTheir fur, a tapestry of earthly hues,\nA testament to nature's wondrous muse.\n\nThe mighty grizzly, a towering sight,\nWith strength unmatched, they rule the night,\nTheir presence commands respect, with no compare,\nA symbol of nature's untamed flair.\n\nIn caves,", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In the wild, where nature's beauty thrives,\nResides a creature with gentle lives,\nA majestic beast, both strong and wise,\nLet me weave a tale of bears, arise!\n\nThrough towering forests, they roam with grace,\nPaws treading softly, leaving no trace,\nTheir fur, a tapestry of earthly hues,\nA testament to nature's wondrous muse.\n\nThe mighty grizzly, a towering sight,\nWith strength unmatched, they rule the night,\nTheir presence commands respect, with no compare,\nA symbol of nature's untamed flair.\n\nIn caves, they", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In the wild, where nature's beauty thrives,\nResides a creature with gentle lives,\nA majestic beast, both strong and wise,\nLet me weave a tale of bears, arise!\n\nThrough towering forests, they roam with grace,\nPaws treading softly, leaving no trace,\nTheir fur, a tapestry of earthly hues,\nA testament to nature's wondrous muse.\n\nThe mighty grizzly, a towering sight,\nWith strength unmatched, they rule the night,\nTheir presence commands respect, with no compare,\nA symbol of nature's untamed flair.\n\nIn caves, they h", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In the wild, where nature's beauty thrives,\nResides a creature with gentle lives,\nA majestic beast, both strong and wise,\nLet me weave a tale of bears, arise!\n\nThrough towering forests, they roam with grace,\nPaws treading softly, leaving no trace,\nTheir fur, a tapestry of earthly hues,\nA testament to nature's wondrous muse.\n\nThe mighty grizzly, a towering sight,\nWith strength unmatched, they rule the night,\nTheir presence commands respect, with no compare,\nA symbol of nature's untamed flair.\n\nIn caves, they hibernate", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In the wild, where nature's beauty thrives,\nResides a creature with gentle lives,\nA majestic beast, both strong and wise,\nLet me weave a tale of bears, arise!\n\nThrough towering forests, they roam with grace,\nPaws treading softly, leaving no trace,\nTheir fur, a tapestry of earthly hues,\nA testament to nature's wondrous muse.\n\nThe mighty grizzly, a towering sight,\nWith strength unmatched, they rule the night,\nTheir presence commands respect, with no compare,\nA symbol of nature's untamed flair.\n\nIn caves, they hibernate,", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In the wild, where nature's beauty thrives,\nResides a creature with gentle lives,\nA majestic beast, both strong and wise,\nLet me weave a tale of bears, arise!\n\nThrough towering forests, they roam with grace,\nPaws treading softly, leaving no trace,\nTheir fur, a tapestry of earthly hues,\nA testament to nature's wondrous muse.\n\nThe mighty grizzly, a towering sight,\nWith strength unmatched, they rule the night,\nTheir presence commands respect, with no compare,\nA symbol of nature's untamed flair.\n\nIn caves, they hibernate, in", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In the wild, where nature's beauty thrives,\nResides a creature with gentle lives,\nA majestic beast, both strong and wise,\nLet me weave a tale of bears, arise!\n\nThrough towering forests, they roam with grace,\nPaws treading softly, leaving no trace,\nTheir fur, a tapestry of earthly hues,\nA testament to nature's wondrous muse.\n\nThe mighty grizzly, a towering sight,\nWith strength unmatched, they rule the night,\nTheir presence commands respect, with no compare,\nA symbol of nature's untamed flair.\n\nIn caves, they hibernate, in sl", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In the wild, where nature's beauty thrives,\nResides a creature with gentle lives,\nA majestic beast, both strong and wise,\nLet me weave a tale of bears, arise!\n\nThrough towering forests, they roam with grace,\nPaws treading softly, leaving no trace,\nTheir fur, a tapestry of earthly hues,\nA testament to nature's wondrous muse.\n\nThe mighty grizzly, a towering sight,\nWith strength unmatched, they rule the night,\nTheir presence commands respect, with no compare,\nA symbol of nature's untamed flair.\n\nIn caves, they hibernate, in slumber", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In the wild, where nature's beauty thrives,\nResides a creature with gentle lives,\nA majestic beast, both strong and wise,\nLet me weave a tale of bears, arise!\n\nThrough towering forests, they roam with grace,\nPaws treading softly, leaving no trace,\nTheir fur, a tapestry of earthly hues,\nA testament to nature's wondrous muse.\n\nThe mighty grizzly, a towering sight,\nWith strength unmatched, they rule the night,\nTheir presence commands respect, with no compare,\nA symbol of nature's untamed flair.\n\nIn caves, they hibernate, in slumber deep", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In the wild, where nature's beauty thrives,\nResides a creature with gentle lives,\nA majestic beast, both strong and wise,\nLet me weave a tale of bears, arise!\n\nThrough towering forests, they roam with grace,\nPaws treading softly, leaving no trace,\nTheir fur, a tapestry of earthly hues,\nA testament to nature's wondrous muse.\n\nThe mighty grizzly, a towering sight,\nWith strength unmatched, they rule the night,\nTheir presence commands respect, with no compare,\nA symbol of nature's untamed flair.\n\nIn caves, they hibernate, in slumber deep,\n", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In the wild, where nature's beauty thrives,\nResides a creature with gentle lives,\nA majestic beast, both strong and wise,\nLet me weave a tale of bears, arise!\n\nThrough towering forests, they roam with grace,\nPaws treading softly, leaving no trace,\nTheir fur, a tapestry of earthly hues,\nA testament to nature's wondrous muse.\n\nThe mighty grizzly, a towering sight,\nWith strength unmatched, they rule the night,\nTheir presence commands respect, with no compare,\nA symbol of nature's untamed flair.\n\nIn caves, they hibernate, in slumber deep,\nA", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In the wild, where nature's beauty thrives,\nResides a creature with gentle lives,\nA majestic beast, both strong and wise,\nLet me weave a tale of bears, arise!\n\nThrough towering forests, they roam with grace,\nPaws treading softly, leaving no trace,\nTheir fur, a tapestry of earthly hues,\nA testament to nature's wondrous muse.\n\nThe mighty grizzly, a towering sight,\nWith strength unmatched, they rule the night,\nTheir presence commands respect, with no compare,\nA symbol of nature's untamed flair.\n\nIn caves, they hibernate, in slumber deep,\nA peaceful", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# ...
# {'poem': "In the wild, where nature's beauty thrives,\nResides a creature with gentle lives,\nA majestic beast, both strong and wise,\nLet me weave a tale of bears, arise!\n\nThrough towering forests, they roam with grace,\nPaws treading softly, leaving no trace,\nTheir fur, a tapestry of earthly hues,\nA testament to nature's wondrous muse.\n\nThe mighty grizzly, a towering sight,\nWith strength unmatched, they rule the night,\nTheir presence commands respect, with no compare,\nA symbol of nature's untamed flair.\n\nIn caves, they hibernate, in slumber deep,\nA peaceful rest, where dreams may seep,\nWrapped in warmth, they patiently wait,\nFor the gentle kiss of spring's embrace.\n\nThe polar bear, a marvel in the snow,\nWith ivory coat, they brave the cold,\nA master of icy realms, they roam,\nAdapting to the frozen depths they call home.\n\nBrown bears, dancing in rivers' flow,\nFishing for salmon with agile show,\nTheir playful spirit, a joy to behold,\nAs they frolic in waters, shimmering gold.\n\nBeneath the moonlit sky, they stand tall,\nSilhouettes against the starry sprawl,\nProtectors of the wild, guardians true,\nTheir presence a reminder, life's essence anew.\n\nSo let us celebrate these creatures rare,\nWith awe and reverence, let's declare,\nBears, the epitome of strength and might,\n", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In the wild, where nature's beauty thrives,\nResides a creature with gentle lives,\nA majestic beast, both strong and wise,\nLet me weave a tale of bears, arise!\n\nThrough towering forests, they roam with grace,\nPaws treading softly, leaving no trace,\nTheir fur, a tapestry of earthly hues,\nA testament to nature's wondrous muse.\n\nThe mighty grizzly, a towering sight,\nWith strength unmatched, they rule the night,\nTheir presence commands respect, with no compare,\nA symbol of nature's untamed flair.\n\nIn caves, they hibernate, in slumber deep,\nA peaceful rest, where dreams may seep,\nWrapped in warmth, they patiently wait,\nFor the gentle kiss of spring's embrace.\n\nThe polar bear, a marvel in the snow,\nWith ivory coat, they brave the cold,\nA master of icy realms, they roam,\nAdapting to the frozen depths they call home.\n\nBrown bears, dancing in rivers' flow,\nFishing for salmon with agile show,\nTheir playful spirit, a joy to behold,\nAs they frolic in waters, shimmering gold.\n\nBeneath the moonlit sky, they stand tall,\nSilhouettes against the starry sprawl,\nProtectors of the wild, guardians true,\nTheir presence a reminder, life's essence anew.\n\nSo let us celebrate these creatures rare,\nWith awe and reverence, let's declare,\nBears, the epitome of strength and might,\nA", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In the wild, where nature's beauty thrives,\nResides a creature with gentle lives,\nA majestic beast, both strong and wise,\nLet me weave a tale of bears, arise!\n\nThrough towering forests, they roam with grace,\nPaws treading softly, leaving no trace,\nTheir fur, a tapestry of earthly hues,\nA testament to nature's wondrous muse.\n\nThe mighty grizzly, a towering sight,\nWith strength unmatched, they rule the night,\nTheir presence commands respect, with no compare,\nA symbol of nature's untamed flair.\n\nIn caves, they hibernate, in slumber deep,\nA peaceful rest, where dreams may seep,\nWrapped in warmth, they patiently wait,\nFor the gentle kiss of spring's embrace.\n\nThe polar bear, a marvel in the snow,\nWith ivory coat, they brave the cold,\nA master of icy realms, they roam,\nAdapting to the frozen depths they call home.\n\nBrown bears, dancing in rivers' flow,\nFishing for salmon with agile show,\nTheir playful spirit, a joy to behold,\nAs they frolic in waters, shimmering gold.\n\nBeneath the moonlit sky, they stand tall,\nSilhouettes against the starry sprawl,\nProtectors of the wild, guardians true,\nTheir presence a reminder, life's essence anew.\n\nSo let us celebrate these creatures rare,\nWith awe and reverence, let's declare,\nBears, the epitome of strength and might,\nA testament", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In the wild, where nature's beauty thrives,\nResides a creature with gentle lives,\nA majestic beast, both strong and wise,\nLet me weave a tale of bears, arise!\n\nThrough towering forests, they roam with grace,\nPaws treading softly, leaving no trace,\nTheir fur, a tapestry of earthly hues,\nA testament to nature's wondrous muse.\n\nThe mighty grizzly, a towering sight,\nWith strength unmatched, they rule the night,\nTheir presence commands respect, with no compare,\nA symbol of nature's untamed flair.\n\nIn caves, they hibernate, in slumber deep,\nA peaceful rest, where dreams may seep,\nWrapped in warmth, they patiently wait,\nFor the gentle kiss of spring's embrace.\n\nThe polar bear, a marvel in the snow,\nWith ivory coat, they brave the cold,\nA master of icy realms, they roam,\nAdapting to the frozen depths they call home.\n\nBrown bears, dancing in rivers' flow,\nFishing for salmon with agile show,\nTheir playful spirit, a joy to behold,\nAs they frolic in waters, shimmering gold.\n\nBeneath the moonlit sky, they stand tall,\nSilhouettes against the starry sprawl,\nProtectors of the wild, guardians true,\nTheir presence a reminder, life's essence anew.\n\nSo let us celebrate these creatures rare,\nWith awe and reverence, let's declare,\nBears, the epitome of strength and might,\nA testament to", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In the wild, where nature's beauty thrives,\nResides a creature with gentle lives,\nA majestic beast, both strong and wise,\nLet me weave a tale of bears, arise!\n\nThrough towering forests, they roam with grace,\nPaws treading softly, leaving no trace,\nTheir fur, a tapestry of earthly hues,\nA testament to nature's wondrous muse.\n\nThe mighty grizzly, a towering sight,\nWith strength unmatched, they rule the night,\nTheir presence commands respect, with no compare,\nA symbol of nature's untamed flair.\n\nIn caves, they hibernate, in slumber deep,\nA peaceful rest, where dreams may seep,\nWrapped in warmth, they patiently wait,\nFor the gentle kiss of spring's embrace.\n\nThe polar bear, a marvel in the snow,\nWith ivory coat, they brave the cold,\nA master of icy realms, they roam,\nAdapting to the frozen depths they call home.\n\nBrown bears, dancing in rivers' flow,\nFishing for salmon with agile show,\nTheir playful spirit, a joy to behold,\nAs they frolic in waters, shimmering gold.\n\nBeneath the moonlit sky, they stand tall,\nSilhouettes against the starry sprawl,\nProtectors of the wild, guardians true,\nTheir presence a reminder, life's essence anew.\n\nSo let us celebrate these creatures rare,\nWith awe and reverence, let's declare,\nBears, the epitome of strength and might,\nA testament to nature", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In the wild, where nature's beauty thrives,\nResides a creature with gentle lives,\nA majestic beast, both strong and wise,\nLet me weave a tale of bears, arise!\n\nThrough towering forests, they roam with grace,\nPaws treading softly, leaving no trace,\nTheir fur, a tapestry of earthly hues,\nA testament to nature's wondrous muse.\n\nThe mighty grizzly, a towering sight,\nWith strength unmatched, they rule the night,\nTheir presence commands respect, with no compare,\nA symbol of nature's untamed flair.\n\nIn caves, they hibernate, in slumber deep,\nA peaceful rest, where dreams may seep,\nWrapped in warmth, they patiently wait,\nFor the gentle kiss of spring's embrace.\n\nThe polar bear, a marvel in the snow,\nWith ivory coat, they brave the cold,\nA master of icy realms, they roam,\nAdapting to the frozen depths they call home.\n\nBrown bears, dancing in rivers' flow,\nFishing for salmon with agile show,\nTheir playful spirit, a joy to behold,\nAs they frolic in waters, shimmering gold.\n\nBeneath the moonlit sky, they stand tall,\nSilhouettes against the starry sprawl,\nProtectors of the wild, guardians true,\nTheir presence a reminder, life's essence anew.\n\nSo let us celebrate these creatures rare,\nWith awe and reverence, let's declare,\nBears, the epitome of strength and might,\nA testament to nature's", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In the wild, where nature's beauty thrives,\nResides a creature with gentle lives,\nA majestic beast, both strong and wise,\nLet me weave a tale of bears, arise!\n\nThrough towering forests, they roam with grace,\nPaws treading softly, leaving no trace,\nTheir fur, a tapestry of earthly hues,\nA testament to nature's wondrous muse.\n\nThe mighty grizzly, a towering sight,\nWith strength unmatched, they rule the night,\nTheir presence commands respect, with no compare,\nA symbol of nature's untamed flair.\n\nIn caves, they hibernate, in slumber deep,\nA peaceful rest, where dreams may seep,\nWrapped in warmth, they patiently wait,\nFor the gentle kiss of spring's embrace.\n\nThe polar bear, a marvel in the snow,\nWith ivory coat, they brave the cold,\nA master of icy realms, they roam,\nAdapting to the frozen depths they call home.\n\nBrown bears, dancing in rivers' flow,\nFishing for salmon with agile show,\nTheir playful spirit, a joy to behold,\nAs they frolic in waters, shimmering gold.\n\nBeneath the moonlit sky, they stand tall,\nSilhouettes against the starry sprawl,\nProtectors of the wild, guardians true,\nTheir presence a reminder, life's essence anew.\n\nSo let us celebrate these creatures rare,\nWith awe and reverence, let's declare,\nBears, the epitome of strength and might,\nA testament to nature's bound", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In the wild, where nature's beauty thrives,\nResides a creature with gentle lives,\nA majestic beast, both strong and wise,\nLet me weave a tale of bears, arise!\n\nThrough towering forests, they roam with grace,\nPaws treading softly, leaving no trace,\nTheir fur, a tapestry of earthly hues,\nA testament to nature's wondrous muse.\n\nThe mighty grizzly, a towering sight,\nWith strength unmatched, they rule the night,\nTheir presence commands respect, with no compare,\nA symbol of nature's untamed flair.\n\nIn caves, they hibernate, in slumber deep,\nA peaceful rest, where dreams may seep,\nWrapped in warmth, they patiently wait,\nFor the gentle kiss of spring's embrace.\n\nThe polar bear, a marvel in the snow,\nWith ivory coat, they brave the cold,\nA master of icy realms, they roam,\nAdapting to the frozen depths they call home.\n\nBrown bears, dancing in rivers' flow,\nFishing for salmon with agile show,\nTheir playful spirit, a joy to behold,\nAs they frolic in waters, shimmering gold.\n\nBeneath the moonlit sky, they stand tall,\nSilhouettes against the starry sprawl,\nProtectors of the wild, guardians true,\nTheir presence a reminder, life's essence anew.\n\nSo let us celebrate these creatures rare,\nWith awe and reverence, let's declare,\nBears, the epitome of strength and might,\nA testament to nature's boundless", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In the wild, where nature's beauty thrives,\nResides a creature with gentle lives,\nA majestic beast, both strong and wise,\nLet me weave a tale of bears, arise!\n\nThrough towering forests, they roam with grace,\nPaws treading softly, leaving no trace,\nTheir fur, a tapestry of earthly hues,\nA testament to nature's wondrous muse.\n\nThe mighty grizzly, a towering sight,\nWith strength unmatched, they rule the night,\nTheir presence commands respect, with no compare,\nA symbol of nature's untamed flair.\n\nIn caves, they hibernate, in slumber deep,\nA peaceful rest, where dreams may seep,\nWrapped in warmth, they patiently wait,\nFor the gentle kiss of spring's embrace.\n\nThe polar bear, a marvel in the snow,\nWith ivory coat, they brave the cold,\nA master of icy realms, they roam,\nAdapting to the frozen depths they call home.\n\nBrown bears, dancing in rivers' flow,\nFishing for salmon with agile show,\nTheir playful spirit, a joy to behold,\nAs they frolic in waters, shimmering gold.\n\nBeneath the moonlit sky, they stand tall,\nSilhouettes against the starry sprawl,\nProtectors of the wild, guardians true,\nTheir presence a reminder, life's essence anew.\n\nSo let us celebrate these creatures rare,\nWith awe and reverence, let's declare,\nBears, the epitome of strength and might,\nA testament to nature's boundless delight", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In the wild, where nature's beauty thrives,\nResides a creature with gentle lives,\nA majestic beast, both strong and wise,\nLet me weave a tale of bears, arise!\n\nThrough towering forests, they roam with grace,\nPaws treading softly, leaving no trace,\nTheir fur, a tapestry of earthly hues,\nA testament to nature's wondrous muse.\n\nThe mighty grizzly, a towering sight,\nWith strength unmatched, they rule the night,\nTheir presence commands respect, with no compare,\nA symbol of nature's untamed flair.\n\nIn caves, they hibernate, in slumber deep,\nA peaceful rest, where dreams may seep,\nWrapped in warmth, they patiently wait,\nFor the gentle kiss of spring's embrace.\n\nThe polar bear, a marvel in the snow,\nWith ivory coat, they brave the cold,\nA master of icy realms, they roam,\nAdapting to the frozen depths they call home.\n\nBrown bears, dancing in rivers' flow,\nFishing for salmon with agile show,\nTheir playful spirit, a joy to behold,\nAs they frolic in waters, shimmering gold.\n\nBeneath the moonlit sky, they stand tall,\nSilhouettes against the starry sprawl,\nProtectors of the wild, guardians true,\nTheir presence a reminder, life's essence anew.\n\nSo let us celebrate these creatures rare,\nWith awe and reverence, let's declare,\nBears, the epitome of strength and might,\nA testament to nature's boundless delight.", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In the wild, where nature's beauty thrives,\nResides a creature with gentle lives,\nA majestic beast, both strong and wise,\nLet me weave a tale of bears, arise!\n\nThrough towering forests, they roam with grace,\nPaws treading softly, leaving no trace,\nTheir fur, a tapestry of earthly hues,\nA testament to nature's wondrous muse.\n\nThe mighty grizzly, a towering sight,\nWith strength unmatched, they rule the night,\nTheir presence commands respect, with no compare,\nA symbol of nature's untamed flair.\n\nIn caves, they hibernate, in slumber deep,\nA peaceful rest, where dreams may seep,\nWrapped in warmth, they patiently wait,\nFor the gentle kiss of spring's embrace.\n\nThe polar bear, a marvel in the snow,\nWith ivory coat, they brave the cold,\nA master of icy realms, they roam,\nAdapting to the frozen depths they call home.\n\nBrown bears, dancing in rivers' flow,\nFishing for salmon with agile show,\nTheir playful spirit, a joy to behold,\nAs they frolic in waters, shimmering gold.\n\nBeneath the moonlit sky, they stand tall,\nSilhouettes against the starry sprawl,\nProtectors of the wild, guardians true,\nTheir presence a reminder, life's essence anew.\n\nSo let us celebrate these creatures rare,\nWith awe and reverence, let's declare,\nBears, the epitome of strength and might,\nA testament to nature's boundless delight.", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}

# %% [markdown]
# ## Stream Log

# %%
from langchain_community.retrievers.tavily_search_api import TavilySearchAPIRetriever
from langchain_core.runnables import RunnablePassthrough

retriever= TavilySearchAPIRetriever()

prompt = ChatPromptTemplate.from_template("""Answer the question based only on the context provided:

Context: {context}

Question: {question}""")

chain = prompt | model | output_parser

retrieval_chain = RunnablePassthrough.assign(
    context=(lambda x: x["question"]) | retriever.with_config(run_name="Docs")
) | chain

# %%
for s in retrieval_chain.stream({"question": "what is langsmith"}):
    print(s, end="")
# Out:
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# LangSmith is a platform that helps trace and evaluate language model applications and intelligent agents. It allows developers to move from prototyping to production by providing tools for debugging, testing, evaluating, and monitoring chains and intelligent agents built on any LLM framework. LangSmith also offers a simple and intuitive user interface that reduces the barrier to entry for those without a software background.

# %%
async for s in retrieval_chain.astream_log({"question": "what is langsmith"}):
    print(s, end="")
# Out:
# RunLogPatch({'op': 'replace',
#   'path': '',
#   'value': {'final_output': None,
#             'id': '103db7cb-3ff7-495f-a862-97f4edfb9b7b',
#             'logs': {},
#             'streamed_output': []}})RunLogPatch({'op': 'add',
#   'path': '/logs/RunnableAssign<context>',
#   'value': {'end_time': None,
#             'final_output': None,
#             'id': '0a0ca07b-8229-4e7d-8aa9-3b752cba3dd5',
#             'metadata': {},
#             'name': 'RunnableAssign<context>',
#             'start_time': '2024-01-14T11:04:46.434+00:00',
#             'streamed_output': [],
#             'streamed_output_str': [],
#             'tags': ['seq:step:1'],
#             'type': 'chain'}})RunLogPatch({'op': 'add',
#   'path': '/logs/RunnableAssign<context>/streamed_output/-',
#   'value': {'question': 'what is langsmith'}})RunLogPatch({'op': 'add',
#   'path': '/logs/RunnableParallel<context>',
#   'value': {'end_time': None,
#             'final_output': None,
#             'id': '99135217-b8a1-4e3a-8bc8-5b7fac668780',
#             'metadata': {},
#             'name': 'RunnableParallel<context>',
#             'start_time': '2024-01-14T11:04:46.438+00:00',
#             'streamed_output': [],
#             'streamed_output_str': [],
#             'tags': [],
#             'type': 'chain'}})RunLogPatch({'op': 'add',
#   'path': '/logs/RunnableSequence',
#   'value': {'end_time': None,
#             'final_output': None,
#             'id': 'e9aca843-115a-4d33-8df2-0c5567efd9c2',
#             'metadata': {},
#             'name': 'RunnableSequence',
#             'start_time': '2024-01-14T11:04:46.442+00:00',
#             'streamed_output': [],
#             'streamed_output_str': [],
#             'tags': ['map:key:context'],
#             'type': 'chain'}})RunLogPatch({'op': 'add',
#   'path': '/logs/RunnableLambda',
#   'value': {'end_time': None,
#             'final_output': None,
#             'id': '2ca550ba-6817-4a1c-b1cb-a1fcb937e3a4',
#             'metadata': {},
#             'name': 'RunnableLambda',
#             'start_time': '2024-01-14T11:04:46.445+00:00',
#             'streamed_output': [],
#             'streamed_output_str': [],
#             'tags': ['seq:step:1'],
#             'type': 'chain'}})RunLogPatch({'op': 'add',
#   'path': '/logs/RunnableLambda/streamed_output/-',
#   'value': 'what is langsmith'})RunLogPatch({'op': 'add',
#   'path': '/logs/RunnableLambda/final_output',
#   'value': {'output': 'what is langsmith'}},
#  {'op': 'add',
#   'path': '/logs/RunnableLambda/end_time',
#   'value': '2024-01-14T11:04:46.449+00:00'})RunLogPatch({'op': 'add',
#   'path': '/logs/Docs',
#   'value': {'end_time': None,
#             'final_output': None,
#             'id': '24afc88a-5316-46b7-8934-7ef6dd4875dd',
#             'metadata': {},
#             'name': 'Docs',
#             'start_time': '2024-01-14T11:04:46.504+00:00',
#             'streamed_output': [],
#             'streamed_output_str': [],
#             'tags': ['seq:step:2'],
#             'type': 'retriever'}})RunLogPatch({'op': 'add',
#   'path': '/logs/Docs/final_output',
#   'value': {'documents': [Document(page_content="BETA Sign Up\nContact Sales\nProducts and use-cases\nLangChain\nLangSmith\nRetrieval\nAgents\nInspiration\nCode\nGitHub\nLangChain Hub\nPython Docs\nJS/TS Docs\nSocial\nTwitter\nDiscord\nBlog\nLinkedIn\nYouTube\nTerms of Service\nSign up for our newsletter\nProducts and use-cases\nLangChain\nLangSmith\nRetrieval\nAgents\nInspiration\nCode\nGitHub\nLangChain Hub\nPython Docs\nJS/TS Docs\nSocial\nTwitter\nDiscord\nBlog\nLinkedIn\nYouTube\nTerms of Service\nSign up for our newsletter\nProducts and use-cases\nLangChain\nLangSmith\nRetrieval\nAgents\nInspiration\nCode\nGitHub\nLangChain Hub\nPython Docs\nJS/TS Docs\nSocial\nTwitter\nDiscord\nBlog\nLinkedIn\nYouTube\nTerms of Service\nSign up for our newsletter 🦜🔗 LangChain\nLangSmith\nLangServe\nAgents\nRetrieval\nEvaluation\nBlog\nDocs\n🦜🔗 LangChain\nBuild and deploy LLM apps with confidence\nAn all-in-one developer platform for every step of the application lifecycle.\n Prompt playground\nCross-team collaboration\nCatalog of ranging models & tasks\nProven prompting strategies\nExplore LangChain Hub\nTurn the magic of LLM applications into enterprise-ready products\nNative collaboration\nBring your team together in LangSmith to craft prompts, debug, and capture feedback.\n Application-level usage stats\nFeedback collection\nFilter traces\nCost measurement\nPerformance comparison\nGo To Docs\nManage Prompts\nPrompts power your team's chains and agents, and LangSmith allows you to refine, test, and version them in one place. Dataset curation\nEvaluate chain performance\nAI-assisted evaluation\nEasy benchmarking\nGo To Docs\nMonitor\nGiven the stochastic nature of LLMs, it can be hard to answer the simple question: “what’s happening with my application?”", metadata={'title': 'LangSmith', 'source': 'https://www.langchain.com/langsmith', 'score': 0.97426, 'images': None}),
#                           Document(page_content="If you already use LangChain, you can connect to LangSmith in a few steps:\nFor environments where process.env is not defined, initialize by explicitly passing keys:\nIf you don't want to use LangChain in your LLM application, you can get started with LangSmith in just a few steps:\nCongratulations! It lets you debug, test, evaluate, and monitor chains and intelligent agents built on any LLM framework and seamlessly integrates with LangChain, the go-to open source framework for building with LLMs.\n Quick Start\u200b\nIf following along with code is more your thing, we've set up a Jupyter notebook at this link to help you get started with LangSmith.\n LangChain JS Docs for the TypeScript LangChain library\nDiscord: Join us on our Discord to discuss all things LangChain!\n Next Steps\u200b\nRead the LangSmith Overview to learn more about what LangSmith has to offer.\n", metadata={'title': 'LangSmith | ️ ️ LangSmith', 'source': 'https://docs.smith.langchain.com/', 'score': 0.93028, 'images': None}),
#                           Document(page_content='This function helps to load the specific language models and tools required for the task as shown in the code snippet below:\nAs a next step, initialize an agent by calling the initialize_agent function with several parameters like tools, llms, and agent:\nThe verbose parameter is set to false, indicating that the agent will not provide verbose or detailed output.\n You can accomplish this by following the shell commands provided below:\nCreating a LangSmith client\nNext, create a LangSmith client to interact with the API:\nIf you’re using Python, run the following commands to import the module:\n This code also handles exceptions that may occur during the agent execution:\nIt’s also important to call the wait_for_all_tracers function from the langchain.callbacks.tracers.langchain module as shown in the code snippet below:\nCalling the wait_for_all_tracers function helps ensure that logs and traces are submitted in full before the program proceeds. The temperature parameter will be set to 0, implying that the generated response will be more deterministic as shown in the code snippet below:\nNow, let’s call the load_tools function with a list of tool APIs, such as serpapi and llm-math, and also take the llm instance as a parameter. It initializes a chat model, loads specific tools, and creates an agent that can generate responses based on descriptions:\nInput processing with exception handling\nThe code below defines a list of input examples using the asyncio library to asynchronously run the agent on each input and gather the results for further processing.', metadata={'title': 'Using LangSmith to test LLMs and AI applications', 'source': 'https://blog.logrocket.com/langsmith-test-llms-ai-applications/', 'score': 0.9277, 'images': None}),
#                           Document(page_content='LangSmith helps you trace and evaluate your language model applications and intelligent agents to help you move from prototype to production. Check out the interactive walkthrough to get started. For more information, please refer to the LangSmith documentation.', metadata={'title': 'LangSmith | ️ Langchain', 'source': 'https://python.langchain.com/docs/langsmith/', 'score': 0.92043, 'images': None}),
#                           Document(page_content='But what are the production challenges that need to be solved which were not as relevant in prototyping?\nReliability — it is deceptively easy to build something that works well for a simple constrained example but actually still quite hard today to build LLM applications with the consistency that most companies would want.\n for tools\nKim Seon Woo - Nov 6\nComo deixar o Swagger com tema dark mode usando NestJS\nWiliam V. Joaquim - Nov 5\nData visualizing\nBIRINGANINE BASEME Destin\n- Oct 7\nFree Face-Swap AI 🎭 with Source Code for Web and Mobile App.\nshadee22 - As you build more complex workflows, it can be hard to understand exactly what queries are moving through different flows so a simple UI to see this and log the historical data is going to be a value add from day one.\n A huge part of the value add for LangSmith is being able to do all of these things from a simple and intuitive UI which significantly reduces the barrier to entry for those without a software background.\n [Quick note: I am writing this article to reflect my personal views as I explore the LLM ecosystem and this is not intended to represent the views of my employer, hence being on my personal blog]\nWhat is LangSmith?', metadata={'title': 'What is LangSmith and why should I care as a developer?', 'source': 'https://dev.to/logankilpatrick/what-is-langsmith-and-why-should-i-care-as-a-developer-19k', 'score': 0.91222, 'images': None}),
#                           Document(page_content='We consistently see developers relying on LangSmith to track the system-level performance of their application (like latency and cost), track the model/chain performance (through associating feedback with runs), debug issues (diving into a particular run that went wrong), and establish a broad understanding of how users are interacting with their application and what their experience is like.\n Over the last few months, we’ve been working directly with some early design partners and testing it on our own internal workflows, and we’ve found LangSmith helps teams in 5 core ways:\nDebugging\nLangSmith gives you full visibility into model inputs and output of every step in the chain of events. As a very simple example, we considered it to be table stakes for LangSmith to help users easily create datasets from existing logs and use them immediately for testing and evaluation, seamlessly connecting the logging/debugging workflows to the testing/evaluation ones.\n A unified platform\nWhile each of these product areas provide unique value, often at a specific point in time in the development process, we believe a great deal of the long term impact of LangSmith will come from having a single, fully-integrated hub to do this work from. Additionally, tracing and evaluating the complex agent prompt chains is much easier, reducing the time required to debug and refine our prompts, and giving us the confidence to move to deployment.”\n', metadata={'title': 'Announcing LangSmith, a unified platform for debugging, testing ...', 'source': 'https://blog.langchain.dev/announcing-langsmith/', 'score': 0.87879, 'images': None}),
#                           Document(page_content='This will:\nThe results will be visible in the LangSmith app.\nReview the test results\u200b\nYou can review the test results tracing UI below by clicking the URL in the output above or navigating to the "Testing & Datasets" page in LangSmith\n"agent-qa-{unique_id}" dataset.\n Below, we will create some pre-implemented run evaluators that do the following:\nFor a longer discussion of how to select an appropriate evaluator for your use case and how to create your own\ncustom evaluators, please refer to the LangSmith documentation.\n For more information on datasets, including how to create them from CSVs or other files or how to create them in the platform, please refer to the LangSmith documentation.\n Create the langsmith client to interact with the API\nCreate a LangChain component and log runs to the platform. Create a LangSmith dataset\u200b\nBelow, we use the LangSmith client to create a dataset from the input questions from above and a list labels.', metadata={'title': 'LangSmith Walkthrough | ️ Langchain', 'source': 'https://python.langchain.com/docs/langsmith/walkthrough', 'score': 0.86395, 'images': None}),
#                           Document(page_content='The Run tab for the top-level chain shows the human input, the parsed output, the latency (under a second), and the tokens used, as well as the clock time and call status.\n The cookbook covers tracing your code without LangChain (using the @traceable decorator); using the LangChain Hub to discover, share, and version control prompts; testing and benchmarking your LLM systems in Python and TypeScript or JavaScript; using user feedback to improve, monitor, and personalize your applications; exporting data for fine-tuning; and exporting your run data for exploratory data analysis.\n In addition to the input variables (prompt), an LLM call uses a template and often auxiliary functions; for example, retrieval of information from the web, uploaded files, and system prompts that set the context for the LLM.\n After I set up my LangSmith account, created my API key, updated my LangChain installation with pip, and set up my shell environment variables, I tried to run the Python quickstart application:\nBefore we discuss the results, take a look at the LangSmith hub:\nFigure 1. Here are the evaluation statistics, which were printed in the terminal during the run:\nSomebody had fun creating the rap battle prompts, as shown in the dataset below:\nFigure 9.', metadata={'title': 'What is LangSmith? Tracing and debugging for LLMs | InfoWorld', 'source': 'https://www.infoworld.com/article/3708628/what-is-langsmith-tracing-and-debugging-for-llms.html', 'score': 0.82697, 'images': None})]}},
#  {'op': 'add',
#   'path': '/logs/Docs/end_time',
#   'value': '2024-01-14T11:04:48.152+00:00'})RunLogPatch({'op': 'add',
#   'path': '/logs/RunnableSequence/streamed_output/-',
#   'value': [Document(page_content="BETA Sign Up\nContact Sales\nProducts and use-cases\nLangChain\nLangSmith\nRetrieval\nAgents\nInspiration\nCode\nGitHub\nLangChain Hub\nPython Docs\nJS/TS Docs\nSocial\nTwitter\nDiscord\nBlog\nLinkedIn\nYouTube\nTerms of Service\nSign up for our newsletter\nProducts and use-cases\nLangChain\nLangSmith\nRetrieval\nAgents\nInspiration\nCode\nGitHub\nLangChain Hub\nPython Docs\nJS/TS Docs\nSocial\nTwitter\nDiscord\nBlog\nLinkedIn\nYouTube\nTerms of Service\nSign up for our newsletter\nProducts and use-cases\nLangChain\nLangSmith\nRetrieval\nAgents\nInspiration\nCode\nGitHub\nLangChain Hub\nPython Docs\nJS/TS Docs\nSocial\nTwitter\nDiscord\nBlog\nLinkedIn\nYouTube\nTerms of Service\nSign up for our newsletter 🦜🔗 LangChain\nLangSmith\nLangServe\nAgents\nRetrieval\nEvaluation\nBlog\nDocs\n🦜🔗 LangChain\nBuild and deploy LLM apps with confidence\nAn all-in-one developer platform for every step of the application lifecycle.\n Prompt playground\nCross-team collaboration\nCatalog of ranging models & tasks\nProven prompting strategies\nExplore LangChain Hub\nTurn the magic of LLM applications into enterprise-ready products\nNative collaboration\nBring your team together in LangSmith to craft prompts, debug, and capture feedback.\n Application-level usage stats\nFeedback collection\nFilter traces\nCost measurement\nPerformance comparison\nGo To Docs\nManage Prompts\nPrompts power your team's chains and agents, and LangSmith allows you to refine, test, and version them in one place. Dataset curation\nEvaluate chain performance\nAI-assisted evaluation\nEasy benchmarking\nGo To Docs\nMonitor\nGiven the stochastic nature of LLMs, it can be hard to answer the simple question: “what’s happening with my application?”", metadata={'title': 'LangSmith', 'source': 'https://www.langchain.com/langsmith', 'score': 0.97426, 'images': None}),
#             Document(page_content="If you already use LangChain, you can connect to LangSmith in a few steps:\nFor environments where process.env is not defined, initialize by explicitly passing keys:\nIf you don't want to use LangChain in your LLM application, you can get started with LangSmith in just a few steps:\nCongratulations! It lets you debug, test, evaluate, and monitor chains and intelligent agents built on any LLM framework and seamlessly integrates with LangChain, the go-to open source framework for building with LLMs.\n Quick Start\u200b\nIf following along with code is more your thing, we've set up a Jupyter notebook at this link to help you get started with LangSmith.\n LangChain JS Docs for the TypeScript LangChain library\nDiscord: Join us on our Discord to discuss all things LangChain!\n Next Steps\u200b\nRead the LangSmith Overview to learn more about what LangSmith has to offer.\n", metadata={'title': 'LangSmith | ️ ️ LangSmith', 'source': 'https://docs.smith.langchain.com/', 'score': 0.93028, 'images': None}),
#             Document(page_content='This function helps to load the specific language models and tools required for the task as shown in the code snippet below:\nAs a next step, initialize an agent by calling the initialize_agent function with several parameters like tools, llms, and agent:\nThe verbose parameter is set to false, indicating that the agent will not provide verbose or detailed output.\n You can accomplish this by following the shell commands provided below:\nCreating a LangSmith client\nNext, create a LangSmith client to interact with the API:\nIf you’re using Python, run the following commands to import the module:\n This code also handles exceptions that may occur during the agent execution:\nIt’s also important to call the wait_for_all_tracers function from the langchain.callbacks.tracers.langchain module as shown in the code snippet below:\nCalling the wait_for_all_tracers function helps ensure that logs and traces are submitted in full before the program proceeds. The temperature parameter will be set to 0, implying that the generated response will be more deterministic as shown in the code snippet below:\nNow, let’s call the load_tools function with a list of tool APIs, such as serpapi and llm-math, and also take the llm instance as a parameter. It initializes a chat model, loads specific tools, and creates an agent that can generate responses based on descriptions:\nInput processing with exception handling\nThe code below defines a list of input examples using the asyncio library to asynchronously run the agent on each input and gather the results for further processing.', metadata={'title': 'Using LangSmith to test LLMs and AI applications', 'source': 'https://blog.logrocket.com/langsmith-test-llms-ai-applications/', 'score': 0.9277, 'images': None}),
#             Document(page_content='LangSmith helps you trace and evaluate your language model applications and intelligent agents to help you move from prototype to production. Check out the interactive walkthrough to get started. For more information, please refer to the LangSmith documentation.', metadata={'title': 'LangSmith | ️ Langchain', 'source': 'https://python.langchain.com/docs/langsmith/', 'score': 0.92043, 'images': None}),
#             Document(page_content='But what are the production challenges that need to be solved which were not as relevant in prototyping?\nReliability — it is deceptively easy to build something that works well for a simple constrained example but actually still quite hard today to build LLM applications with the consistency that most companies would want.\n for tools\nKim Seon Woo - Nov 6\nComo deixar o Swagger com tema dark mode usando NestJS\nWiliam V. Joaquim - Nov 5\nData visualizing\nBIRINGANINE BASEME Destin\n- Oct 7\nFree Face-Swap AI 🎭 with Source Code for Web and Mobile App.\nshadee22 - As you build more complex workflows, it can be hard to understand exactly what queries are moving through different flows so a simple UI to see this and log the historical data is going to be a value add from day one.\n A huge part of the value add for LangSmith is being able to do all of these things from a simple and intuitive UI which significantly reduces the barrier to entry for those without a software background.\n [Quick note: I am writing this article to reflect my personal views as I explore the LLM ecosystem and this is not intended to represent the views of my employer, hence being on my personal blog]\nWhat is LangSmith?', metadata={'title': 'What is LangSmith and why should I care as a developer?', 'source': 'https://dev.to/logankilpatrick/what-is-langsmith-and-why-should-i-care-as-a-developer-19k', 'score': 0.91222, 'images': None}),
#             Document(page_content='We consistently see developers relying on LangSmith to track the system-level performance of their application (like latency and cost), track the model/chain performance (through associating feedback with runs), debug issues (diving into a particular run that went wrong), and establish a broad understanding of how users are interacting with their application and what their experience is like.\n Over the last few months, we’ve been working directly with some early design partners and testing it on our own internal workflows, and we’ve found LangSmith helps teams in 5 core ways:\nDebugging\nLangSmith gives you full visibility into model inputs and output of every step in the chain of events. As a very simple example, we considered it to be table stakes for LangSmith to help users easily create datasets from existing logs and use them immediately for testing and evaluation, seamlessly connecting the logging/debugging workflows to the testing/evaluation ones.\n A unified platform\nWhile each of these product areas provide unique value, often at a specific point in time in the development process, we believe a great deal of the long term impact of LangSmith will come from having a single, fully-integrated hub to do this work from. Additionally, tracing and evaluating the complex agent prompt chains is much easier, reducing the time required to debug and refine our prompts, and giving us the confidence to move to deployment.”\n', metadata={'title': 'Announcing LangSmith, a unified platform for debugging, testing ...', 'source': 'https://blog.langchain.dev/announcing-langsmith/', 'score': 0.87879, 'images': None}),
#             Document(page_content='This will:\nThe results will be visible in the LangSmith app.\nReview the test results\u200b\nYou can review the test results tracing UI below by clicking the URL in the output above or navigating to the "Testing & Datasets" page in LangSmith\n"agent-qa-{unique_id}" dataset.\n Below, we will create some pre-implemented run evaluators that do the following:\nFor a longer discussion of how to select an appropriate evaluator for your use case and how to create your own\ncustom evaluators, please refer to the LangSmith documentation.\n For more information on datasets, including how to create them from CSVs or other files or how to create them in the platform, please refer to the LangSmith documentation.\n Create the langsmith client to interact with the API\nCreate a LangChain component and log runs to the platform. Create a LangSmith dataset\u200b\nBelow, we use the LangSmith client to create a dataset from the input questions from above and a list labels.', metadata={'title': 'LangSmith Walkthrough | ️ Langchain', 'source': 'https://python.langchain.com/docs/langsmith/walkthrough', 'score': 0.86395, 'images': None}),
#             Document(page_content='The Run tab for the top-level chain shows the human input, the parsed output, the latency (under a second), and the tokens used, as well as the clock time and call status.\n The cookbook covers tracing your code without LangChain (using the @traceable decorator); using the LangChain Hub to discover, share, and version control prompts; testing and benchmarking your LLM systems in Python and TypeScript or JavaScript; using user feedback to improve, monitor, and personalize your applications; exporting data for fine-tuning; and exporting your run data for exploratory data analysis.\n In addition to the input variables (prompt), an LLM call uses a template and often auxiliary functions; for example, retrieval of information from the web, uploaded files, and system prompts that set the context for the LLM.\n After I set up my LangSmith account, created my API key, updated my LangChain installation with pip, and set up my shell environment variables, I tried to run the Python quickstart application:\nBefore we discuss the results, take a look at the LangSmith hub:\nFigure 1. Here are the evaluation statistics, which were printed in the terminal during the run:\nSomebody had fun creating the rap battle prompts, as shown in the dataset below:\nFigure 9.', metadata={'title': 'What is LangSmith? Tracing and debugging for LLMs | InfoWorld', 'source': 'https://www.infoworld.com/article/3708628/what-is-langsmith-tracing-and-debugging-for-llms.html', 'score': 0.82697, 'images': None})]})RunLogPatch({'op': 'add',
#   'path': '/logs/RunnableParallel<context>/streamed_output/-',
#   'value': {'context': [Document(page_content="BETA Sign Up\nContact Sales\nProducts and use-cases\nLangChain\nLangSmith\nRetrieval\nAgents\nInspiration\nCode\nGitHub\nLangChain Hub\nPython Docs\nJS/TS Docs\nSocial\nTwitter\nDiscord\nBlog\nLinkedIn\nYouTube\nTerms of Service\nSign up for our newsletter\nProducts and use-cases\nLangChain\nLangSmith\nRetrieval\nAgents\nInspiration\nCode\nGitHub\nLangChain Hub\nPython Docs\nJS/TS Docs\nSocial\nTwitter\nDiscord\nBlog\nLinkedIn\nYouTube\nTerms of Service\nSign up for our newsletter\nProducts and use-cases\nLangChain\nLangSmith\nRetrieval\nAgents\nInspiration\nCode\nGitHub\nLangChain Hub\nPython Docs\nJS/TS Docs\nSocial\nTwitter\nDiscord\nBlog\nLinkedIn\nYouTube\nTerms of Service\nSign up for our newsletter 🦜🔗 LangChain\nLangSmith\nLangServe\nAgents\nRetrieval\nEvaluation\nBlog\nDocs\n🦜🔗 LangChain\nBuild and deploy LLM apps with confidence\nAn all-in-one developer platform for every step of the application lifecycle.\n Prompt playground\nCross-team collaboration\nCatalog of ranging models & tasks\nProven prompting strategies\nExplore LangChain Hub\nTurn the magic of LLM applications into enterprise-ready products\nNative collaboration\nBring your team together in LangSmith to craft prompts, debug, and capture feedback.\n Application-level usage stats\nFeedback collection\nFilter traces\nCost measurement\nPerformance comparison\nGo To Docs\nManage Prompts\nPrompts power your team's chains and agents, and LangSmith allows you to refine, test, and version them in one place. Dataset curation\nEvaluate chain performance\nAI-assisted evaluation\nEasy benchmarking\nGo To Docs\nMonitor\nGiven the stochastic nature of LLMs, it can be hard to answer the simple question: “what’s happening with my application?”", metadata={'title': 'LangSmith', 'source': 'https://www.langchain.com/langsmith', 'score': 0.97426, 'images': None}),
#                         Document(page_content="If you already use LangChain, you can connect to LangSmith in a few steps:\nFor environments where process.env is not defined, initialize by explicitly passing keys:\nIf you don't want to use LangChain in your LLM application, you can get started with LangSmith in just a few steps:\nCongratulations! It lets you debug, test, evaluate, and monitor chains and intelligent agents built on any LLM framework and seamlessly integrates with LangChain, the go-to open source framework for building with LLMs.\n Quick Start\u200b\nIf following along with code is more your thing, we've set up a Jupyter notebook at this link to help you get started with LangSmith.\n LangChain JS Docs for the TypeScript LangChain library\nDiscord: Join us on our Discord to discuss all things LangChain!\n Next Steps\u200b\nRead the LangSmith Overview to learn more about what LangSmith has to offer.\n", metadata={'title': 'LangSmith | ️ ️ LangSmith', 'source': 'https://docs.smith.langchain.com/', 'score': 0.93028, 'images': None}),
#                         Document(page_content='This function helps to load the specific language models and tools required for the task as shown in the code snippet below:\nAs a next step, initialize an agent by calling the initialize_agent function with several parameters like tools, llms, and agent:\nThe verbose parameter is set to false, indicating that the agent will not provide verbose or detailed output.\n You can accomplish this by following the shell commands provided below:\nCreating a LangSmith client\nNext, create a LangSmith client to interact with the API:\nIf you’re using Python, run the following commands to import the module:\n This code also handles exceptions that may occur during the agent execution:\nIt’s also important to call the wait_for_all_tracers function from the langchain.callbacks.tracers.langchain module as shown in the code snippet below:\nCalling the wait_for_all_tracers function helps ensure that logs and traces are submitted in full before the program proceeds. The temperature parameter will be set to 0, implying that the generated response will be more deterministic as shown in the code snippet below:\nNow, let’s call the load_tools function with a list of tool APIs, such as serpapi and llm-math, and also take the llm instance as a parameter. It initializes a chat model, loads specific tools, and creates an agent that can generate responses based on descriptions:\nInput processing with exception handling\nThe code below defines a list of input examples using the asyncio library to asynchronously run the agent on each input and gather the results for further processing.', metadata={'title': 'Using LangSmith to test LLMs and AI applications', 'source': 'https://blog.logrocket.com/langsmith-test-llms-ai-applications/', 'score': 0.9277, 'images': None}),
#                         Document(page_content='LangSmith helps you trace and evaluate your language model applications and intelligent agents to help you move from prototype to production. Check out the interactive walkthrough to get started. For more information, please refer to the LangSmith documentation.', metadata={'title': 'LangSmith | ️ Langchain', 'source': 'https://python.langchain.com/docs/langsmith/', 'score': 0.92043, 'images': None}),
#                         Document(page_content='But what are the production challenges that need to be solved which were not as relevant in prototyping?\nReliability — it is deceptively easy to build something that works well for a simple constrained example but actually still quite hard today to build LLM applications with the consistency that most companies would want.\n for tools\nKim Seon Woo - Nov 6\nComo deixar o Swagger com tema dark mode usando NestJS\nWiliam V. Joaquim - Nov 5\nData visualizing\nBIRINGANINE BASEME Destin\n- Oct 7\nFree Face-Swap AI 🎭 with Source Code for Web and Mobile App.\nshadee22 - As you build more complex workflows, it can be hard to understand exactly what queries are moving through different flows so a simple UI to see this and log the historical data is going to be a value add from day one.\n A huge part of the value add for LangSmith is being able to do all of these things from a simple and intuitive UI which significantly reduces the barrier to entry for those without a software background.\n [Quick note: I am writing this article to reflect my personal views as I explore the LLM ecosystem and this is not intended to represent the views of my employer, hence being on my personal blog]\nWhat is LangSmith?', metadata={'title': 'What is LangSmith and why should I care as a developer?', 'source': 'https://dev.to/logankilpatrick/what-is-langsmith-and-why-should-i-care-as-a-developer-19k', 'score': 0.91222, 'images': None}),
#                         Document(page_content='We consistently see developers relying on LangSmith to track the system-level performance of their application (like latency and cost), track the model/chain performance (through associating feedback with runs), debug issues (diving into a particular run that went wrong), and establish a broad understanding of how users are interacting with their application and what their experience is like.\n Over the last few months, we’ve been working directly with some early design partners and testing it on our own internal workflows, and we’ve found LangSmith helps teams in 5 core ways:\nDebugging\nLangSmith gives you full visibility into model inputs and output of every step in the chain of events. As a very simple example, we considered it to be table stakes for LangSmith to help users easily create datasets from existing logs and use them immediately for testing and evaluation, seamlessly connecting the logging/debugging workflows to the testing/evaluation ones.\n A unified platform\nWhile each of these product areas provide unique value, often at a specific point in time in the development process, we believe a great deal of the long term impact of LangSmith will come from having a single, fully-integrated hub to do this work from. Additionally, tracing and evaluating the complex agent prompt chains is much easier, reducing the time required to debug and refine our prompts, and giving us the confidence to move to deployment.”\n', metadata={'title': 'Announcing LangSmith, a unified platform for debugging, testing ...', 'source': 'https://blog.langchain.dev/announcing-langsmith/', 'score': 0.87879, 'images': None}),
#                         Document(page_content='This will:\nThe results will be visible in the LangSmith app.\nReview the test results\u200b\nYou can review the test results tracing UI below by clicking the URL in the output above or navigating to the "Testing & Datasets" page in LangSmith\n"agent-qa-{unique_id}" dataset.\n Below, we will create some pre-implemented run evaluators that do the following:\nFor a longer discussion of how to select an appropriate evaluator for your use case and how to create your own\ncustom evaluators, please refer to the LangSmith documentation.\n For more information on datasets, including how to create them from CSVs or other files or how to create them in the platform, please refer to the LangSmith documentation.\n Create the langsmith client to interact with the API\nCreate a LangChain component and log runs to the platform. Create a LangSmith dataset\u200b\nBelow, we use the LangSmith client to create a dataset from the input questions from above and a list labels.', metadata={'title': 'LangSmith Walkthrough | ️ Langchain', 'source': 'https://python.langchain.com/docs/langsmith/walkthrough', 'score': 0.86395, 'images': None}),
#                         Document(page_content='The Run tab for the top-level chain shows the human input, the parsed output, the latency (under a second), and the tokens used, as well as the clock time and call status.\n The cookbook covers tracing your code without LangChain (using the @traceable decorator); using the LangChain Hub to discover, share, and version control prompts; testing and benchmarking your LLM systems in Python and TypeScript or JavaScript; using user feedback to improve, monitor, and personalize your applications; exporting data for fine-tuning; and exporting your run data for exploratory data analysis.\n In addition to the input variables (prompt), an LLM call uses a template and often auxiliary functions; for example, retrieval of information from the web, uploaded files, and system prompts that set the context for the LLM.\n After I set up my LangSmith account, created my API key, updated my LangChain installation with pip, and set up my shell environment variables, I tried to run the Python quickstart application:\nBefore we discuss the results, take a look at the LangSmith hub:\nFigure 1. Here are the evaluation statistics, which were printed in the terminal during the run:\nSomebody had fun creating the rap battle prompts, as shown in the dataset below:\nFigure 9.', metadata={'title': 'What is LangSmith? Tracing and debugging for LLMs | InfoWorld', 'source': 'https://www.infoworld.com/article/3708628/what-is-langsmith-tracing-and-debugging-for-llms.html', 'score': 0.82697, 'images': None})]}})RunLogPatch({'op': 'add',
#   'path': '/logs/RunnableAssign<context>/streamed_output/-',
#   'value': {'context': [Document(page_content="BETA Sign Up\nContact Sales\nProducts and use-cases\nLangChain\nLangSmith\nRetrieval\nAgents\nInspiration\nCode\nGitHub\nLangChain Hub\nPython Docs\nJS/TS Docs\nSocial\nTwitter\nDiscord\nBlog\nLinkedIn\nYouTube\nTerms of Service\nSign up for our newsletter\nProducts and use-cases\nLangChain\nLangSmith\nRetrieval\nAgents\nInspiration\nCode\nGitHub\nLangChain Hub\nPython Docs\nJS/TS Docs\nSocial\nTwitter\nDiscord\nBlog\nLinkedIn\nYouTube\nTerms of Service\nSign up for our newsletter\nProducts and use-cases\nLangChain\nLangSmith\nRetrieval\nAgents\nInspiration\nCode\nGitHub\nLangChain Hub\nPython Docs\nJS/TS Docs\nSocial\nTwitter\nDiscord\nBlog\nLinkedIn\nYouTube\nTerms of Service\nSign up for our newsletter 🦜🔗 LangChain\nLangSmith\nLangServe\nAgents\nRetrieval\nEvaluation\nBlog\nDocs\n🦜🔗 LangChain\nBuild and deploy LLM apps with confidence\nAn all-in-one developer platform for every step of the application lifecycle.\n Prompt playground\nCross-team collaboration\nCatalog of ranging models & tasks\nProven prompting strategies\nExplore LangChain Hub\nTurn the magic of LLM applications into enterprise-ready products\nNative collaboration\nBring your team together in LangSmith to craft prompts, debug, and capture feedback.\n Application-level usage stats\nFeedback collection\nFilter traces\nCost measurement\nPerformance comparison\nGo To Docs\nManage Prompts\nPrompts power your team's chains and agents, and LangSmith allows you to refine, test, and version them in one place. Dataset curation\nEvaluate chain performance\nAI-assisted evaluation\nEasy benchmarking\nGo To Docs\nMonitor\nGiven the stochastic nature of LLMs, it can be hard to answer the simple question: “what’s happening with my application?”", metadata={'title': 'LangSmith', 'source': 'https://www.langchain.com/langsmith', 'score': 0.97426, 'images': None}),
#                         Document(page_content="If you already use LangChain, you can connect to LangSmith in a few steps:\nFor environments where process.env is not defined, initialize by explicitly passing keys:\nIf you don't want to use LangChain in your LLM application, you can get started with LangSmith in just a few steps:\nCongratulations! It lets you debug, test, evaluate, and monitor chains and intelligent agents built on any LLM framework and seamlessly integrates with LangChain, the go-to open source framework for building with LLMs.\n Quick Start\u200b\nIf following along with code is more your thing, we've set up a Jupyter notebook at this link to help you get started with LangSmith.\n LangChain JS Docs for the TypeScript LangChain library\nDiscord: Join us on our Discord to discuss all things LangChain!\n Next Steps\u200b\nRead the LangSmith Overview to learn more about what LangSmith has to offer.\n", metadata={'title': 'LangSmith | ️ ️ LangSmith', 'source': 'https://docs.smith.langchain.com/', 'score': 0.93028, 'images': None}),
#                         Document(page_content='This function helps to load the specific language models and tools required for the task as shown in the code snippet below:\nAs a next step, initialize an agent by calling the initialize_agent function with several parameters like tools, llms, and agent:\nThe verbose parameter is set to false, indicating that the agent will not provide verbose or detailed output.\n You can accomplish this by following the shell commands provided below:\nCreating a LangSmith client\nNext, create a LangSmith client to interact with the API:\nIf you’re using Python, run the following commands to import the module:\n This code also handles exceptions that may occur during the agent execution:\nIt’s also important to call the wait_for_all_tracers function from the langchain.callbacks.tracers.langchain module as shown in the code snippet below:\nCalling the wait_for_all_tracers function helps ensure that logs and traces are submitted in full before the program proceeds. The temperature parameter will be set to 0, implying that the generated response will be more deterministic as shown in the code snippet below:\nNow, let’s call the load_tools function with a list of tool APIs, such as serpapi and llm-math, and also take the llm instance as a parameter. It initializes a chat model, loads specific tools, and creates an agent that can generate responses based on descriptions:\nInput processing with exception handling\nThe code below defines a list of input examples using the asyncio library to asynchronously run the agent on each input and gather the results for further processing.', metadata={'title': 'Using LangSmith to test LLMs and AI applications', 'source': 'https://blog.logrocket.com/langsmith-test-llms-ai-applications/', 'score': 0.9277, 'images': None}),
#                         Document(page_content='LangSmith helps you trace and evaluate your language model applications and intelligent agents to help you move from prototype to production. Check out the interactive walkthrough to get started. For more information, please refer to the LangSmith documentation.', metadata={'title': 'LangSmith | ️ Langchain', 'source': 'https://python.langchain.com/docs/langsmith/', 'score': 0.92043, 'images': None}),
#                         Document(page_content='But what are the production challenges that need to be solved which were not as relevant in prototyping?\nReliability — it is deceptively easy to build something that works well for a simple constrained example but actually still quite hard today to build LLM applications with the consistency that most companies would want.\n for tools\nKim Seon Woo - Nov 6\nComo deixar o Swagger com tema dark mode usando NestJS\nWiliam V. Joaquim - Nov 5\nData visualizing\nBIRINGANINE BASEME Destin\n- Oct 7\nFree Face-Swap AI 🎭 with Source Code for Web and Mobile App.\nshadee22 - As you build more complex workflows, it can be hard to understand exactly what queries are moving through different flows so a simple UI to see this and log the historical data is going to be a value add from day one.\n A huge part of the value add for LangSmith is being able to do all of these things from a simple and intuitive UI which significantly reduces the barrier to entry for those without a software background.\n [Quick note: I am writing this article to reflect my personal views as I explore the LLM ecosystem and this is not intended to represent the views of my employer, hence being on my personal blog]\nWhat is LangSmith?', metadata={'title': 'What is LangSmith and why should I care as a developer?', 'source': 'https://dev.to/logankilpatrick/what-is-langsmith-and-why-should-i-care-as-a-developer-19k', 'score': 0.91222, 'images': None}),
#                         Document(page_content='We consistently see developers relying on LangSmith to track the system-level performance of their application (like latency and cost), track the model/chain performance (through associating feedback with runs), debug issues (diving into a particular run that went wrong), and establish a broad understanding of how users are interacting with their application and what their experience is like.\n Over the last few months, we’ve been working directly with some early design partners and testing it on our own internal workflows, and we’ve found LangSmith helps teams in 5 core ways:\nDebugging\nLangSmith gives you full visibility into model inputs and output of every step in the chain of events. As a very simple example, we considered it to be table stakes for LangSmith to help users easily create datasets from existing logs and use them immediately for testing and evaluation, seamlessly connecting the logging/debugging workflows to the testing/evaluation ones.\n A unified platform\nWhile each of these product areas provide unique value, often at a specific point in time in the development process, we believe a great deal of the long term impact of LangSmith will come from having a single, fully-integrated hub to do this work from. Additionally, tracing and evaluating the complex agent prompt chains is much easier, reducing the time required to debug and refine our prompts, and giving us the confidence to move to deployment.”\n', metadata={'title': 'Announcing LangSmith, a unified platform for debugging, testing ...', 'source': 'https://blog.langchain.dev/announcing-langsmith/', 'score': 0.87879, 'images': None}),
#                         Document(page_content='This will:\nThe results will be visible in the LangSmith app.\nReview the test results\u200b\nYou can review the test results tracing UI below by clicking the URL in the output above or navigating to the "Testing & Datasets" page in LangSmith\n"agent-qa-{unique_id}" dataset.\n Below, we will create some pre-implemented run evaluators that do the following:\nFor a longer discussion of how to select an appropriate evaluator for your use case and how to create your own\ncustom evaluators, please refer to the LangSmith documentation.\n For more information on datasets, including how to create them from CSVs or other files or how to create them in the platform, please refer to the LangSmith documentation.\n Create the langsmith client to interact with the API\nCreate a LangChain component and log runs to the platform. Create a LangSmith dataset\u200b\nBelow, we use the LangSmith client to create a dataset from the input questions from above and a list labels.', metadata={'title': 'LangSmith Walkthrough | ️ Langchain', 'source': 'https://python.langchain.com/docs/langsmith/walkthrough', 'score': 0.86395, 'images': None}),
#                         Document(page_content='The Run tab for the top-level chain shows the human input, the parsed output, the latency (under a second), and the tokens used, as well as the clock time and call status.\n The cookbook covers tracing your code without LangChain (using the @traceable decorator); using the LangChain Hub to discover, share, and version control prompts; testing and benchmarking your LLM systems in Python and TypeScript or JavaScript; using user feedback to improve, monitor, and personalize your applications; exporting data for fine-tuning; and exporting your run data for exploratory data analysis.\n In addition to the input variables (prompt), an LLM call uses a template and often auxiliary functions; for example, retrieval of information from the web, uploaded files, and system prompts that set the context for the LLM.\n After I set up my LangSmith account, created my API key, updated my LangChain installation with pip, and set up my shell environment variables, I tried to run the Python quickstart application:\nBefore we discuss the results, take a look at the LangSmith hub:\nFigure 1. Here are the evaluation statistics, which were printed in the terminal during the run:\nSomebody had fun creating the rap battle prompts, as shown in the dataset below:\nFigure 9.', metadata={'title': 'What is LangSmith? Tracing and debugging for LLMs | InfoWorld', 'source': 'https://www.infoworld.com/article/3708628/what-is-langsmith-tracing-and-debugging-for-llms.html', 'score': 0.82697, 'images': None})]}})RunLogPatch({'op': 'add',
#   'path': '/logs/RunnableSequence/final_output',
# ...
#   'path': '/logs/ChatOpenAI/streamed_output_str/-',
#   'value': ' perform'},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI/streamed_output/-',
#   'value': AIMessageChunk(content=' perform')})RunLogPatch({'op': 'add',
#   'path': '/logs/StrOutputParser/streamed_output/-',
#   'value': ' these'})RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': ' these'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': 'LangSmith is a developer platform and tool that helps trace, '
#            'evaluate, debug, test, and monitor language model applications and '
#            'intelligent agents built on any LLM (Large Language Model) '
#            'framework. It seamlessly integrates with LangChain, an open-source '
#            'framework for building with LLMs. LangSmith provides features such '
#            'as cross-team collaboration, catalog of ranging models and tasks, '
#            'proven prompting strategies, performance comparison, dataset '
#            'curation, and more. It also offers a simple and intuitive UI to '
#            'perform these'})RunLogPatch({'op': 'add',
#   'path': '/logs/ChatOpenAI/streamed_output_str/-',
#   'value': ' these'},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI/streamed_output/-',
#   'value': AIMessageChunk(content=' these')})RunLogPatch({'op': 'add',
#   'path': '/logs/StrOutputParser/streamed_output/-',
#   'value': ' tasks'})RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': ' tasks'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': 'LangSmith is a developer platform and tool that helps trace, '
#            'evaluate, debug, test, and monitor language model applications and '
#            'intelligent agents built on any LLM (Large Language Model) '
#            'framework. It seamlessly integrates with LangChain, an open-source '
#            'framework for building with LLMs. LangSmith provides features such '
#            'as cross-team collaboration, catalog of ranging models and tasks, '
#            'proven prompting strategies, performance comparison, dataset '
#            'curation, and more. It also offers a simple and intuitive UI to '
#            'perform these tasks'})RunLogPatch({'op': 'add',
#   'path': '/logs/ChatOpenAI/streamed_output_str/-',
#   'value': ' tasks'},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI/streamed_output/-',
#   'value': AIMessageChunk(content=' tasks')})RunLogPatch({'op': 'add', 'path': '/logs/StrOutputParser/streamed_output/-', 'value': ','})RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': ','},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': 'LangSmith is a developer platform and tool that helps trace, '
#            'evaluate, debug, test, and monitor language model applications and '
#            'intelligent agents built on any LLM (Large Language Model) '
#            'framework. It seamlessly integrates with LangChain, an open-source '
#            'framework for building with LLMs. LangSmith provides features such '
#            'as cross-team collaboration, catalog of ranging models and tasks, '
#            'proven prompting strategies, performance comparison, dataset '
#            'curation, and more. It also offers a simple and intuitive UI to '
#            'perform these tasks,'})RunLogPatch({'op': 'add', 'path': '/logs/ChatOpenAI/streamed_output_str/-', 'value': ','},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI/streamed_output/-',
#   'value': AIMessageChunk(content=',')})RunLogPatch({'op': 'add',
#   'path': '/logs/StrOutputParser/streamed_output/-',
#   'value': ' reducing'})RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': ' reducing'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': 'LangSmith is a developer platform and tool that helps trace, '
#            'evaluate, debug, test, and monitor language model applications and '
#            'intelligent agents built on any LLM (Large Language Model) '
#            'framework. It seamlessly integrates with LangChain, an open-source '
#            'framework for building with LLMs. LangSmith provides features such '
#            'as cross-team collaboration, catalog of ranging models and tasks, '
#            'proven prompting strategies, performance comparison, dataset '
#            'curation, and more. It also offers a simple and intuitive UI to '
#            'perform these tasks, reducing'})RunLogPatch({'op': 'add',
#   'path': '/logs/ChatOpenAI/streamed_output_str/-',
#   'value': ' reducing'},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI/streamed_output/-',
#   'value': AIMessageChunk(content=' reducing')})RunLogPatch({'op': 'add',
#   'path': '/logs/StrOutputParser/streamed_output/-',
#   'value': ' the'})RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': ' the'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': 'LangSmith is a developer platform and tool that helps trace, '
#            'evaluate, debug, test, and monitor language model applications and '
#            'intelligent agents built on any LLM (Large Language Model) '
#            'framework. It seamlessly integrates with LangChain, an open-source '
#            'framework for building with LLMs. LangSmith provides features such '
#            'as cross-team collaboration, catalog of ranging models and tasks, '
#            'proven prompting strategies, performance comparison, dataset '
#            'curation, and more. It also offers a simple and intuitive UI to '
#            'perform these tasks, reducing the'})RunLogPatch({'op': 'add',
#   'path': '/logs/ChatOpenAI/streamed_output_str/-',
#   'value': ' the'},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI/streamed_output/-',
#   'value': AIMessageChunk(content=' the')})RunLogPatch({'op': 'add',
#   'path': '/logs/StrOutputParser/streamed_output/-',
#   'value': ' barrier'})RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': ' barrier'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': 'LangSmith is a developer platform and tool that helps trace, '
#            'evaluate, debug, test, and monitor language model applications and '
#            'intelligent agents built on any LLM (Large Language Model) '
#            'framework. It seamlessly integrates with LangChain, an open-source '
#            'framework for building with LLMs. LangSmith provides features such '
#            'as cross-team collaboration, catalog of ranging models and tasks, '
#            'proven prompting strategies, performance comparison, dataset '
#            'curation, and more. It also offers a simple and intuitive UI to '
#            'perform these tasks, reducing the barrier'})RunLogPatch({'op': 'add',
#   'path': '/logs/ChatOpenAI/streamed_output_str/-',
#   'value': ' barrier'},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI/streamed_output/-',
#   'value': AIMessageChunk(content=' barrier')})RunLogPatch({'op': 'add',
#   'path': '/logs/StrOutputParser/streamed_output/-',
#   'value': ' to'})RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': ' to'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': 'LangSmith is a developer platform and tool that helps trace, '
#            'evaluate, debug, test, and monitor language model applications and '
#            'intelligent agents built on any LLM (Large Language Model) '
#            'framework. It seamlessly integrates with LangChain, an open-source '
#            'framework for building with LLMs. LangSmith provides features such '
#            'as cross-team collaboration, catalog of ranging models and tasks, '
#            'proven prompting strategies, performance comparison, dataset '
#            'curation, and more. It also offers a simple and intuitive UI to '
#            'perform these tasks, reducing the barrier to'})RunLogPatch({'op': 'add',
#   'path': '/logs/ChatOpenAI/streamed_output_str/-',
#   'value': ' to'},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI/streamed_output/-',
#   'value': AIMessageChunk(content=' to')})RunLogPatch({'op': 'add',
#   'path': '/logs/StrOutputParser/streamed_output/-',
#   'value': ' entry'})RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': ' entry'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': 'LangSmith is a developer platform and tool that helps trace, '
#            'evaluate, debug, test, and monitor language model applications and '
#            'intelligent agents built on any LLM (Large Language Model) '
#            'framework. It seamlessly integrates with LangChain, an open-source '
#            'framework for building with LLMs. LangSmith provides features such '
#            'as cross-team collaboration, catalog of ranging models and tasks, '
#            'proven prompting strategies, performance comparison, dataset '
#            'curation, and more. It also offers a simple and intuitive UI to '
#            'perform these tasks, reducing the barrier to entry'})RunLogPatch({'op': 'add',
#   'path': '/logs/ChatOpenAI/streamed_output_str/-',
#   'value': ' entry'},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI/streamed_output/-',
#   'value': AIMessageChunk(content=' entry')})RunLogPatch({'op': 'add',
#   'path': '/logs/StrOutputParser/streamed_output/-',
#   'value': ' for'})RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': ' for'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': 'LangSmith is a developer platform and tool that helps trace, '
#            'evaluate, debug, test, and monitor language model applications and '
#            'intelligent agents built on any LLM (Large Language Model) '
#            'framework. It seamlessly integrates with LangChain, an open-source '
#            'framework for building with LLMs. LangSmith provides features such '
#            'as cross-team collaboration, catalog of ranging models and tasks, '
#            'proven prompting strategies, performance comparison, dataset '
#            'curation, and more. It also offers a simple and intuitive UI to '
#            'perform these tasks, reducing the barrier to entry for'})RunLogPatch({'op': 'add',
#   'path': '/logs/ChatOpenAI/streamed_output_str/-',
#   'value': ' for'},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI/streamed_output/-',
#   'value': AIMessageChunk(content=' for')})RunLogPatch({'op': 'add',
#   'path': '/logs/StrOutputParser/streamed_output/-',
#   'value': ' developers'})RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': ' developers'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': 'LangSmith is a developer platform and tool that helps trace, '
#            'evaluate, debug, test, and monitor language model applications and '
#            'intelligent agents built on any LLM (Large Language Model) '
#            'framework. It seamlessly integrates with LangChain, an open-source '
#            'framework for building with LLMs. LangSmith provides features such '
#            'as cross-team collaboration, catalog of ranging models and tasks, '
#            'proven prompting strategies, performance comparison, dataset '
#            'curation, and more. It also offers a simple and intuitive UI to '
#            'perform these tasks, reducing the barrier to entry for developers'})RunLogPatch({'op': 'add',
#   'path': '/logs/ChatOpenAI/streamed_output_str/-',
#   'value': ' developers'},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI/streamed_output/-',
#   'value': AIMessageChunk(content=' developers')})RunLogPatch({'op': 'add', 'path': '/logs/StrOutputParser/streamed_output/-', 'value': '.'})RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': '.'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': 'LangSmith is a developer platform and tool that helps trace, '
#            'evaluate, debug, test, and monitor language model applications and '
#            'intelligent agents built on any LLM (Large Language Model) '
#            'framework. It seamlessly integrates with LangChain, an open-source '
#            'framework for building with LLMs. LangSmith provides features such '
#            'as cross-team collaboration, catalog of ranging models and tasks, '
#            'proven prompting strategies, performance comparison, dataset '
#            'curation, and more. It also offers a simple and intuitive UI to '
#            'perform these tasks, reducing the barrier to entry for '
#            'developers.'})RunLogPatch({'op': 'add', 'path': '/logs/ChatOpenAI/streamed_output_str/-', 'value': '.'},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI/streamed_output/-',
#   'value': AIMessageChunk(content='.')})RunLogPatch({'op': 'add', 'path': '/logs/StrOutputParser/streamed_output/-', 'value': ''})RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': ''})RunLogPatch({'op': 'add', 'path': '/logs/ChatOpenAI/streamed_output_str/-', 'value': ''},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI/streamed_output/-',
#   'value': AIMessageChunk(content='')})RunLogPatch({'op': 'add',
#   'path': '/logs/ChatOpenAI/final_output',
#   'value': {'generations': [[{'generation_info': {'finish_reason': 'stop'},
#                               'message': AIMessageChunk(content='LangSmith is a developer platform and tool that helps trace, evaluate, debug, test, and monitor language model applications and intelligent agents built on any LLM (Large Language Model) framework. It seamlessly integrates with LangChain, an open-source framework for building with LLMs. LangSmith provides features such as cross-team collaboration, catalog of ranging models and tasks, proven prompting strategies, performance comparison, dataset curation, and more. It also offers a simple and intuitive UI to perform these tasks, reducing the barrier to entry for developers.'),
#                               'text': 'LangSmith is a developer platform and '
#                                       'tool that helps trace, evaluate, debug, '
#                                       'test, and monitor language model '
#                                       'applications and intelligent agents '
#                                       'built on any LLM (Large Language Model) '
#                                       'framework. It seamlessly integrates '
#                                       'with LangChain, an open-source '
#                                       'framework for building with LLMs. '
#                                       'LangSmith provides features such as '
#                                       'cross-team collaboration, catalog of '
#                                       'ranging models and tasks, proven '
#                                       'prompting strategies, performance '
#                                       'comparison, dataset curation, and more. '
#                                       'It also offers a simple and intuitive '
#                                       'UI to perform these tasks, reducing the '
#                                       'barrier to entry for developers.',
#                               'type': 'ChatGenerationChunk'}]],
#             'llm_output': None,
#             'run': None}},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI/end_time',
#   'value': '2024-01-14T11:04:50.691+00:00'})RunLogPatch({'op': 'add',
#   'path': '/logs/StrOutputParser/final_output',
#   'value': {'output': 'LangSmith is a developer platform and tool that helps '
#                       'trace, evaluate, debug, test, and monitor language '
#                       'model applications and intelligent agents built on any '
#                       'LLM (Large Language Model) framework. It seamlessly '
#                       'integrates with LangChain, an open-source framework for '
#                       'building with LLMs. LangSmith provides features such as '
#                       'cross-team collaboration, catalog of ranging models and '
#                       'tasks, proven prompting strategies, performance '
#                       'comparison, dataset curation, and more. It also offers '
#                       'a simple and intuitive UI to perform these tasks, '
#                       'reducing the barrier to entry for developers.'}},
#  {'op': 'add',
#   'path': '/logs/StrOutputParser/end_time',
#   'value': '2024-01-14T11:04:50.699+00:00'})

# %%
async for s in retrieval_chain.astream_log({"question": "what is langsmith"}, include_names=["Docs"]):
    print(s, end="")
# Out:
# RunLogPatch({'op': 'replace',
#   'path': '',
#   'value': {'final_output': None,
#             'id': '559e6038-da33-4a31-9eda-e0ae2ff42768',
#             'logs': {},
#             'streamed_output': []}})RunLogPatch({'op': 'add',
#   'path': '/logs/Docs',
#   'value': {'end_time': None,
#             'final_output': None,
#             'id': '791f30f5-ca81-4244-81b2-00c829ba6be9',
#             'metadata': {},
#             'name': 'Docs',
#             'start_time': '2024-01-14T11:06:31.322+00:00',
#             'streamed_output': [],
#             'streamed_output_str': [],
#             'tags': ['seq:step:2'],
#             'type': 'retriever'}})RunLogPatch({'op': 'add',
#   'path': '/logs/Docs/final_output',
#   'value': {'documents': [Document(page_content='LangSmith helps you trace and evaluate your language model applications and intelligent agents to help you move from prototype to production. Check out the interactive walkthrough to get started. For more information, please refer to the LangSmith documentation.', metadata={'title': 'LangSmith | ️ Langchain', 'source': 'https://python.langchain.com/docs/langsmith/', 'score': 0.94543, 'images': None}),
#                           Document(page_content="If you already use LangChain, you can connect to LangSmith in a few steps:\nFor environments where process.env is not defined, initialize by explicitly passing keys:\nIf you don't want to use LangChain in your LLM application, you can get started with LangSmith in just a few steps:\nCongratulations! It lets you debug, test, evaluate, and monitor chains and intelligent agents built on any LLM framework and seamlessly integrates with LangChain, the go-to open source framework for building with LLMs.\n Quick Start\u200b\nIf following along with code is more your thing, we've set up a Jupyter notebook at this link to help you get started with LangSmith.\n LangChain JS Docs for the TypeScript LangChain library\nDiscord: Join us on our Discord to discuss all things LangChain!\n Next Steps\u200b\nRead the LangSmith Overview to learn more about what LangSmith has to offer.\n", metadata={'title': 'LangSmith | ️ ️ LangSmith', 'source': 'https://docs.smith.langchain.com/', 'score': 0.94524, 'images': None}),
#                           Document(page_content='But what are the production challenges that need to be solved which were not as relevant in prototyping?\nReliability — it is deceptively easy to build something that works well for a simple constrained example but actually still quite hard today to build LLM applications with the consistency that most companies would want.\n for tools\nKim Seon Woo - Nov 6\nComo deixar o Swagger com tema dark mode usando NestJS\nWiliam V. Joaquim - Nov 5\nData visualizing\nBIRINGANINE BASEME Destin\n- Oct 7\nFree Face-Swap AI 🎭 with Source Code for Web and Mobile App.\nshadee22 - As you build more complex workflows, it can be hard to understand exactly what queries are moving through different flows so a simple UI to see this and log the historical data is going to be a value add from day one.\n A huge part of the value add for LangSmith is being able to do all of these things from a simple and intuitive UI which significantly reduces the barrier to entry for those without a software background.\n [Quick note: I am writing this article to reflect my personal views as I explore the LLM ecosystem and this is not intended to represent the views of my employer, hence being on my personal blog]\nWhat is LangSmith?', metadata={'title': 'What is LangSmith and why should I care as a developer?', 'source': 'https://dev.to/logankilpatrick/what-is-langsmith-and-why-should-i-care-as-a-developer-19k', 'score': 0.94291, 'images': None}),
#                           Document(page_content='This function helps to load the specific language models and tools required for the task as shown in the code snippet below:\nAs a next step, initialize an agent by calling the initialize_agent function with several parameters like tools, llms, and agent:\nThe verbose parameter is set to false, indicating that the agent will not provide verbose or detailed output.\n You can accomplish this by following the shell commands provided below:\nCreating a LangSmith client\nNext, create a LangSmith client to interact with the API:\nIf you’re using Python, run the following commands to import the module:\n This code also handles exceptions that may occur during the agent execution:\nIt’s also important to call the wait_for_all_tracers function from the langchain.callbacks.tracers.langchain module as shown in the code snippet below:\nCalling the wait_for_all_tracers function helps ensure that logs and traces are submitted in full before the program proceeds. The temperature parameter will be set to 0, implying that the generated response will be more deterministic as shown in the code snippet below:\nNow, let’s call the load_tools function with a list of tool APIs, such as serpapi and llm-math, and also take the llm instance as a parameter. It initializes a chat model, loads specific tools, and creates an agent that can generate responses based on descriptions:\nInput processing with exception handling\nThe code below defines a list of input examples using the asyncio library to asynchronously run the agent on each input and gather the results for further processing.', metadata={'title': 'Using LangSmith to test LLMs and AI applications', 'source': 'https://blog.logrocket.com/langsmith-test-llms-ai-applications/', 'score': 0.93399, 'images': None}),
#                           Document(page_content="BETA Sign Up\nContact Sales\nProducts and use-cases\nLangChain\nLangSmith\nRetrieval\nAgents\nInspiration\nCode\nGitHub\nLangChain Hub\nPython Docs\nJS/TS Docs\nSocial\nTwitter\nDiscord\nBlog\nLinkedIn\nYouTube\nTerms of Service\nSign up for our newsletter\nProducts and use-cases\nLangChain\nLangSmith\nRetrieval\nAgents\nInspiration\nCode\nGitHub\nLangChain Hub\nPython Docs\nJS/TS Docs\nSocial\nTwitter\nDiscord\nBlog\nLinkedIn\nYouTube\nTerms of Service\nSign up for our newsletter\nProducts and use-cases\nLangChain\nLangSmith\nRetrieval\nAgents\nInspiration\nCode\nGitHub\nLangChain Hub\nPython Docs\nJS/TS Docs\nSocial\nTwitter\nDiscord\nBlog\nLinkedIn\nYouTube\nTerms of Service\nSign up for our newsletter 🦜🔗 LangChain\nLangSmith\nLangServe\nAgents\nRetrieval\nEvaluation\nBlog\nDocs\n🦜🔗 LangChain\nBuild and deploy LLM apps with confidence\nAn all-in-one developer platform for every step of the application lifecycle.\n Prompt playground\nCross-team collaboration\nCatalog of ranging models & tasks\nProven prompting strategies\nExplore LangChain Hub\nTurn the magic of LLM applications into enterprise-ready products\nNative collaboration\nBring your team together in LangSmith to craft prompts, debug, and capture feedback.\n Application-level usage stats\nFeedback collection\nFilter traces\nCost measurement\nPerformance comparison\nGo To Docs\nManage Prompts\nPrompts power your team's chains and agents, and LangSmith allows you to refine, test, and version them in one place. Dataset curation\nEvaluate chain performance\nAI-assisted evaluation\nEasy benchmarking\nGo To Docs\nMonitor\nGiven the stochastic nature of LLMs, it can be hard to answer the simple question: “what’s happening with my application?”", metadata={'title': 'LangSmith', 'source': 'https://www.langchain.com/langsmith', 'score': 0.92747, 'images': None}),
#                           Document(page_content='The Run tab for the top-level chain shows the human input, the parsed output, the latency (under a second), and the tokens used, as well as the clock time and call status.\n The cookbook covers tracing your code without LangChain (using the @traceable decorator); using the LangChain Hub to discover, share, and version control prompts; testing and benchmarking your LLM systems in Python and TypeScript or JavaScript; using user feedback to improve, monitor, and personalize your applications; exporting data for fine-tuning; and exporting your run data for exploratory data analysis.\n In addition to the input variables (prompt), an LLM call uses a template and often auxiliary functions; for example, retrieval of information from the web, uploaded files, and system prompts that set the context for the LLM.\n After I set up my LangSmith account, created my API key, updated my LangChain installation with pip, and set up my shell environment variables, I tried to run the Python quickstart application:\nBefore we discuss the results, take a look at the LangSmith hub:\nFigure 1. Here are the evaluation statistics, which were printed in the terminal during the run:\nSomebody had fun creating the rap battle prompts, as shown in the dataset below:\nFigure 9.', metadata={'title': 'What is LangSmith? Tracing and debugging for LLMs | InfoWorld', 'source': 'https://www.infoworld.com/article/3708628/what-is-langsmith-tracing-and-debugging-for-llms.html', 'score': 0.87276, 'images': None}),
#                           Document(page_content="This was such an important unlock for us as we build in tactical functionality to our AI.\nAdvice for Product Teams Considering LangSmith\nWhen you're in the thick of product development, the whirlwind of AI and LLMs can be overwhelming. ou can now clearly see the citations coming through with the responses in the traces, and we’re good to ship the changes to the prompt to prod.\n We do this primarily to legitimize the LLMs response and give our HelpHub customer’s peace of mind that their end users are in fact getting to the help resource they need (instead of an LLM just hallucinating and giving any response it wants.)\n Take it from us, as we integrated AI more heavily and widely across our products, we’ve been more conscious than ever that the quality of the outputs matches the quality and trust that our customers have in our product. We updated our prompt to be more firm when asking for the sources:\nWe then tested everything using LangSmith evals, to make sure that it fixes the issue before pushing to production.\n", metadata={'title': 'Peering Into the Soul of AI Decision-Making with LangSmith', 'source': 'https://blog.langchain.dev/peering-into-the-soul-of-ai-decision-making-with-langsmith/', 'score': 0.86357, 'images': None}),
#                           Document(page_content='We consistently see developers relying on LangSmith to track the system-level performance of their application (like latency and cost), track the model/chain performance (through associating feedback with runs), debug issues (diving into a particular run that went wrong), and establish a broad understanding of how users are interacting with their application and what their experience is like.\n Over the last few months, we’ve been working directly with some early design partners and testing it on our own internal workflows, and we’ve found LangSmith helps teams in 5 core ways:\nDebugging\nLangSmith gives you full visibility into model inputs and output of every step in the chain of events. As a very simple example, we considered it to be table stakes for LangSmith to help users easily create datasets from existing logs and use them immediately for testing and evaluation, seamlessly connecting the logging/debugging workflows to the testing/evaluation ones.\n A unified platform\nWhile each of these product areas provide unique value, often at a specific point in time in the development process, we believe a great deal of the long term impact of LangSmith will come from having a single, fully-integrated hub to do this work from. Additionally, tracing and evaluating the complex agent prompt chains is much easier, reducing the time required to debug and refine our prompts, and giving us the confidence to move to deployment.”\n', metadata={'title': 'Announcing LangSmith, a unified platform for debugging, testing ...', 'source': 'https://blog.langchain.dev/announcing-langsmith/', 'score': 0.8613, 'images': None}),
#                           Document(page_content='A deep dive into the latest product from the creators of LangChain 🦜\n--\n3\nCobus Greyling\nLangSmith\nI was fortunate to get early access to the LangSmith platform and in this article you will find practical code examples and demonstration…\n--\nLists\nNatural Language Processing\nPredictive Modeling w/ Python\nAI Regulation\nPractical Guides to Machine Learning\nYule Wang, PhD\nA Complete Guide to LLMs-based Autonomous Agents (Part I):\n—\u200a—\u200aChain of Thought, Plan and Solve/Execute, Self-Ask, ReAct, Reflexion, Self-Consistency, Tree of Thoughts and Graph of Thoughts\n--\n1\nRyan Nguyen\nin\nBetter Programming\nLlamaIndex: How To Evaluate Your RAG (Retrieval Augmented Generation) Applications\nClassic 10k reports with Australian real estate market reports to demonstrate the end-to-end evaluation process\n--\n2\nKelvin Lu\nTracing How LangChain Works Behind the Scenes\nIntroduction of LLM Tracing technique with both LangChain built-in tracing funciton and LangChain Visualizer.\n --\nCameron R. Wolfe, Ph.D.\nin\nTowards Data Science\nChain of Thought Prompting for LLMs\nA practical and simple approach for “reasoning” with LLMs\n--\nHelp\nStatus\nAbout\nCareers\nBlog\nPrivacy\nTerms\nText to speech\nTeams A Step-by-Step Guide to Deploying ChromaDB in the Cloud\n--\nBenoit Ruiz\nin\nBetter Programming\nAdvice From a Software Engineer With 8 Years of Experience\nPractical tips for those who want to advance in their careers\n--\n233\nVinita\nin\nBetter Programming\n4 Strategies to Give Effective Feedback to a Difficult Person\nRespect is like air. But if you take it away, it’s all that people can think about.\n--\n21\nRicardo Ledan\nin\nBetter Programming\nBuilding Context-Aware Question-Answering Systems With LLMs\nA step-by-step guide to using embeddings, vector search, and prompt engineering for building context-aware question-answering systems\n--\n1\nRecommended from Medium\nLogan Kilpatrick\nWhat is LangSmith and why should I care as a developer?\n Ricardo Ledan\nFollow\nBetter Programming\n--\nShare\nWhat is LangSmith?\n', metadata={'title': 'The Art of LangSmithing - Better Programming', 'source': 'https://betterprogramming.pub/the-art-of-langsmithing-42dcd191a220', 'score': 0.85673, 'images': None}),
#                           Document(page_content='This will:\nThe results will be visible in the LangSmith app.\nReview the test results\u200b\nYou can review the test results tracing UI below by clicking the URL in the output above or navigating to the "Testing & Datasets" page in LangSmith\n"agent-qa-{unique_id}" dataset.\n Below, we will create some pre-implemented run evaluators that do the following:\nFor a longer discussion of how to select an appropriate evaluator for your use case and how to create your own\ncustom evaluators, please refer to the LangSmith documentation.\n For more information on datasets, including how to create them from CSVs or other files or how to create them in the platform, please refer to the LangSmith documentation.\n Create the langsmith client to interact with the API\nCreate a LangChain component and log runs to the platform. Create a LangSmith dataset\u200b\nBelow, we use the LangSmith client to create a dataset from the input questions from above and a list labels.', metadata={'title': 'LangSmith Walkthrough | ️ Langchain', 'source': 'https://python.langchain.com/docs/langsmith/walkthrough', 'score': 0.80211, 'images': None})]}},
#  {'op': 'add',
#   'path': '/logs/Docs/end_time',
#   'value': '2024-01-14T11:06:33.073+00:00'})
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': ''},
#  {'op': 'replace', 'path': '/final_output', 'value': ''})RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': 'Lang'},
#  {'op': 'replace', 'path': '/final_output', 'value': 'Lang'})RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': 'Smith'},
#  {'op': 'replace', 'path': '/final_output', 'value': 'LangSmith'})RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': ' is'},
#  {'op': 'replace', 'path': '/final_output', 'value': 'LangSmith is'})RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': ' a'},
#  {'op': 'replace', 'path': '/final_output', 'value': 'LangSmith is a'})RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': ' platform'},
#  {'op': 'replace', 'path': '/final_output', 'value': 'LangSmith is a platform'})RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': ' that'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': 'LangSmith is a platform that'})RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': ' helps'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': 'LangSmith is a platform that helps'})RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': ' trace'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': 'LangSmith is a platform that helps trace'})RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': ' and'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': 'LangSmith is a platform that helps trace and'})RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': ' evaluate'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': 'LangSmith is a platform that helps trace and evaluate'})RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': ' language'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': 'LangSmith is a platform that helps trace and evaluate language'})RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': ' model'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': 'LangSmith is a platform that helps trace and evaluate language '
#            'model'})RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': ' applications'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': 'LangSmith is a platform that helps trace and evaluate language '
#            'model applications'})RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': ' and'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': 'LangSmith is a platform that helps trace and evaluate language '
#            'model applications and'})RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': ' intelligent'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': 'LangSmith is a platform that helps trace and evaluate language '
#            'model applications and intelligent'})RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': ' agents'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': 'LangSmith is a platform that helps trace and evaluate language '
#            'model applications and intelligent agents'})RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': ','},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': 'LangSmith is a platform that helps trace and evaluate language '
#            'model applications and intelligent agents,'})RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': ' allowing'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': 'LangSmith is a platform that helps trace and evaluate language '
#            'model applications and intelligent agents, allowing'})RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': ' users'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': 'LangSmith is a platform that helps trace and evaluate language '
#            'model applications and intelligent agents, allowing users'})RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': ' to'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': 'LangSmith is a platform that helps trace and evaluate language '
#            'model applications and intelligent agents, allowing users to'})RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': ' move'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': 'LangSmith is a platform that helps trace and evaluate language '
#            'model applications and intelligent agents, allowing users to move'})RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': ' from'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': 'LangSmith is a platform that helps trace and evaluate language '
#            'model applications and intelligent agents, allowing users to move '
#            'from'})RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': ' prototype'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': 'LangSmith is a platform that helps trace and evaluate language '
#            'model applications and intelligent agents, allowing users to move '
#            'from prototype'})RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': ' to'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': 'LangSmith is a platform that helps trace and evaluate language '
#            'model applications and intelligent agents, allowing users to move '
#            'from prototype to'})RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': ' production'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': 'LangSmith is a platform that helps trace and evaluate language '
#            'model applications and intelligent agents, allowing users to move '
#            'from prototype to production'})RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': '.'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': 'LangSmith is a platform that helps trace and evaluate language '
#            'model applications and intelligent agents, allowing users to move '
#            'from prototype to production.'})RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': ' It'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': 'LangSmith is a platform that helps trace and evaluate language '
#            'model applications and intelligent agents, allowing users to move '
#            'from prototype to production. It'})RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': ' offers'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': 'LangSmith is a platform that helps trace and evaluate language '
#            'model applications and intelligent agents, allowing users to move '
#            'from prototype to production. It offers'})RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': ' features'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': 'LangSmith is a platform that helps trace and evaluate language '
#            'model applications and intelligent agents, allowing users to move '
#            'from prototype to production. It offers features'})RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': ' such'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': 'LangSmith is a platform that helps trace and evaluate language '
#            'model applications and intelligent agents, allowing users to move '
#            'from prototype to production. It offers features such'})RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': ' as'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': 'LangSmith is a platform that helps trace and evaluate language '
#            'model applications and intelligent agents, allowing users to move '
#            'from prototype to production. It offers features such as'})RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': ' debugging'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': 'LangSmith is a platform that helps trace and evaluate language '
#            'model applications and intelligent agents, allowing users to move '
#            'from prototype to production. It offers features such as '
#            'debugging'})RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': ','},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': 'LangSmith is a platform that helps trace and evaluate language '
#            'model applications and intelligent agents, allowing users to move '
#            'from prototype to production. It offers features such as '
#            'debugging,'})RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': ' testing'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': 'LangSmith is a platform that helps trace and evaluate language '
#            'model applications and intelligent agents, allowing users to move '
#            'from prototype to production. It offers features such as '
#            'debugging, testing'})RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': ','},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': 'LangSmith is a platform that helps trace and evaluate language '
#            'model applications and intelligent agents, allowing users to move '
#            'from prototype to production. It offers features such as '
#            'debugging, testing,'})RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': ' evaluating'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': 'LangSmith is a platform that helps trace and evaluate language '
#            'model applications and intelligent agents, allowing users to move '
#            'from prototype to production. It offers features such as '
#            'debugging, testing, evaluating'})RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': ','},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': 'LangSmith is a platform that helps trace and evaluate language '
#            'model applications and intelligent agents, allowing users to move '
#            'from prototype to production. It offers features such as '
#            'debugging, testing, evaluating,'})RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': ' and'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': 'LangSmith is a platform that helps trace and evaluate language '
#            'model applications and intelligent agents, allowing users to move '
#            'from prototype to production. It offers features such as '
#            'debugging, testing, evaluating, and'})RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': ' monitoring'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': 'LangSmith is a platform that helps trace and evaluate language '
#            'model applications and intelligent agents, allowing users to move '
#            'from prototype to production. It offers features such as '
#            'debugging, testing, evaluating, and monitoring'})RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': ' chains'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': 'LangSmith is a platform that helps trace and evaluate language '
#            'model applications and intelligent agents, allowing users to move '
#            'from prototype to production. It offers features such as '
#            'debugging, testing, evaluating, and monitoring chains'})RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': ' and'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': 'LangSmith is a platform that helps trace and evaluate language '
#            'model applications and intelligent agents, allowing users to move '
#            'from prototype to production. It offers features such as '
#            'debugging, testing, evaluating, and monitoring chains and'})RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': ' intelligent'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': 'LangSmith is a platform that helps trace and evaluate language '
#            'model applications and intelligent agents, allowing users to move '
#            'from prototype to production. It offers features such as '
#            'debugging, testing, evaluating, and monitoring chains and '
#            'intelligent'})RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': ' agents'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': 'LangSmith is a platform that helps trace and evaluate language '
#            'model applications and intelligent agents, allowing users to move '
#            'from prototype to production. It offers features such as '
#            'debugging, testing, evaluating, and monitoring chains and '
#            'intelligent agents'})RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': ' built'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': 'LangSmith is a platform that helps trace and evaluate language '
#            'model applications and intelligent agents, allowing users to move '
#            'from prototype to production. It offers features such as '
#            'debugging, testing, evaluating, and monitoring chains and '
#            'intelligent agents built'})RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': ' on'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': 'LangSmith is a platform that helps trace and evaluate language '
#            'model applications and intelligent agents, allowing users to move '
#            'from prototype to production. It offers features such as '
#            'debugging, testing, evaluating, and monitoring chains and '
#            'intelligent agents built on'})RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': ' any'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': 'LangSmith is a platform that helps trace and evaluate language '
#            'model applications and intelligent agents, allowing users to move '
#            'from prototype to production. It offers features such as '
#            'debugging, testing, evaluating, and monitoring chains and '
#            'intelligent agents built on any'})RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': ' language'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': 'LangSmith is a platform that helps trace and evaluate language '
#            'model applications and intelligent agents, allowing users to move '
#            'from prototype to production. It offers features such as '
#            'debugging, testing, evaluating, and monitoring chains and '
#            'intelligent agents built on any language'})RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': ' model'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': 'LangSmith is a platform that helps trace and evaluate language '
#            'model applications and intelligent agents, allowing users to move '
#            'from prototype to production. It offers features such as '
#            'debugging, testing, evaluating, and monitoring chains and '
#            'intelligent agents built on any language model'})RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': ' framework'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': 'LangSmith is a platform that helps trace and evaluate language '
#            'model applications and intelligent agents, allowing users to move '
#            'from prototype to production. It offers features such as '
#            'debugging, testing, evaluating, and monitoring chains and '
#            'intelligent agents built on any language model framework'})RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': '.'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': 'LangSmith is a platform that helps trace and evaluate language '
#            'model applications and intelligent agents, allowing users to move '
#            'from prototype to production. It offers features such as '
#            'debugging, testing, evaluating, and monitoring chains and '
#            'intelligent agents built on any language model framework.'})RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': ' Lang'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': 'LangSmith is a platform that helps trace and evaluate language '
#            'model applications and intelligent agents, allowing users to move '
#            'from prototype to production. It offers features such as '
#            'debugging, testing, evaluating, and monitoring chains and '
#            'intelligent agents built on any language model framework. Lang'})RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': 'Smith'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': 'LangSmith is a platform that helps trace and evaluate language '
#            'model applications and intelligent agents, allowing users to move '
#            'from prototype to production. It offers features such as '
#            'debugging, testing, evaluating, and monitoring chains and '
#            'intelligent agents built on any language model framework. '
#            'LangSmith'})RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': ' seamlessly'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': 'LangSmith is a platform that helps trace and evaluate language '
#            'model applications and intelligent agents, allowing users to move '
#            'from prototype to production. It offers features such as '
#            'debugging, testing, evaluating, and monitoring chains and '
#            'intelligent agents built on any language model framework. '
#            'LangSmith seamlessly'})RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': ' integrates'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': 'LangSmith is a platform that helps trace and evaluate language '
#            'model applications and intelligent agents, allowing users to move '
#            'from prototype to production. It offers features such as '
#            'debugging, testing, evaluating, and monitoring chains and '
#            'intelligent agents built on any language model framework. '
#            'LangSmith seamlessly integrates'})RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': ' with'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': 'LangSmith is a platform that helps trace and evaluate language '
#            'model applications and intelligent agents, allowing users to move '
#            'from prototype to production. It offers features such as '
#            'debugging, testing, evaluating, and monitoring chains and '
#            'intelligent agents built on any language model framework. '
#            'LangSmith seamlessly integrates with'})RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': ' Lang'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': 'LangSmith is a platform that helps trace and evaluate language '
#            'model applications and intelligent agents, allowing users to move '
#            'from prototype to production. It offers features such as '
#            'debugging, testing, evaluating, and monitoring chains and '
#            'intelligent agents built on any language model framework. '
#            'LangSmith seamlessly integrates with Lang'})RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': 'Chain'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': 'LangSmith is a platform that helps trace and evaluate language '
#            'model applications and intelligent agents, allowing users to move '
#            'from prototype to production. It offers features such as '
#            'debugging, testing, evaluating, and monitoring chains and '
#            'intelligent agents built on any language model framework. '
#            'LangSmith seamlessly integrates with LangChain'})RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': ','},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': 'LangSmith is a platform that helps trace and evaluate language '
#            'model applications and intelligent agents, allowing users to move '
#            'from prototype to production. It offers features such as '
#            'debugging, testing, evaluating, and monitoring chains and '
#            'intelligent agents built on any language model framework. '
#            'LangSmith seamlessly integrates with LangChain,'})RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': ' an'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': 'LangSmith is a platform that helps trace and evaluate language '
#            'model applications and intelligent agents, allowing users to move '
#            'from prototype to production. It offers features such as '
#            'debugging, testing, evaluating, and monitoring chains and '
#            'intelligent agents built on any language model framework. '
#            'LangSmith seamlessly integrates with LangChain, an'})RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': ' open'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': 'LangSmith is a platform that helps trace and evaluate language '
#            'model applications and intelligent agents, allowing users to move '
#            'from prototype to production. It offers features such as '
#            'debugging, testing, evaluating, and monitoring chains and '
#            'intelligent agents built on any language model framework. '
#            'LangSmith seamlessly integrates with LangChain, an open'})RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': '-source'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': 'LangSmith is a platform that helps trace and evaluate language '
#            'model applications and intelligent agents, allowing users to move '
#            'from prototype to production. It offers features such as '
#            'debugging, testing, evaluating, and monitoring chains and '
#            'intelligent agents built on any language model framework. '
#            'LangSmith seamlessly integrates with LangChain, an open-source'})RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': ' framework'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': 'LangSmith is a platform that helps trace and evaluate language '
#            'model applications and intelligent agents, allowing users to move '
#            'from prototype to production. It offers features such as '
#            'debugging, testing, evaluating, and monitoring chains and '
#            'intelligent agents built on any language model framework. '
#            'LangSmith seamlessly integrates with LangChain, an open-source '
#            'framework'})RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': ' for'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': 'LangSmith is a platform that helps trace and evaluate language '
#            'model applications and intelligent agents, allowing users to move '
#            'from prototype to production. It offers features such as '
#            'debugging, testing, evaluating, and monitoring chains and '
#            'intelligent agents built on any language model framework. '
#            'LangSmith seamlessly integrates with LangChain, an open-source '
#            'framework for'})RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': ' building'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': 'LangSmith is a platform that helps trace and evaluate language '
#            'model applications and intelligent agents, allowing users to move '
#            'from prototype to production. It offers features such as '
#            'debugging, testing, evaluating, and monitoring chains and '
#            'intelligent agents built on any language model framework. '
#            'LangSmith seamlessly integrates with LangChain, an open-source '
#            'framework for building'})RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': ' with'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': 'LangSmith is a platform that helps trace and evaluate language '
#            'model applications and intelligent agents, allowing users to move '
#            'from prototype to production. It offers features such as '
#            'debugging, testing, evaluating, and monitoring chains and '
#            'intelligent agents built on any language model framework. '
#            'LangSmith seamlessly integrates with LangChain, an open-source '
#            'framework for building with'})RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': ' language'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': 'LangSmith is a platform that helps trace and evaluate language '
#            'model applications and intelligent agents, allowing users to move '
#            'from prototype to production. It offers features such as '
#            'debugging, testing, evaluating, and monitoring chains and '
#            'intelligent agents built on any language model framework. '
#            'LangSmith seamlessly integrates with LangChain, an open-source '
#            'framework for building with language'})RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': ' models'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': 'LangSmith is a platform that helps trace and evaluate language '
#            'model applications and intelligent agents, allowing users to move '
#            'from prototype to production. It offers features such as '
#            'debugging, testing, evaluating, and monitoring chains and '
#            'intelligent agents built on any language model framework. '
#            'LangSmith seamlessly integrates with LangChain, an open-source '
#            'framework for building with language models'})RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': '.'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': 'LangSmith is a platform that helps trace and evaluate language '
#            'model applications and intelligent agents, allowing users to move '
#            'from prototype to production. It offers features such as '
#            'debugging, testing, evaluating, and monitoring chains and '
#            'intelligent agents built on any language model framework. '
#            'LangSmith seamlessly integrates with LangChain, an open-source '
#            'framework for building with language models.'})RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': ''})

# %% [markdown]
# ## Agents

# %% [markdown]
# ### Stream Actions

# %%
from langchain import hub
from langchain.agents import AgentExecutor, create_openai_functions_agent
from langchain_openai import ChatOpenAI
from langchain_community.tools.tavily_search import TavilySearchResults

search = TavilySearchResults()
tools = [search]

# Get the prompt to use - you can modify this!
# If you want to see the prompt in full, you can at: https://smith.langchain.com/hub/hwchase17/openai-functions-agent
prompt = hub.pull("hwchase17/openai-functions-agent")

# llm = ChatOpenAI(model="gpt-3.5-turbo", temperature=0)
llm = ChatOpenAI(model="gpt-4-1106-preview", temperature=0)

agent = create_openai_functions_agent(llm, tools, prompt)
agent_executor = AgentExecutor(agent=agent, tools=tools)

# %%
for chunk in agent_executor.stream({"input": "what is the weather in SF and then LA"}):
    print(chunk)
    print("------")
# Out:
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# {'actions': [AgentActionMessageLog(tool='tavily_search_results_json', tool_input={'query': 'current weather in San Francisco'}, log="\nInvoking: `tavily_search_results_json` with `{'query': 'current weather in San Francisco'}`\n\n\n", message_log=[AIMessage(content='', additional_kwargs={'function_call': {'arguments': '{"query":"current weather in San Francisco"}', 'name': 'tavily_search_results_json'}})])], 'messages': [AIMessage(content='', additional_kwargs={'function_call': {'arguments': '{"query":"current weather in San Francisco"}', 'name': 'tavily_search_results_json'}})]}
# ------
# {'steps': [AgentStep(action=AgentActionMessageLog(tool='tavily_search_results_json', tool_input={'query': 'current weather in San Francisco'}, log="\nInvoking: `tavily_search_results_json` with `{'query': 'current weather in San Francisco'}`\n\n\n", message_log=[AIMessage(content='', additional_kwargs={'function_call': {'arguments': '{"query":"current weather in San Francisco"}', 'name': 'tavily_search_results_json'}})]), observation=[{'url': 'https://www.weather25.com/north-america/usa/california/san-francisco', 'content': "San Francisco 14 day weather The weather today in San Francisco San Francisco weather report  will give you an idea of weather trends in San Francisco. For example, the weather in San Francisco in January 2024.  the weather in San Francisco including humidity, wind, chance of rain and more on the San Francisco current weather  Weather25.com provides all the information that you need to know about the weather in San Francisco, United States.Sunset: Miles % % San Francisco weather report Looking for San Francisco weather updates? You've come to the right place! The current temperature in San Francisco is ° F. You can find more detailed information about the weather in San Francisco including humidity, wind, chance of rain and more on the San Francisco current weather page."}, {'url': 'https://en.climate-data.org/north-america/united-states-of-america/california/san-francisco-385/t/january-1/', 'content': 'San Francisco Weather in January  San Francisco weather in January San Francisco weather by month // weather averages 9.6 (49.2) 6.2 (43.2) 14 (57.3) 113  you can find all information about the weather in San Francisco in January:  San Francisco weather in January // weather averages Airport close to San FranciscoData: 1991 - 2021 Min. Temperature °C (°F), Max. Temperature °C (°F), Precipitation / Rainfall mm (in), Humidity, Rainy days. Data: 1999 - 2019: avg. Sun hours San Francisco weather and climate for further months San Francisco in February San Francisco in March San Francisco in April San Francisco in May San Francisco in June San Francisco in July'}])], 'messages': [FunctionMessage(content='[{"url": "https://www.weather25.com/north-america/usa/california/san-francisco", "content": "San Francisco 14 day weather The weather today in San Francisco San Francisco weather report  will give you an idea of weather trends in San Francisco. For example, the weather in San Francisco in January 2024.  the weather in San Francisco including humidity, wind, chance of rain and more on the San Francisco current weather  Weather25.com provides all the information that you need to know about the weather in San Francisco, United States.Sunset: Miles % % San Francisco weather report Looking for San Francisco weather updates? You\'ve come to the right place! The current temperature in San Francisco is ° F. You can find more detailed information about the weather in San Francisco including humidity, wind, chance of rain and more on the San Francisco current weather page."}, {"url": "https://en.climate-data.org/north-america/united-states-of-america/california/san-francisco-385/t/january-1/", "content": "San Francisco Weather in January  San Francisco weather in January San Francisco weather by month // weather averages 9.6 (49.2) 6.2 (43.2) 14 (57.3) 113  you can find all information about the weather in San Francisco in January:  San Francisco weather in January // weather averages Airport close to San FranciscoData: 1991 - 2021 Min. Temperature °C (°F), Max. Temperature °C (°F), Precipitation / Rainfall mm (in), Humidity, Rainy days. Data: 1999 - 2019: avg. Sun hours San Francisco weather and climate for further months San Francisco in February San Francisco in March San Francisco in April San Francisco in May San Francisco in June San Francisco in July"}]', name='tavily_search_results_json')]}
# ------
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# {'actions': [AgentActionMessageLog(tool='tavily_search_results_json', tool_input={'query': 'current weather in Los Angeles'}, log="\nInvoking: `tavily_search_results_json` with `{'query': 'current weather in Los Angeles'}`\nresponded: The current weather information for San Francisco is not explicitly detailed in the search results. However, you can find up-to-date weather information for San Francisco by visiting [Weather25.com](https://www.weather25.com/north-america/usa/california/san-francisco) or checking climate averages and historical data on [Climate-Data.org](https://en.climate-data.org/north-america/united-states-of-america/california/san-francisco-385/t/january-1/).\n\nNow, let's check the weather in Los Angeles.\n\n", message_log=[AIMessage(content="The current weather information for San Francisco is not explicitly detailed in the search results. However, you can find up-to-date weather information for San Francisco by visiting [Weather25.com](https://www.weather25.com/north-america/usa/california/san-francisco) or checking climate averages and historical data on [Climate-Data.org](https://en.climate-data.org/north-america/united-states-of-america/california/san-francisco-385/t/january-1/).\n\nNow, let's check the weather in Los Angeles.", additional_kwargs={'function_call': {'arguments': '{"query":"current weather in Los Angeles"}', 'name': 'tavily_search_results_json'}})])], 'messages': [AIMessage(content="The current weather information for San Francisco is not explicitly detailed in the search results. However, you can find up-to-date weather information for San Francisco by visiting [Weather25.com](https://www.weather25.com/north-america/usa/california/san-francisco) or checking climate averages and historical data on [Climate-Data.org](https://en.climate-data.org/north-america/united-states-of-america/california/san-francisco-385/t/january-1/).\n\nNow, let's check the weather in Los Angeles.", additional_kwargs={'function_call': {'arguments': '{"query":"current weather in Los Angeles"}', 'name': 'tavily_search_results_json'}})]}
# ------
# {'steps': [AgentStep(action=AgentActionMessageLog(tool='tavily_search_results_json', tool_input={'query': 'current weather in Los Angeles'}, log="\nInvoking: `tavily_search_results_json` with `{'query': 'current weather in Los Angeles'}`\nresponded: The current weather information for San Francisco is not explicitly detailed in the search results. However, you can find up-to-date weather information for San Francisco by visiting [Weather25.com](https://www.weather25.com/north-america/usa/california/san-francisco) or checking climate averages and historical data on [Climate-Data.org](https://en.climate-data.org/north-america/united-states-of-america/california/san-francisco-385/t/january-1/).\n\nNow, let's check the weather in Los Angeles.\n\n", message_log=[AIMessage(content="The current weather information for San Francisco is not explicitly detailed in the search results. However, you can find up-to-date weather information for San Francisco by visiting [Weather25.com](https://www.weather25.com/north-america/usa/california/san-francisco) or checking climate averages and historical data on [Climate-Data.org](https://en.climate-data.org/north-america/united-states-of-america/california/san-francisco-385/t/january-1/).\n\nNow, let's check the weather in Los Angeles.", additional_kwargs={'function_call': {'arguments': '{"query":"current weather in Los Angeles"}', 'name': 'tavily_search_results_json'}})]), observation=[{'url': 'https://weatherspark.com/h/m/1705/2024/1/Historical-Weather-in-January-2024-in-Los-Angeles-California-United-States', 'content': 'January 2024 Weather History in Los Angeles California, United States  Daily Precipitation in January 2024 in Los Angeles Observed Weather in January 2024 in Los Angeles  Los Angeles Temperature History January 2024 Hourly Temperature in January 2024 in Los Angeles  Hours of Daylight and Twilight in January 2024 in Los AngelesThe daily range of reported temperatures (gray bars) and 24-hour highs (red ticks) and lows (blue ticks), placed over the daily average high (faint red line) and low (faint blue line) temperature, with 25th to 75th and 10th to 90th percentile bands. Hourly Temperature in January 2024 in Los Angeles'}, {'url': 'https://www.whereandwhen.net/when/north-america/california/los-angeles-ca/january/', 'content': 'Best time to go to Los Angeles? Weather in Los Angeles in january 2024  How was the weather last january? Here is the day by day recorded weather in Los Angeles in january 2023:  Weather data for Los Angeles for january are derived from an average of the weather forecast since 2009 in Los Angeles.  6% 4% 64% 24% 6% 5% Evolution of daily average temperature and precipitation in Los Angeles in januaryWeather in Los Angeles in january 2024. The weather in Los Angeles (California) in january comes from statistical datas on the last years. You can view the weather statistics for the whole month, but also navigating through the tabs for the beginning, the middle and the end of the month. ... 14-01-2023 56°F to 59°F. 15-01-2023 54°F to 58°F ...'}, {'url': 'https://www.inkl.com/news/cold-weather-expected-in-los-angeles-today-14-january-2024', 'content': 'Cold Weather Expected in Los Angeles Today - 14 January 2024  The weather forecast for today, 14 January 2024, in Los Angeles predicts a maximum temperature of 17°C (62°F) and a  Title: Embracing Unusual Chills: Cold Weather Sweeps through Los Angeles Today Introduction:  change from the usual Southern California climate.The weather forecast for today, 14 January 2024, in Los Angeles predicts a maximum temperature of 17°C (62°F) and a minimum of 11°C (51°F). The sudden cold spell is attributed to the changing winds and a drop in atmospheric pressure, causing cool air currents to descend upon the city.'}, {'url': 'https://www.latimes.com/opinion/story/2024-01-14/wildfire-fire-weather-california', 'content': 'Aug. 14, 2023  June 14, 2023  The year that killed L.A. restaurants: Here are more than 65 notable closures  ...
# ------
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# {'output': 'The search results do not provide a direct current temperature for Los Angeles, but they do offer some historical data and forecasts. For instance, on January 14, 2024, the weather forecast predicted a maximum temperature of 17°C (62°F) and a minimum of 11°C (51°F) for Los Angeles.\n\nFor the most accurate and current weather conditions in Los Angeles, you may want to visit a dedicated weather website or use a weather app.', 'messages': [AIMessage(content='The search results do not provide a direct current temperature for Los Angeles, but they do offer some historical data and forecasts. For instance, on January 14, 2024, the weather forecast predicted a maximum temperature of 17°C (62°F) and a minimum of 11°C (51°F) for Los Angeles.\n\nFor the most accurate and current weather conditions in Los Angeles, you may want to visit a dedicated weather website or use a weather app.')]}
# ------

# %% [markdown]
# ### Stream Tokens

# %%
# llm = ChatOpenAI(model="gpt-3.5-turbo", temperature=0, streaming=True)
llm = ChatOpenAI(model="gpt-4-1106-preview", temperature=0, streaming=True)

agent = create_openai_functions_agent(llm, tools, prompt)
agent_executor = AgentExecutor(agent=agent, tools=tools)

# %%
async for chunk in agent_executor.astream_log(
    {"input": "what is the weather in sf", "chat_history": []},
    include_names=["ChatOpenAI"],
):
    print(chunk)
# Out:
# RunLogPatch({'op': 'replace',
#   'path': '',
#   'value': {'final_output': None,
#             'id': '271903a5-b404-4a9f-a961-8ec427f4cf89',
#             'logs': {},
#             'streamed_output': []}})
# RunLogPatch({'op': 'add',
#   'path': '/logs/ChatOpenAI',
#   'value': {'end_time': None,
#             'final_output': None,
#             'id': '88cb21f2-60d7-40d4-94cb-4b31bb6bc3dc',
#             'metadata': {},
#             'name': 'ChatOpenAI',
#             'start_time': '2024-01-14T11:31:26.694+00:00',
#             'streamed_output': [],
#             'streamed_output_str': [],
#             'tags': ['seq:step:3'],
#             'type': 'llm'}})
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# RunLogPatch({'op': 'add', 'path': '/logs/ChatOpenAI/streamed_output_str/-', 'value': ''},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI/streamed_output/-',
#   'value': AIMessageChunk(content='', additional_kwargs={'function_call': {'arguments': '', 'name': 'tavily_search_results_json'}})})
# RunLogPatch({'op': 'add', 'path': '/logs/ChatOpenAI/streamed_output_str/-', 'value': ''},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI/streamed_output/-',
#   'value': AIMessageChunk(content='', additional_kwargs={'function_call': {'arguments': '{"', 'name': ''}})})
# RunLogPatch({'op': 'add', 'path': '/logs/ChatOpenAI/streamed_output_str/-', 'value': ''},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI/streamed_output/-',
#   'value': AIMessageChunk(content='', additional_kwargs={'function_call': {'arguments': 'query', 'name': ''}})})
# RunLogPatch({'op': 'add', 'path': '/logs/ChatOpenAI/streamed_output_str/-', 'value': ''},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI/streamed_output/-',
#   'value': AIMessageChunk(content='', additional_kwargs={'function_call': {'arguments': '":"', 'name': ''}})})
# RunLogPatch({'op': 'add', 'path': '/logs/ChatOpenAI/streamed_output_str/-', 'value': ''},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI/streamed_output/-',
#   'value': AIMessageChunk(content='', additional_kwargs={'function_call': {'arguments': 'current', 'name': ''}})})
# RunLogPatch({'op': 'add', 'path': '/logs/ChatOpenAI/streamed_output_str/-', 'value': ''},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI/streamed_output/-',
#   'value': AIMessageChunk(content='', additional_kwargs={'function_call': {'arguments': ' weather', 'name': ''}})})
# RunLogPatch({'op': 'add', 'path': '/logs/ChatOpenAI/streamed_output_str/-', 'value': ''},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI/streamed_output/-',
#   'value': AIMessageChunk(content='', additional_kwargs={'function_call': {'arguments': ' in', 'name': ''}})})
# RunLogPatch({'op': 'add', 'path': '/logs/ChatOpenAI/streamed_output_str/-', 'value': ''},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI/streamed_output/-',
#   'value': AIMessageChunk(content='', additional_kwargs={'function_call': {'arguments': ' San', 'name': ''}})})
# RunLogPatch({'op': 'add', 'path': '/logs/ChatOpenAI/streamed_output_str/-', 'value': ''},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI/streamed_output/-',
#   'value': AIMessageChunk(content='', additional_kwargs={'function_call': {'arguments': ' Francisco', 'name': ''}})})
# RunLogPatch({'op': 'add', 'path': '/logs/ChatOpenAI/streamed_output_str/-', 'value': ''},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI/streamed_output/-',
#   'value': AIMessageChunk(content='', additional_kwargs={'function_call': {'arguments': '"}', 'name': ''}})})
# RunLogPatch({'op': 'add', 'path': '/logs/ChatOpenAI/streamed_output_str/-', 'value': ''},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI/streamed_output/-',
#   'value': AIMessageChunk(content='')})
# RunLogPatch({'op': 'add',
#   'path': '/logs/ChatOpenAI/final_output',
#   'value': {'generations': [[{'generation_info': {'finish_reason': 'function_call'},
#                               'message': AIMessage(content='', additional_kwargs={'function_call': {'arguments': '{"query":"current weather in San Francisco"}', 'name': 'tavily_search_results_json'}}),
#                               'text': '',
#                               'type': 'ChatGeneration'}]],
#             'llm_output': None,
#             'run': None}},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI/end_time',
#   'value': '2024-01-14T11:31:28.081+00:00'})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': {'actions': [AgentActionMessageLog(tool='tavily_search_results_json', tool_input={'query': 'current weather in San Francisco'}, log="\nInvoking: `tavily_search_results_json` with `{'query': 'current weather in San Francisco'}`\n\n\n", message_log=[AIMessage(content='', additional_kwargs={'function_call': {'arguments': '{"query":"current weather in San Francisco"}', 'name': 'tavily_search_results_json'}})])],
#             'messages': [AIMessage(content='', additional_kwargs={'function_call': {'arguments': '{"query":"current weather in San Francisco"}', 'name': 'tavily_search_results_json'}})]}},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': {'actions': [AgentActionMessageLog(tool='tavily_search_results_json', tool_input={'query': 'current weather in San Francisco'}, log="\nInvoking: `tavily_search_results_json` with `{'query': 'current weather in San Francisco'}`\n\n\n", message_log=[AIMessage(content='', additional_kwargs={'function_call': {'arguments': '{"query":"current weather in San Francisco"}', 'name': 'tavily_search_results_json'}})])],
#             'messages': [AIMessage(content='', additional_kwargs={'function_call': {'arguments': '{"query":"current weather in San Francisco"}', 'name': 'tavily_search_results_json'}})]}})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': {'messages': [FunctionMessage(content='[{"url": "https://www.weather25.com/north-america/usa/california/san-francisco", "content": "San Francisco 14 day weather The weather today in San Francisco San Francisco weather report  will give you an idea of weather trends in San Francisco. For example, the weather in San Francisco in January 2024.  the weather in San Francisco including humidity, wind, chance of rain and more on the San Francisco current weather  Weather25.com provides all the information that you need to know about the weather in San Francisco, United States.Sunset: Miles % % San Francisco weather report Looking for San Francisco weather updates? You\'ve come to the right place! The current temperature in San Francisco is ° F. You can find more detailed information about the weather in San Francisco including humidity, wind, chance of rain and more on the San Francisco current weather page."}, {"url": "https://en.climate-data.org/north-america/united-states-of-america/california/san-francisco-385/t/january-1/", "content": "San Francisco Weather in January  San Francisco weather in January San Francisco weather by month // weather averages 9.6 (49.2) 6.2 (43.2) 14 (57.3) 113  you can find all information about the weather in San Francisco in January:  San Francisco weather in January // weather averages Airport close to San FranciscoData: 1991 - 2021 Min. Temperature °C (°F), Max. Temperature °C (°F), Precipitation / Rainfall mm (in), Humidity, Rainy days. Data: 1999 - 2019: avg. Sun hours San Francisco weather and climate for further months San Francisco in February San Francisco in March San Francisco in April San Francisco in May San Francisco in June San Francisco in July"}, {"url": "https://www.eastbaytimes.com/2024/01/12/widespread-prolific-rainstorm-headed-to-northern-california-on-saturday/", "content": "— NWS Bay Area 🌉 (@NWSBayArea) January 12, 2024  #cawx pic.twitter.com/GJKTZQoOON — NWS Bay Area 🌉 (@NWSBayArea) January 12, 2024  Weather | Widespread, prolific rainstorm headed to Northern California on Saturday News Weather Weather |  As much as one inch of rain is expected in parts of the Bay AreaThe widespread storm was predicted to cover the entire region, though totals may vary due to rain shadowing, an effect where mountains act as a shield to heavier rain to valleys because..."}]', name='tavily_search_results_json')],
#             'steps': [AgentStep(action=AgentActionMessageLog(tool='tavily_search_results_json', tool_input={'query': 'current weather in San Francisco'}, log="\nInvoking: `tavily_search_results_json` with `{'query': 'current weather in San Francisco'}`\n\n\n", message_log=[AIMessage(content='', additional_kwargs={'function_call': {'arguments': '{"query":"current weather in San Francisco"}', 'name': 'tavily_search_results_json'}})]), observation=[{'url': 'https://www.weather25.com/north-america/usa/california/san-francisco', 'content': "San Francisco 14 day weather The weather today in San Francisco San Francisco weather report  will give you an idea of weather trends in San Francisco. For example, the weather in San Francisco in January 2024.  the weather in San Francisco including humidity, wind, chance of rain and more on the San Francisco current weather  Weather25.com provides all the information that you need to know about the weather in San Francisco, United States.Sunset: Miles % % San Francisco weather report Looking for San Francisco weather updates? You've come to the right place! The current temperature in San Francisco is ° F. You can find more detailed information about the weather in San Francisco including humidity, wind, chance of rain and more on the San Francisco current weather page."}, {'url': 'https://en.climate-data.org/north-america/united-states-of-america/california/san-francisco-385/t/january-1/', 'content': 'San Francisco Weather in January  San Francisco weather in January San Francisco weather by month // weather averages 9.6 (49.2) 6.2 (43.2) 14 (57.3) 113  you can find all information about the weather in San Francisco in January:  San Francisco weather in January // weather averages Airport close to San FranciscoData: 1991 - 2021 Min. Temperature °C (°F), Max. Temperature °C (°F), Precipitation / Rainfall mm (in), Humidity, Rainy days. Data: 1999 - 2019: avg. Sun hours San Francisco weather and climate for further months San Francisco in February San Francisco in March San Francisco in April San Francisco in May San Francisco in June San Francisco in July'}, {'url': 'https://www.eastbaytimes.com/2024/01/12/widespread-prolific-rainstorm-headed-to-northern-california-on-saturday/', 'content': '— NWS Bay Area 🌉 (@NWSBayArea) January 12, 2024  #cawx pic.twitter.com/GJKTZQoOON — NWS Bay Area 🌉 (@NWSBayArea) January 12, 2024  Weather | Widespread, prolific rainstorm headed to Northern California on Saturday News Weather Weather |  As much as one inch of rain is expected in parts of the Bay AreaThe widespread storm was predicted to cover the entire region, though totals may vary due to rain shadowing, an effect where mountains act as a shield to heavier rain to valleys because...'}])]}},
#  {'op': 'add',
#   'path': '/final_output/steps',
#   'value': [AgentStep(action=AgentActionMessageLog(tool='tavily_search_results_json', tool_input={'query': 'current weather in San Francisco'}, log="\nInvoking: `tavily_search_results_json` with `{'query': 'current weather in San Francisco'}`\n\n\n", message_log=[AIMessage(content='', additional_kwargs={'function_call': {'arguments': '{"query":"current weather in San Francisco"}', 'name': 'tavily_search_results_json'}})]), observation=[{'url': 'https://www.weather25.com/north-america/usa/california/san-francisco', 'content': "San Francisco 14 day weather The weather today in San Francisco San Francisco weather report  will give you an idea of weather trends in San Francisco. For example, the weather in San Francisco in January 2024.  the weather in San Francisco including humidity, wind, chance of rain and more on the San Francisco current weather  Weather25.com provides all the information that you need to know about the weather in San Francisco, United States.Sunset: Miles % % San Francisco weather report Looking for San Francisco weather updates? You've come to the right place! The current temperature in San Francisco is ° F. You can find more detailed information about the weather in San Francisco including humidity, wind, chance of rain and more on the San Francisco current weather page."}, {'url': 'https://en.climate-data.org/north-america/united-states-of-america/california/san-francisco-385/t/january-1/', 'content': 'San Francisco Weather in January  San Francisco weather in January San Francisco weather by month // weather averages 9.6 (49.2) 6.2 (43.2) 14 (57.3) 113  you can find all information about the weather in San Francisco in January:  San Francisco weather in January // weather averages Airport close to San FranciscoData: 1991 - 2021 Min. Temperature °C (°F), Max. Temperature °C (°F), Precipitation / Rainfall mm (in), Humidity, Rainy days. Data: 1999 - 2019: avg. Sun hours San Francisco weather and climate for further months San Francisco in February San Francisco in March San Francisco in April San Francisco in May San Francisco in June San Francisco in July'}, {'url': 'https://www.eastbaytimes.com/2024/01/12/widespread-prolific-rainstorm-headed-to-northern-california-on-saturday/', 'content': '— NWS Bay Area 🌉 (@NWSBayArea) January 12, 2024  #cawx pic.twitter.com/GJKTZQoOON — NWS Bay Area 🌉 (@NWSBayArea) January 12, 2024  Weather | Widespread, prolific rainstorm headed to Northern California on Saturday News Weather Weather |  As much as one inch of rain is expected in parts of the Bay AreaThe widespread storm was predicted to cover the entire region, though totals may vary due to rain shadowing, an effect where mountains act as a shield to heavier rain to valleys because...'}])]},
#  {'op': 'add',
#   'path': '/final_output/messages/1',
#   'value': FunctionMessage(content='[{"url": "https://www.weather25.com/north-america/usa/california/san-francisco", "content": "San Francisco 14 day weather The weather today in San Francisco San Francisco weather report  will give you an idea of weather trends in San Francisco. For example, the weather in San Francisco in January 2024.  the weather in San Francisco including humidity, wind, chance of rain and more on the San Francisco current weather  Weather25.com provides all the information that you need to know about the weather in San Francisco, United States.Sunset: Miles % % San Francisco weather report Looking for San Francisco weather updates? You\'ve come to the right place! The current temperature in San Francisco is ° F. You can find more detailed information about the weather in San Francisco including humidity, wind, chance of rain and more on the San Francisco current weather page."}, {"url": "https://en.climate-data.org/north-america/united-states-of-america/california/san-francisco-385/t/january-1/", "content": "San Francisco Weather in January  San Francisco weather in January San Francisco weather by month // weather averages 9.6 (49.2) 6.2 (43.2) 14 (57.3) 113  you can find all information about the weather in San Francisco in January:  San Francisco weather in January // weather averages Airport close to San FranciscoData: 1991 - 2021 Min. Temperature °C (°F), Max. Temperature °C (°F), Precipitation / Rainfall mm (in), Humidity, Rainy days. Data: 1999 - 2019: avg. Sun hours San Francisco weather and climate for further months San Francisco in February San Francisco in March San Francisco in April San Francisco in May San Francisco in June San Francisco in July"}, {"url": "https://www.eastbaytimes.com/2024/01/12/widespread-prolific-rainstorm-headed-to-northern-california-on-saturday/", "content": "— NWS Bay Area 🌉 (@NWSBayArea) January 12, 2024  #cawx pic.twitter.com/GJKTZQoOON — NWS Bay Area 🌉 (@NWSBayArea) January 12, 2024  Weather | Widespread, prolific rainstorm headed to Northern California on Saturday News Weather Weather |  As much as one inch of rain is expected in parts of the Bay AreaThe widespread storm was predicted to cover the entire region, though totals may vary due to rain shadowing, an effect where mountains act as a shield to heavier rain to valleys because..."}]', name='tavily_search_results_json')})
# RunLogPatch({'op': 'add',
#   'path': '/logs/ChatOpenAI:2',
#   'value': {'end_time': None,
#             'final_output': None,
#             'id': 'be053cac-6bfc-4c91-83b8-d04508ecd286',
#             'metadata': {},
#             'name': 'ChatOpenAI',
#             'start_time': '2024-01-14T11:31:32.284+00:00',
#             'streamed_output': [],
#             'streamed_output_str': [],
#             'tags': ['seq:step:3'],
#             'type': 'llm'}})
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# RunLogPatch({'op': 'add', 'path': '/logs/ChatOpenAI:2/streamed_output_str/-', 'value': ''},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output/-',
#   'value': AIMessageChunk(content='')})
# RunLogPatch({'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output_str/-',
#   'value': 'The'},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output/-',
#   'value': AIMessageChunk(content='The')})
# RunLogPatch({'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output_str/-',
#   'value': ' current'},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output/-',
#   'value': AIMessageChunk(content=' current')})
# RunLogPatch({'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output_str/-',
#   'value': ' weather'},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output/-',
#   'value': AIMessageChunk(content=' weather')})
# RunLogPatch({'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output_str/-',
#   'value': ' in'},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output/-',
#   'value': AIMessageChunk(content=' in')})
# RunLogPatch({'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output_str/-',
#   'value': ' San'},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output/-',
#   'value': AIMessageChunk(content=' San')})
# RunLogPatch({'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output_str/-',
#   'value': ' Francisco'},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output/-',
#   'value': AIMessageChunk(content=' Francisco')})
# RunLogPatch({'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output_str/-',
#   'value': ' is'},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output/-',
#   'value': AIMessageChunk(content=' is')})
# RunLogPatch({'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output_str/-',
#   'value': ' not'},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output/-',
#   'value': AIMessageChunk(content=' not')})
# RunLogPatch({'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output_str/-',
#   'value': ' explicitly'},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output/-',
#   'value': AIMessageChunk(content=' explicitly')})
# RunLogPatch({'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output_str/-',
#   'value': ' detailed'},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output/-',
#   'value': AIMessageChunk(content=' detailed')})
# RunLogPatch({'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output_str/-',
#   'value': ' in'},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output/-',
#   'value': AIMessageChunk(content=' in')})
# RunLogPatch({'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output_str/-',
#   'value': ' the'},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output/-',
#   'value': AIMessageChunk(content=' the')})
# RunLogPatch({'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output_str/-',
#   'value': ' search'},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output/-',
#   'value': AIMessageChunk(content=' search')})
# RunLogPatch({'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output_str/-',
#   'value': ' results'},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output/-',
#   'value': AIMessageChunk(content=' results')})
# RunLogPatch({'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output_str/-',
#   'value': '.'},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output/-',
#   'value': AIMessageChunk(content='.')})
# RunLogPatch({'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output_str/-',
#   'value': ' However'},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output/-',
#   'value': AIMessageChunk(content=' However')})
# RunLogPatch({'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output_str/-',
#   'value': ','},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output/-',
#   'value': AIMessageChunk(content=',')})
# RunLogPatch({'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output_str/-',
#   'value': ' one'},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output/-',
#   'value': AIMessageChunk(content=' one')})
# RunLogPatch({'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output_str/-',
#   'value': ' of'},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output/-',
#   'value': AIMessageChunk(content=' of')})
# RunLogPatch({'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output_str/-',
#   'value': ' the'},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output/-',
#   'value': AIMessageChunk(content=' the')})
# RunLogPatch({'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output_str/-',
#   'value': ' sources'},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output/-',
#   'value': AIMessageChunk(content=' sources')})
# RunLogPatch({'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output_str/-',
#   'value': ' mentions'},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output/-',
#   'value': AIMessageChunk(content=' mentions')})
# RunLogPatch({'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output_str/-',
#   'value': ' that'},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output/-',
#   'value': AIMessageChunk(content=' that')})
# RunLogPatch({'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output_str/-',
#   'value': ' there'},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output/-',
#   'value': AIMessageChunk(content=' there')})
# RunLogPatch({'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output_str/-',
#   'value': ' is'},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output/-',
#   'value': AIMessageChunk(content=' is')})
# RunLogPatch({'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output_str/-',
#   'value': ' a'},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output/-',
#   'value': AIMessageChunk(content=' a')})
# RunLogPatch({'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output_str/-',
#   'value': ' widespread'},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output/-',
#   'value': AIMessageChunk(content=' widespread')})
# RunLogPatch({'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output_str/-',
#   'value': ','},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output/-',
#   'value': AIMessageChunk(content=',')})
# RunLogPatch({'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output_str/-',
#   'value': ' prolific'},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output/-',
#   'value': AIMessageChunk(content=' prolific')})
# RunLogPatch({'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output_str/-',
#   'value': ' rain'},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output/-',
#   'value': AIMessageChunk(content=' rain')})
# RunLogPatch({'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output_str/-',
#   'value': 'storm'},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output/-',
#   'value': AIMessageChunk(content='storm')})
# RunLogPatch({'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output_str/-',
#   'value': ' headed'},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output/-',
#   'value': AIMessageChunk(content=' headed')})
# RunLogPatch({'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output_str/-',
#   'value': ' to'},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output/-',
#   'value': AIMessageChunk(content=' to')})
# RunLogPatch({'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output_str/-',
#   'value': ' Northern'},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output/-',
#   'value': AIMessageChunk(content=' Northern')})
# RunLogPatch({'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output_str/-',
#   'value': ' California'},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output/-',
#   'value': AIMessageChunk(content=' California')})
# RunLogPatch({'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output_str/-',
#   'value': ','},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output/-',
#   'value': AIMessageChunk(content=',')})
# RunLogPatch({'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output_str/-',
#   'value': ' which'},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output/-',
#   'value': AIMessageChunk(content=' which')})
# RunLogPatch({'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output_str/-',
#   'value': ' may'},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output/-',
#   'value': AIMessageChunk(content=' may')})
# RunLogPatch({'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output_str/-',
#   'value': ' affect'},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output/-',
#   'value': AIMessageChunk(content=' affect')})
# RunLogPatch({'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output_str/-',
#   'value': ' San'},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output/-',
#   'value': AIMessageChunk(content=' San')})
# RunLogPatch({'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output_str/-',
#   'value': ' Francisco'},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output/-',
#   'value': AIMessageChunk(content=' Francisco')})
# RunLogPatch({'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output_str/-',
#   'value': ' with'},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output/-',
#   'value': AIMessageChunk(content=' with')})
# RunLogPatch({'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output_str/-',
#   'value': ' as'},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output/-',
#   'value': AIMessageChunk(content=' as')})
# RunLogPatch({'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output_str/-',
#   'value': ' much'},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output/-',
#   'value': AIMessageChunk(content=' much')})
# RunLogPatch({'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output_str/-',
#   'value': ' as'},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output/-',
#   'value': AIMessageChunk(content=' as')})
# RunLogPatch({'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output_str/-',
#   'value': ' one'},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output/-',
#   'value': AIMessageChunk(content=' one')})
# RunLogPatch({'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output_str/-',
#   'value': ' inch'},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output/-',
#   'value': AIMessageChunk(content=' inch')})
# RunLogPatch({'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output_str/-',
#   'value': ' of'},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output/-',
#   'value': AIMessageChunk(content=' of')})
# RunLogPatch({'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output_str/-',
#   'value': ' rain'},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output/-',
#   'value': AIMessageChunk(content=' rain')})
# RunLogPatch({'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output_str/-',
#   'value': ' expected'},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output/-',
#   'value': AIMessageChunk(content=' expected')})
# RunLogPatch({'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output_str/-',
#   'value': ' in'},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output/-',
#   'value': AIMessageChunk(content=' in')})
# RunLogPatch({'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output_str/-',
#   'value': ' parts'},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output/-',
#   'value': AIMessageChunk(content=' parts')})
# RunLogPatch({'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output_str/-',
#   'value': ' of'},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output/-',
#   'value': AIMessageChunk(content=' of')})
# RunLogPatch({'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output_str/-',
#   'value': ' the'},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output/-',
#   'value': AIMessageChunk(content=' the')})
# RunLogPatch({'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output_str/-',
#   'value': ' Bay'},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output/-',
#   'value': AIMessageChunk(content=' Bay')})
# RunLogPatch({'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output_str/-',
#   'value': ' Area'},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output/-',
#   'value': AIMessageChunk(content=' Area')})
# RunLogPatch({'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output_str/-',
#   'value': '.\n\n'},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output/-',
#   'value': AIMessageChunk(content='.\n\n')})
# RunLogPatch({'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output_str/-',
#   'value': 'For'},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output/-',
#   'value': AIMessageChunk(content='For')})
# RunLogPatch({'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output_str/-',
#   'value': ' the'},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output/-',
#   'value': AIMessageChunk(content=' the')})
# RunLogPatch({'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output_str/-',
#   'value': ' most'},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output/-',
#   'value': AIMessageChunk(content=' most')})
# RunLogPatch({'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output_str/-',
#   'value': ' accurate'},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output/-',
#   'value': AIMessageChunk(content=' accurate')})
# RunLogPatch({'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output_str/-',
#   'value': ' and'},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output/-',
#   'value': AIMessageChunk(content=' and')})
# RunLogPatch({'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output_str/-',
#   'value': ' up'},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output/-',
#   'value': AIMessageChunk(content=' up')})
# RunLogPatch({'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output_str/-',
#   'value': '-to'},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output/-',
#   'value': AIMessageChunk(content='-to')})
# RunLogPatch({'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output_str/-',
#   'value': '-date'},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output/-',
#   'value': AIMessageChunk(content='-date')})
# RunLogPatch({'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output_str/-',
#   'value': ' weather'},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output/-',
#   'value': AIMessageChunk(content=' weather')})
# RunLogPatch({'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output_str/-',
#   'value': ' conditions'},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output/-',
#   'value': AIMessageChunk(content=' conditions')})
# RunLogPatch({'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output_str/-',
#   'value': ','},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output/-',
#   'value': AIMessageChunk(content=',')})
# RunLogPatch({'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output_str/-',
#   'value': ' it'},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output/-',
#   'value': AIMessageChunk(content=' it')})
# RunLogPatch({'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output_str/-',
#   'value': ' is'},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output/-',
#   'value': AIMessageChunk(content=' is')})
# RunLogPatch({'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output_str/-',
#   'value': ' recommended'},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output/-',
#   'value': AIMessageChunk(content=' recommended')})
# RunLogPatch({'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output_str/-',
#   'value': ' to'},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output/-',
#   'value': AIMessageChunk(content=' to')})
# RunLogPatch({'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output_str/-',
#   'value': ' check'},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output/-',
#   'value': AIMessageChunk(content=' check')})
# RunLogPatch({'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output_str/-',
#   'value': ' a'},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output/-',
#   'value': AIMessageChunk(content=' a')})
# RunLogPatch({'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output_str/-',
#   'value': ' reliable'},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output/-',
#   'value': AIMessageChunk(content=' reliable')})
# RunLogPatch({'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output_str/-',
#   'value': ' weather'},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output/-',
#   'value': AIMessageChunk(content=' weather')})
# RunLogPatch({'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output_str/-',
#   'value': ' forecasting'},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output/-',
#   'value': AIMessageChunk(content=' forecasting')})
# RunLogPatch({'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output_str/-',
#   'value': ' service'},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output/-',
#   'value': AIMessageChunk(content=' service')})
# RunLogPatch({'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output_str/-',
#   'value': ' or'},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output/-',
#   'value': AIMessageChunk(content=' or')})
# RunLogPatch({'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output_str/-',
#   'value': ' website'},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output/-',
#   'value': AIMessageChunk(content=' website')})
# RunLogPatch({'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output_str/-',
#   'value': '.'},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output/-',
#   'value': AIMessageChunk(content='.')})
# RunLogPatch({'op': 'add', 'path': '/logs/ChatOpenAI:2/streamed_output_str/-', 'value': ''},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output/-',
#   'value': AIMessageChunk(content='')})
# RunLogPatch({'op': 'add',
#   'path': '/logs/ChatOpenAI:2/final_output',
#   'value': {'generations': [[{'generation_info': {'finish_reason': 'stop'},
#                               'message': AIMessage(content='The current weather in San Francisco is not explicitly detailed in the search results. However, one of the sources mentions that there is a widespread, prolific rainstorm headed to Northern California, which may affect San Francisco with as much as one inch of rain expected in parts of the Bay Area.\n\nFor the most accurate and up-to-date weather conditions, it is recommended to check a reliable weather forecasting service or website.'),
#                               'text': 'The current weather in San Francisco is '
#                                       'not explicitly detailed in the search '
#                                       'results. However, one of the sources '
#                                       'mentions that there is a widespread, '
#                                       'prolific rainstorm headed to Northern '
#                                       'California, which may affect San '
#                                       'Francisco with as much as one inch of '
#                                       'rain expected in parts of the Bay '
#                                       'Area.\n'
#                                       '\n'
#                                       'For the most accurate and up-to-date '
#                                       'weather conditions, it is recommended '
#                                       'to check a reliable weather forecasting '
#                                       'service or website.',
#                               'type': 'ChatGeneration'}]],
#             'llm_output': None,
#             'run': None}},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI:2/end_time',
#   'value': '2024-01-14T11:31:34.706+00:00'})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': {'messages': [AIMessage(content='The current weather in San Francisco is not explicitly detailed in the search results. However, one of the sources mentions that there is a widespread, prolific rainstorm headed to Northern California, which may affect San Francisco with as much as one inch of rain expected in parts of the Bay Area.\n\nFor the most accurate and up-to-date weather conditions, it is recommended to check a reliable weather forecasting service or website.')],
#             'output': 'The current weather in San Francisco is not explicitly '
#                       'detailed in the search results. However, one of the '
#                       'sources mentions that there is a widespread, prolific '
#                       'rainstorm headed to Northern California, which may '
#                       'affect San Francisco with as much as one inch of rain '
#                       'expected in parts of the Bay Area.\n'
#                       '\n'
#                       'For the most accurate and up-to-date weather '
#                       'conditions, it is recommended to check a reliable '
#                       'weather forecasting service or website.'}},
#  {'op': 'add',
#   'path': '/final_output/output',
#   'value': 'The current weather in San Francisco is not explicitly detailed in '
#            'the search results. However, one of the sources mentions that '
#            'there is a widespread, prolific rainstorm headed to Northern '
#            'California, which may affect San Francisco with as much as one '
#            'inch of rain expected in parts of the Bay Area.\n'
#            '\n'
#            'For the most accurate and up-to-date weather conditions, it is '
#            'recommended to check a reliable weather forecasting service or '
#            'website.'},
#  {'op': 'add',
#   'path': '/final_output/messages/2',
#   'value': AIMessage(content='The current weather in San Francisco is not explicitly detailed in the search results. However, one of the sources mentions that there is a widespread, prolific rainstorm headed to Northern California, which may affect San Francisco with as much as one inch of rain expected in parts of the Bay Area.\n\nFor the most accurate and up-to-date weather conditions, it is recommended to check a reliable weather forecasting service or website.')})
