# %% [markdown]
# # Cohere Rerank 3 - Search over Tabular Data
#
# This notebook shows an example how the JSON capabilities of [Cohere Rerank 3](https://txt.cohere.com/rerank-3/) can be used to search over tabular data, in this example for a Pandas DataFrame with top-5000 movies.

# %%
# !pip install -q cohere pandas numpy

# %%
from dotenv import load_dotenv

import pandas as pd
import cohere
import numpy as np

# %%
load_dotenv()
# Out:
# True

# %%
# Get your free API key from: www.cohere.com
# cohere_key = "<<YOUR_COHERE_API_KEY>>"
# co = cohere.Client(cohere_key)
co = cohere.Client()

# %%
# Here we load a pandas DataFrame with around top-5000 movies
df = pd.read_parquet("https://huggingface.co/datasets/Cohere/movies/resolve/main/movies.parquet")
df
# Out:
#                             title  \
# 0                          Avatar
# 1                         Titanic
# 2                    The Avengers
# 3                  Jurassic World
# 4                       Furious 7
# ...                           ...
# 4798             Midnight Cabaret
# 4799             Growing Up Smith
# 4800                       8 Days
# 4801              Running Forever
# 4802  To Be Frank, Sinatra at 100
#
#                                                overview  \
# 0     In the 22nd century, a paraplegic Marine is di...
# 1     84 years later, a 101-year-old woman named Ros...
# 2     When an unexpected enemy emerges and threatens...
# 3     Twenty-two years after the events of Jurassic ...
# 4     Deckard Shaw seeks revenge against Dominic Tor...
# ...                                                 ...
# 4798  A Broadway producer puts on a play with a Devi...
# 4799  In 1979, an Indian family moves to America wit...
# 4800  After sneaking to a party with her friends, 16...
# 4801  After being estranged since her mother's death...
# 4802                                               None
#
#                                             genres  \
# 0      Action, Adventure, Fantasy, Science Fiction
# 1                         Drama, Romance, Thriller
# 2               Science Fiction, Action, Adventure
# 3     Action, Adventure, Science Fiction, Thriller
# 4                                           Action
# ...                                            ...
# 4798                                        Horror
# 4799                         Comedy, Family, Drama
# 4800                               Thriller, Drama
# 4801                                        Family
# 4802                                   Documentary
#
#                                                producer  \
# 0     Ingenious Film Partners, Twentieth Century Fox...
# 1     Paramount Pictures, Twentieth Century Fox Film...
# 2                    Paramount Pictures, Marvel Studios
# 3     Universal Studios, Amblin Entertainment, Legen...
# 4     Universal Pictures, Original Film, Fuji Televi...
# ...                                                 ...
# 4798
# 4799
# 4800                                After Eden Pictures
# 4801                               New Kingdom Pictures
# 4802                              Eyeline Entertainment
#
#                                                    cast
# 0     Sam Worthington as Jake Sully, Zoe Saldana as ...
# 1     Kate Winslet as Rose DeWitt Bukater, Leonardo ...
# 2     Robert Downey Jr. as Tony Stark / Iron Man, Ch...
# 3     Chris Pratt as Owen Grady, Bryce Dallas Howard...
# 4     Vin Diesel as Dominic Toretto, Paul Walker as ...
# ...                                                 ...
# 4798  Lisa Hart Carroll as Dawn, Michael Des Barres ...
# 4799  Roni Akurati as Smith Bhatnagar, Brighton Shar...
# 4800  Nicole Smolen as Amber, Kim Baldwin as BB, Ari...
# 4801
# 4802                        Tony Oppedisano as Narrator
#
# [4803 rows x 5 columns]

# %%
# Randomly get 50 rows with no None value in all columns
df = df.dropna(axis=0, how='all').sample(n=50, random_state=42)
# 4197  A police profiler has just returned from psych...
# 2609  The OSSA discovers a spacecraft thought to be ...
# 828   Elle Woods has it all. She's the president of ...
# 4109  Two plus-sized ladies meet the men of their dr...
# 1323  Maverick cop Orin Boyd always brings down the ...
# 3622  It took Anna 10 years to recover from the deat...
# 23    After a threat from the tiger Shere Khan force...
# 586   Three escaped criminals from the planet Krypto...
# 3590  The Hollywood version of the popular video gam...
# 3119  On Christmas Eve, a little girl named Marie (C...
# 33    Shrek, Fiona and Donkey set off to Far, Far Aw...
# 4333  Werner Ernst is a young hospital resident who ...
# 1995  Just when you thought it was safe to sleep, Fr...
# 79    Bella once again finds herself surrounded by d...
# 4455  A self-centered, middle-aged pitchman for a po...
# 254   A struggling songwriter named Dave Seville fin...
# 2992  Four Lions tells the story of a group of Briti...
# 4270  After their production "Princess Ida" meets wi...
# 486   On a fall night in 2003, Harvard undergrad and...
# 2329  This documentary showcases basketball player M...
#
#                                              genres  \
# 596                                  Action, Comedy
# 3372                               Horror, Thriller
# 2702                                         Comedy
# 2473                                         Comedy
# 8              Family, Animation, Adventure, Comedy
# 577                                 Comedy, Romance
# 3172                                          Drama
# 811                                           Drama
# 2077                                      Adventure
# 4032                                          Drama
# 4402                         Drama, Comedy, Romance
# 3365         Action, Adventure, Drama, History, War
# 3745                            Comedy, Documentary
# 4337                                          Drama
# 227                         Action, Crime, Thriller
# 296                                 Comedy, Romance
# 3323       Comedy, Science Fiction, Romance, Horror
# 1973                                  Drama, Horror
# 2521                                     War, Drama
# 2045                         Comedy, Music, Romance
# 4015                                 Drama, Romance
# 534                     Action, Drama, History, War
# 2634                      Science Fiction, Thriller
# 3339                 Action, Comedy, Drama, History
# 1231                              Mystery, Thriller
# 2459                                    Documentary
# 2715                                          Drama
# 759                     War, Drama, History, Action
# 2647                         Crime, Drama, Thriller
# 805                                 Comedy, Romance
# 4197                      Horror, Thriller, Mystery
# 2609                                Science Fiction
# 828                                          Comedy
# 4109                                Comedy, Romance
# 1323                        Action, Crime, Thriller
# 3622                       Drama, Mystery, Thriller
# 23                Family, Adventure, Drama, Fantasy
# 586     Action, Adventure, Fantasy, Science Fiction
# 3590                        Action, Science Fiction
# 3119                         Family, Fantasy, Music
# 33    Adventure, Animation, Comedy, Family, Fantasy
# 4333                                  Comedy, Drama
# 1995                       Horror, Thriller, Comedy
# 79               Adventure, Fantasy, Drama, Romance
# 4455                                  Comedy, Drama
# 254       Comedy, Music, Family, Fantasy, Animation
# 2992                           Comedy, Crime, Drama
# 4270                           Comedy, Drama, Music
# 486                                           Drama
# 2329                                    Documentary
#
#                                                producer  \
# 596   DreamWorks SKG, Goldcrest Pictures, Red Hour F...
# 3372                                  Destination Films
# 2702  New Line Cinema, Capella International, KC Med...
# 2473  Miramax Films, Sidney Kimmel Entertainment, Th...
# 8        Universal Pictures, Illumination Entertainment
# 577   Columbia Pictures, Universal Pictures, Waverly...
ards Attendee (uncredited), Anya Monzikova as Trophy Presenter (uncredited), Chad Mountain as Agency Assistant (uncredited), Brittany Perry-Russell as Booty Sweat Girl (uncredited), Simon Rhee as Flaming Dragon Compound Person (uncredited), DJ Rivers as Award Show Security (uncredited), Samantha Sadoff as Farm Girl (uncredited), Gaku Space as Guerilla Guard (uncredited), Becca Sweitzer as Go Go Dancer (uncredited), Kaye Marie Talise as Academy Award Attendee (uncredited), Sandra Valladares as Red Carpet Repor ...

# %%
doc_emb = np.asarray(co.embed(texts=docs_txt, model="embed-v4.0", input_type="search_document").embeddings)
print(f"Doc embeddings: {doc_emb.shape}")
# Out:
# Doc embeddings: (50, 1536)

# %% [markdown]
# # Embedding-Only Search Results

# %%
# Now we define a specific query and first run embedding search to go from 50 movies to 10 movies
query = "Action movies with Christian Bale"

# Get the query embedding
query_emb = np.asarray(co.embed(texts=[query], model="embed-v4.0", input_type="search_query").embeddings)

# Compute the cosine similarity / dot product for the query embedding and all document embeddings
dot_scores = np.matmul(query_emb, doc_emb.transpose())[0]

# Get the top_10 hits
top_10_hits = np.argsort(-dot_scores).tolist()[0:10]

# Create a data frame with the top-10 results

# We see that the data frame contains some Christian Bale movies, but
# not necessarily at the top positions
emb_results = df.iloc[top_10_hits].copy()
emb_results.insert(loc=0, column='rank', value=(np.arange(len(emb_results))+1))
emb_results
# Out:
#       rank                       title  \
# 227      1                     Taken 2
# 1323     2                 Exit Wounds
# 534      3                  Braveheart
# 486      4          The Social Network
# 4015     5                 Remember Me
# 79       6  The Twilight Saga: Eclipse
# 586      7                 Superman II
# 2992     8                  Four Lions
# 759      9           The Monuments Men
# 596     10              Tropic Thunder
#
#                                                overview  \
# 227   In Istanbul, retired CIA operative Bryan Mills...
# 1323  Maverick cop Orin Boyd always brings down the ...
# 534   Enraged at the slaughter of Murron, his new br...
# 486   On a fall night in 2003, Harvard undergrad and...
# 4015  Still reeling from a heartbreaking family even...
# 79    Bella once again finds herself surrounded by d...
# 586   Three escaped criminals from the planet Krypto...
# 2992  Four Lions tells the story of a group of Briti...
# 759   Based on the true story of the greatest treasu...
# 596   Vietnam veteran 'Four Leaf' Tayback's memoir, ...
#
#                                            genres  \
# 227                       Action, Crime, Thriller
# 1323                      Action, Crime, Thriller
# 534                   Action, Drama, History, War
# 486                                         Drama
# 4015                               Drama, Romance
# 79             Adventure, Fantasy, Drama, Romance
# 586   Action, Adventure, Fantasy, Science Fiction
# 2992                         Comedy, Crime, Drama
# 759                   War, Drama, History, Action
# 596                                Action, Comedy
#
#                                                producer  \
# 227   Twentieth Century Fox Film Corporation, M6 Fil...
# 1323  Village Roadshow Pictures, NPV Entertainment, ...
# 534   Icon Entertainment International, The Ladd Com...
# 486   Columbia Pictures, Scott Rudin Productions, Re...
# 4015                               Summit Entertainment
# 79    Summit Entertainment, Maverick Films, Imprint ...
# 586      Warner Bros., Dovemead Films, Film Export A.G.
# 2992  Film4, Drafthouse Films, Warp Films, Wild Bunc...
# 759   Columbia Pictures, Studio Babelsberg, Fox 2000...
# 596   DreamWorks SKG, Goldcrest Pictures, Red Hour F...
#
#                                                    cast
# 227   Liam Neeson as Bryan Mills, Maggie Grace as Ki...
# 1323  Steven Seagal as Orin Boyd, DMX as Latrell Wal...
# 534   Mel Gibson as William Wallace, Catherine McCor...
# 486   Jesse Eisenberg as Mark Zuckerberg, Andrew Gar...
# 4015  Robert Pattinson as Tyler Hawkins, Emilie de R...
# 79    Kristen Stewart as Isabella 'Bella' Swan, Robe...
# 586   Gene Hackman as Lex Luthor, Christopher Reeve ...
# 2992  Riz Ahmed as Omar, Nigel Lindsay as Barry, Kay...
# 759   Matt Damon as James Granger, Cate Blanchett as...
# 596   Ben Stiller as Tugg Speedman, Jack Black as Je...

# %% [markdown]
# # Rerank 3 Search Results
# We transform the dataframe to a list of JSON records, and then use the JSON capabilities of Rerank 3 for the ranking.

# %%
# We now use rerank to improve our results. We rerank the results from embedding search

# Convert the data frame with the results from embeddings search to a list with JSON rows
docs = emb_results.to_dict('records')

#We rank over all fields in our DataFrame. You could also limit the columns you want to include in the search
rank_fields = list(docs[0].keys())

#We pass this to co.rerank
results = co.rerank(query=query, documents=docs, top_n=5, model='rerank-v3.5', rank_fields=rank_fields)

# Collect the indices for the top results
top_ids = [hit.index for hit in results.results]

# Create the DataFrame with the rerank results
rerank_results = emb_results.iloc[top_ids].copy()
rerank_results['rank'] = (np.arange(len(rerank_results))+1)

# Show results for the query "Action movies with Christian Bale"
# We now see that the top positions all contain action movies with Christian Bale (Reign of Fire, The Dark Knight Rises, ...)
rerank_results
# Out:
#       rank              title  \
# 586      1        Superman II
# 759      2  The Monuments Men
# 1323     3        Exit Wounds
# 534      4         Braveheart
# 227      5            Taken 2
#
#                                                overview  \
# 586   Three escaped criminals from the planet Krypto...
# 759   Based on the true story of the greatest treasu...
# 1323  Maverick cop Orin Boyd always brings down the ...
# 534   Enraged at the slaughter of Murron, his new br...
# 227   In Istanbul, retired CIA operative Bryan Mills...
#
#                                            genres  \
# 586   Action, Adventure, Fantasy, Science Fiction
# 759                   War, Drama, History, Action
# 1323                      Action, Crime, Thriller
# 534                   Action, Drama, History, War
# 227                       Action, Crime, Thriller
#
#                                                producer  \
# 586      Warner Bros., Dovemead Films, Film Export A.G.
# 759   Columbia Pictures, Studio Babelsberg, Fox 2000...
# 1323  Village Roadshow Pictures, NPV Entertainment, ...
# 534   Icon Entertainment International, The Ladd Com...
# 227   Twentieth Century Fox Film Corporation, M6 Fil...
#
#                                                    cast
# 586   Gene Hackman as Lex Luthor, Christopher Reeve ...
# 759   Matt Damon as James Granger, Cate Blanchett as...
# 1323  Steven Seagal as Orin Boyd, DMX as Latrell Wal...
# 534   Mel Gibson as William Wallace, Catherine McCor...
# 227   Liam Neeson as Bryan Mills, Maggie Grace as Ki...
