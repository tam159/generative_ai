# %% [markdown]
# # Cohere Rerank 3 - Search over Tabular Data
#
# This notebook shows an example how the JSON capabilities of [Cohere Rerank 3](https://txt.cohere.com/rerank-3/) can be used to search over tabular data, in this example for a Pandas DataFrame with top-5000 movies.

# %%
# !pip install -q cohere pandas numpy

# %%
from dotenv import load_dotenv

import pandas as pd
import cohere
import numpy as np

# %%
load_dotenv()
# Out:
# True

# %%
# Get your free API key from: www.cohere.com
# cohere_key = "<<YOUR_COHERE_API_KEY>>"
# co = cohere.Client(cohere_key)
co = cohere.Client()

# %%
# Here we load a pandas DataFrame with around top-5000 movies
df = pd.read_parquet("https://huggingface.co/datasets/Cohere/movies/resolve/main/movies.parquet")
df
# Out:
#                             title  \
# 0                          Avatar
# 1                         Titanic
# 2                    The Avengers
# 3                  Jurassic World
# 4                       Furious 7
# ...                           ...
# 4798             Midnight Cabaret
# 4799             Growing Up Smith
# 4800                       8 Days
# 4801              Running Forever
# 4802  To Be Frank, Sinatra at 100
#
#                                                overview  \
# 0     In the 22nd century, a paraplegic Marine is di...
# 1     84 years later, a 101-year-old woman named Ros...
# 2     When an unexpected enemy emerges and threatens...
# 3     Twenty-two years after the events of Jurassic ...
# 4     Deckard Shaw seeks revenge against Dominic Tor...
# ...                                                 ...
# 4798  A Broadway producer puts on a play with a Devi...
# 4799  In 1979, an Indian family moves to America wit...
# 4800  After sneaking to a party with her friends, 16...
# 4801  After being estranged since her mother's death...
# 4802                                               None
#
#                                             genres  \
# 0      Action, Adventure, Fantasy, Science Fiction
# 1                         Drama, Romance, Thriller
# 2               Science Fiction, Action, Adventure
# 3     Action, Adventure, Science Fiction, Thriller
# 4                                           Action
# ...                                            ...
# 4798                                        Horror
# 4799                         Comedy, Family, Drama
# 4800                               Thriller, Drama
# 4801                                        Family
# 4802                                   Documentary
#
#                                                producer  \
# 0     Ingenious Film Partners, Twentieth Century Fox...
# 1     Paramount Pictures, Twentieth Century Fox Film...
# 2                    Paramount Pictures, Marvel Studios
# 3     Universal Studios, Amblin Entertainment, Legen...
# 4     Universal Pictures, Original Film, Fuji Televi...
# ...                                                 ...
# 4798
# 4799
# 4800                                After Eden Pictures
# 4801                               New Kingdom Pictures
# 4802                              Eyeline Entertainment
#
#                                                    cast
# 0     Sam Worthington as Jake Sully, Zoe Saldana as ...
# 1     Kate Winslet as Rose DeWitt Bukater, Leonardo ...
# 2     Robert Downey Jr. as Tony Stark / Iron Man, Ch...
# 3     Chris Pratt as Owen Grady, Bryce Dallas Howard...
# 4     Vin Diesel as Dominic Toretto, Paul Walker as ...
# ...                                                 ...
# 4798  Lisa Hart Carroll as Dawn, Michael Des Barres ...
# 4799  Roni Akurati as Smith Bhatnagar, Brighton Shar...
# 4800  Nicole Smolen as Amber, Kim Baldwin as BB, Ari...
# 4801
# 4802                        Tony Oppedisano as Narrator
#
# [4803 rows x 5 columns]

# %%
# First we embed all movies to be able to go from 5000 movies to top-100 movies
docs_txt = [str(doc) for doc in df.to_dict('records')]
print(docs_txt[0])
# Out:
# {'title': 'Avatar', 'overview': 'In the 22nd century, a paraplegic Marine is dispatched to the moon Pandora on a unique mission, but becomes torn between following orders and protecting an alien civilization
# %%
# Now we define a specific query and first run embedding search to go from 5000 movies to 100 movies
query = "Action movies with Christian Bale"

# Get the query embedding
query_emb = np.asarray(co.embed(texts=[query], model="embed-english-v3.0", input_type="search_query").embeddings)

# Compute the cosine similarity / dot product for the query embedding and all document embeddings
dot_scores = np.matmul(query_emb, doc_emb.transpose())[0]

# Get the top_100 hits
top_100_hits = np.argsort(-dot_scores).tolist()[0:100]

# Create a data frame with the top-100 results

# We see that the data frame contains some Christian Bale movies, but
# not necessarily at the top positions
emb_results = df.iloc[top_100_hits].copy()
emb_results.insert(loc=0, column='rank', value=(np.arange(len(emb_results))+1))
emb_results
# Out:
#       rank                       title  \
# 1874     1                         War
# 2942     2                 Equilibrium
# 1818     3               Reign of Fire
# 2361     4              Action Jackson
# 417      5                 Cliffhanger
# ...    ...                         ...
# 2028    96                       I Spy
# 130     97             American Sniper
# 3906    98            The Devil's Tomb
# 247     99  Die Hard: With a Vengeance
# 4492   100                      U.F.O.
#
#                                                overview  \
# 1874  FBI agent Jack Crawford is out for revenge whe...
# 2942  In a dystopian future, a totalitarian regime m...
# 1818  In post-apocalyptic England, an American volun...
# 2361  Vengence drives a tough Detroit cop to stay on...
# 417   A year after losing his friend in a tragic 4,0...
# ...                                                 ...
# 2028  When the Switchblade, the most sophisticated p...
# 130   U.S. Navy SEAL Chris Kyle takes his sole missi...
# 3906  Captain Mack leads an elite military unit on a...
# 247   New York detective John McClane is back and ki...
# 4492  A group of friends awake one morning to find a...
#
#                                          genres  \
# 1874                    Action, Thriller, Crime
# 2942          Action, Science Fiction, Thriller
# 1818                 Adventure, Action, Fantasy
# 2361    Action, Adventure, Comedy, Crime, Drama
# 417                 Action, Adventure, Thriller
# ...                                         ...
# 2028        Action, Adventure, Comedy, Thriller
# 130                                 War, Action
# 3906  Action, Horror, Thriller, Science Fiction
# 247                            Action, Thriller
# 4492         Action, Adventure, Science Fiction
#
#                                                producer  \
# 1874  Mosaic Media Group, Current Entertainment, Lio...
# 2942            Dimension Films, Blue Tulip Productions
# 1818  The Zanuck Company, Spyglass Entertainment, Wo...
# 2361           Silver Pictures, Lorimar Motion Pictures
# 417   TriStar Pictures, Canal+, Carolco Pictures, RC...
# ...                                                 ...
# 2028                      Columbia Pictures Corporation
# 130   Village Roadshow Pictures, Malpaso Productions...
# 3906  Ice Cold Productions, Empyreal Entertainment, ...
# 247   Twentieth Century Fox Film Corporation, Cinerg...
# 4492        Hawthorn Productions, Hawthorne Productions
#
#                                                    cast
# 1874  Jet Li as Rogue, Jason Statham as Special Agen...
# 2942  Christian Bale as John Preston, Taye Diggs as ...
# 1818  Christian Bale as Quinn Abercromby, Matthew Mc...
# 2361  Carl Weathers as Sgt. Jericho 'Action' Jackson...
# 417   Sylvester Stallone as Gabe Walker, John Lithgo...
# ...                                                 ...
# 2028  Eddie Murphy as Kelly Robinson, Owen Wilson as...
# 130   Bradley Cooper as Chris Kyle, Sienna Miller as...
# 3906  Cuba Gooding Jr. as Mack, Ray Winstone as Blak...
# 247   Bruce Willis as John McClane, Jeremy Irons as ...
# 4492  Bianca Bree as Carrie, Sean Brosnan as Michael...
#
# [100 rows x 6 columns]

# %% [markdown]
# # Rerank 3 Search Results
# We transform the dataframe to a list of JSON records, and then use the JSON capabilities of Rerank 3 for the ranking.

# %%
# We now use rerank to improve our results. We rerank the results from embedding search

# Convert the data frame with the results from embeddings search to a list with JSON rows
docs = emb_results.to_dict('records')

#We rank over all fields in our DataFrame. You could also limit the columns you want to include in the search
rank_fields = list(docs[0].keys())

#We pass this to co.rerank
results = co.rerank(query=query, documents=docs, top_n=10, model='rerank-english-v3.0', rank_fields=rank_fields)

# Collect the indices for the  top results
top_ids = [hit.index for hit in results.results]

# Create the DataFrame with the rerank results
rerank_results = emb_results.iloc[top_ids].copy()
rerank_results['rank'] = (np.arange(len(rerank_results))+1)

# Show results for the query "Action movies with Christian Bale"
# We now see that the top positions all contain action movies with Christian Bale (Reign of Fire, The Dark Knight Rises, ...)
rerank_results
# Out:
#       rank                  title  \
# 1818     1          Reign of Fire
# 2942     2            Equilibrium
# 14       3  The Dark Knight Rises
# 20       4        The Dark Knight
# 2849     5            Rescue Dawn
# 1176     6     The Flowers of War
# 4492     7                 U.F.O.
# 1688     8           Maximum Risk
# 531      9      Kingdom of Heaven
# 288     10               The Rock
#
#                                                overview  \
# 1818  In post-apocalyptic England, an American volun...
# 2942  In a dystopian future, a totalitarian regime m...
# 14    Following the death of District Attorney Harve...
# 20    Batman raises the stakes in his war on crime. ...
# 2849  A US Fighter pilot's epic struggle of survival...
# 1176  A Westerner finds refuge with a group of women...
# 4492  A group of friends awake one morning to find a...
# 1688  A policeman takes his twin brother's place and...
# 531   After his wife dies, a blacksmith named Balian...
# 288   A group of renegade marine commandos seizes a ...
#
#                                       genres  \
# 1818              Adventure, Action, Fantasy
# 2942       Action, Science Fiction, Thriller
# 14            Action, Crime, Drama, Thriller
# 20            Drama, Action, Crime, Thriller
# 2849                   Adventure, Drama, War
# 1176                     Drama, History, War
# 4492      Action, Adventure, Science Fiction
# 1688             Action, Adventure, Thriller
# 531   Drama, Action, Adventure, History, War
# 288              Action, Adventure, Thriller
#
#                                                producer  \
# 1818  The Zanuck Company, Spyglass Entertainment, Wo...
# 2942            Dimension Films, Blue Tulip Productions
# 14    Legendary Pictures, Warner Bros., DC Entertain...
# 20    DC Comics, Legendary Pictures, Warner Bros., D...
# 2849                          Metro-Goldwyn-Mayer (MGM)
# 1176  Beijing New Picture Film Co. Ltd., EDKO Film, ...
# 4492        Hawthorn Productions, Hawthorne Productions
# 1688                                  Columbia Pictures
# 531   Studio Babelsberg, Twentieth Century Fox Film ...
# 288   Hollywood Pictures, Don Simpson/Jerry Bruckhei...
#
#                                                    cast
# 1818  Christian Bale as Quinn Abercromby, Matthew Mc...
# 2942  Christian Bale as John Preston, Taye Diggs as ...
# 14    Christian Bale as Bruce Wayne / Batman, Michae...
# 20    Christian Bale as Bruce Wayne, Heath Ledger as...
# 2849  Christian Bale as Dieter Dengler, Steve Zahn a...
# 1176  Christian Bale as John Miller, Ni Ni as Yu Mo,...
# 4492  Bianca Bree as Carrie, Sean Brosnan as Michael...
# 1688  Jean-Claude Van Damme as Mikhail Suverov, Nata...
# 531   Orlando Bloom as Balian de Ibelin, Eva Green a...
# 288   Sean Connery as John Patrick Mason, Nicolas Ca...
